# %% [markdown]
# #### Explanation of Word Mover's Distance
# Imagine you have a box of different colored LEGO blocks, and each color represents a word. Now, let's say you want to build two towers out of these blocks, but the towers look a little different from each other.
#
# The **Word Mover's Distance (WMD)** is like figuring out the smallest number of steps it would take to move the blocks around so that one tower looks exactly like the other one. In this case, the blocks are words, and the steps are how different the words are from each other.
#
# For example, if one tower has a red block (representing the word "cat") and the other has a pink block (representing the word "kitten"), it wouldn't take many steps to swap them because they’re pretty similar. But if it was a red block ("cat") and a blue block ("car"), it would take more steps since those words are less related.
#
# The WMD algorithm does this for all the words in two sentences to see how "close" the meanings of the sentences are. If it takes just a few steps, the sentences mean almost the same thing. If it takes a lot of steps, the meanings are quite different.

# %%
import numpy as np
import gensim
from gensim.models import KeyedVectors
from sklearn.metrics import pairwise_distances
from nltk.corpus import stopwords
import nltk
import re

# Download NLTK stopwords
nltk.download('stopwords')
print("Libraries imported and NLTK stopwords downloaded.")
# Out:
# Libraries imported and NLTK stopwords downloaded.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Path to preprocessed GloVe Word2Vec file
word2vec_path = r"C:\Users\KIIT\PycharmProjects\JupyterProject\data\glove.6B.100d.word2vec.txt"

# Load keyed vectors
glove_model = KeyedVectors.load_word2vec_format(word2vec_path, binary=False)
print("Preprocessed GloVe embeddings loaded successfully.")
# Out:
# Preprocessed GloVe embeddings loaded successfully.

# %%
# Define stopwords
stop_words = set(stopwords.words('english'))

def preprocess(sentence):
    # Convert to lowercase
    sentence = sentence.lower()
    # Remove punctuation and numbers
    sentence = re.sub(r'[^a-z\s]', '', sentence)
    # Tokenize into words
    words = sentence.split()
    # Remove stopwords
    words = [word for word in words if word not in stop_words]
    return words

print("Text preprocessing function defined.")
# Out:
# Text preprocessing function defined.

# %%
# Path to original dataset
original_dataset_path = r"C:\Users\KIIT\PycharmProjects\JupyterProject\data\sentence_pairs.txt"

# Path to reformatted dataset
reformatted_dataset_path = r"C:\Users\KIIT\PycharmProjects\JupyterProject\data\sentence_pairs_reformatted.txt"

# Reformat dataset
with open(original_dataset_path, 'r', encoding='utf-8') as infile, \
     open(reformatted_dataset_path, 'w', encoding='utf-8') as outfile:
    for line in infile:
        # Split into two sentences based on "Sentence B:"
        parts = line.strip().split("Sentence B:")
        if len(parts) == 2:
            sentence_a = parts[0].replace("Sentence A:", "").strip()
            sentence_b = parts[1].strip()
            outfile.write(f"{sentence_a}\t{sentence_b}\n")
        else:
            print(f"Skipping malformed line: {line.strip()}")

print("Dataset reformatted successfully.")
# Out:
# Dataset reformatted successfully.

# %%
# Path to dataset
dataset_path = r"C:\Users\KIIT\PycharmProjects\JupyterProject\data\sentence_pairs_reformatted.txt"

# Read sentence pairs
sentence_pairs = []
with open(dataset_path, 'r', encoding='utf-8') as file:
    for line in file:
        # Strip whitespace and split by tab
        parts = line.strip().split('\t')

        # Ensure there are exactly two parts (sentence A and sentence B)
        if len(parts) == 2:
            sentence_a, sentence_b = parts
            sentence_pairs.append((sentence_a, sentence_b))
        else:
            print(f"Skipping malformed line: {line.strip()}")

print(f"Dataset loaded successfully with {len(sentence_pairs)} valid sentence pairs.")
# Out:
# Dataset loaded successfully with 50 valid sentence pairs.

# %%
def calculate_wmd(sentence_a, sentence_b):
    # Preprocess sentences
    words_a = preprocess(sentence_a)
    words_b = preprocess(sentence_b)

    # Print the list of words being passed to the model
    print(f"Sentence A: {sentence_a}")
    print(f"Processed Words A: {words_a}")
    print(f"Sentence B: {sentence_b}")
    print(f"Processed Words B: {words_b}")

    # Calculate WMD
    if len(words_a) == 0 or len(words_b) == 0:
        print("One or both sentences have no valid words after preprocessing. Skipping...")
        return None

    wmd_distance = glove_model.wmdistance(words_a, words_b)
    print(f"Word Movers Distance: {wmd_distance:.4f}\n")
    return wmd_distance

# Calculate WMD for all sentence pairs
results = []
for idx, (sentence_a, sentence_b) in enumerate(sentence_pairs, start=1):
    print(f"Processing Pair {idx}:")
    wmd_score = calculate_wmd(sentence_a, sentence_b)
    results.append((sentence_a, sentence_b, wmd_score))
# Out:
# Processing Pair 1:
# Sentence A: 1.  The cat sleeps on the couch.
# Processed Words A: ['cat', 'sleeps', 'couch']
# Sentence B: A dog rests on the sofa.
# Processed Words B: ['dog', 'rests', 'sofa']
# Word Movers Distance: 0.8288
#
# Processing Pair 2:
# Sentence A: 2.  She enjoys reading books in the park.
# Processed Words A: ['enjoys', 'reading', 'books', 'park']
# Sentence B: He likes to read novels outdoors.
# Processed Words B: ['likes', 'read', 'novels', 'outdoors']
# Word Movers Distance: 0.9093
#
# Processing Pair 3:
# Sentence A: 3.  The weather is sunny today.
# Processed Words A: ['weather', 'sunny', 'today']
# Sentence B: It's a bright and clear day.
# Processed Words B: ['bright', 'clear', 'day']
# Word Movers Distance: 0.8642
#
# Processing Pair 4:
# Sentence A: 4.  I love eating pizza with friends.
# Processed Words A: ['love', 'eating', 'pizza', 'friends']
# Sentence B: My favorite food is pizza.
# Processed Words B: ['favorite', 'food', 'pizza']
# Word Movers Distance: 0.7091
#
# Processing Pair 5:
# Sentence A: 5.  The boy plays soccer in the yard.
# Processed Words A: ['boy', 'plays', 'soccer', 'yard']
# Sentence B: A child kicks a ball in the garden.
# Processed Words B: ['child', 'kicks', 'ball', 'garden']
# Word Movers Distance: 0.9616
#
# Processing Pair 6:
# Sentence A: 6.  She drives a red car to work.
# Processed Words A: ['drives', 'red', 'car', 'work']
# Sentence B: Her vehicle is crimson.
# Processed Words B: ['vehicle', 'crimson']
# Word Movers Distance: 0.9414
#
# Processing Pair 7:
# Sentence A: 7.  They went hiking in the mountains.
# Processed Words A: ['went', 'hiking', 'mountains']
# Sentence B: The group climbed hills for fun.
# Processed Words B: ['group', 'climbed', 'hills', 'fun']
# Word Movers Distance: 0.9951
#
# Processing Pair 8:
# Sentence A: 8.  The movie was very entertaining.
# Processed Words A: ['movie', 'entertaining']
# Sentence B: It was an enjoyable film.
# Processed Words B: ['enjoyable', 'film']
# Word Movers Distance: 0.5238
#
# Processing Pair 9:
# Sentence A: 9.  He bought a new laptop for school.
# Processed Words A: ['bought', 'new', 'laptop', 'school']
# Sentence B: His computer is brand new.
# Processed Words B: ['computer', 'brand', 'new']
# Word Movers Distance: 0.6899
#
# Processing Pair 10:
# Sentence A: 10.  The teacher explained the lesson clearly.
# Processed Words A: ['teacher', 'explained', 'lesson', 'clearly']
# Sentence B: The instructor made the topic easy to understand.
# Processed Words B: ['instructor', 'made', 'topic', 'easy', 'understand']
# Word Movers Distance: 0.8994
#
# Processing Pair 11:
# Sentence A: 11.  The flowers bloom in spring.
# Processed Words A: ['flowers', 'bloom', 'spring']
# Sentence B: Blossoms appear during the warmer months.
# Processed Words B: ['blossoms', 'appear', 'warmer', 'months']
# Word Movers Distance: 0.9841
#
# Processing Pair 12:
# Sentence A: 12.  We visited Paris last summer.
# Processed Words A: ['visited', 'paris', 'last', 'summer']
# Sentence B: Our trip to France was amazing.
# Processed Words B: ['trip', 'france', 'amazing']
# Word Movers Distance: 0.9311
#
# Processing Pair 13:
# Sentence A: 13.  The baby cried all night.
# Processed Words A: ['baby', 'cried', 'night']
# Sentence B: The infant was upset throughout the evening.
# Processed Words B: ['infant', 'upset', 'throughout', 'evening']
# Word Movers Distance: 0.9201
#
# Processing Pair 14:
# Sentence A: 14.  She painted a beautiful picture.
# Processed Words A: ['painted', 'beautiful', 'picture']
# Sentence B: Her artwork was stunning.
# Processed Words B: ['artwork', 'stunning']
# Word Movers Distance: 0.9410
#
# Processing Pair 15:
# Sentence A: 15.  The man wore a black suit to the wedding.
# Processed Words A: ['man', 'wore', 'black', 'suit', 'wedding']
# Sentence B: He dressed formally for the event.
# Processed Words B: ['dressed', 'formally', 'event']
# Word Movers Distance: 0.9971
#
# Processing Pair 16:
# Sentence A: 16.  I need to buy groceries for dinner.
# Processed Words A: ['need', 'buy', 'groceries', 'dinner']
# Sentence B: Shopping for food is necessary tonight.
# Processed Words B: ['shopping', 'food', 'necessary', 'tonight']
# Word Movers Distance: 0.8812
#
# Processing Pair 17:
# Sentence A: 17.  The train arrived late at the station.
# Processed Words A: ['train', 'arrived', 'late', 'station']
# Sentence B: The locomotive was delayed.
# Processed Words B: ['locomotive', 'delayed']
# Word Movers Distance: 1.0207
#
# Processing Pair 18:
# Sentence A: 18.  She sings beautifully in the choir.
# Processed Words A: ['sings', 'beautifully', 'choir']
# Sentence B: Her voice is lovely during performances.
# Processed Words B: ['voice', 'lovely', 'performances']
# Word Movers Distance: 0.8753
#
# Processing Pair 19:
# Sentence A: 19.  The restaurant serves delicious pasta.
# Processed Words A: ['restaurant', 'serves', 'delicious', 'pasta']
# Sentence B: Their spaghetti is fantastic.
# Processed Words B: ['spaghetti', 'fantastic']
# Word Movers Distance: 1.0900
#
# Processing Pair 20:
# Sentence A: 20.  He fixed the broken chair with glue.
# Processed Words A: ['fixed', 'broken', 'chair', 'glue']
# Sentence B: The damaged seat was repaired.
# Processed Words B: ['damaged', 'seat', 'repaired']
# Word Movers Distance: 1.0601
#
# Processing Pair 21:
# Sentence A: 21.  The sun sets in the west.
# Processed Words A: ['sun', 'sets', 'west']
# Sentence B: Sunset occurs over the horizon.
# Processed Words B: ['sunset', 'occurs', 'horizon']
# Word Movers Distance: 1.1504
#
# Processing Pair 22:
# Sentence A: 22.  She studies biology at university.
# Processed Words A: ['studies', 'biology', 'university']
# Sentence B: Her major is life sciences.
# Processed Words B: ['major', 'life', 'sciences']
# Word Movers Distance: 0.9402
#
# Processing Pair 23:
# Sentence A: 23.  The bird flew high in the sky.
# Processed Words A: ['bird', 'flew', 'high', 'sky']
# Sentence B: A feathered creature soared above.
# Processed Words B: ['feathered', 'creature', 'soared']
# Word Movers Distance: 1.1475
#
# Processing Pair 24:
# Sentence A: 24.  I prefer coffee over tea.
# Processed Words A: ['prefer', 'coffee', 'tea']
# Sentence B: Coffee is my favorite drink.
# Processed Words B: ['coffee', 'favorite', 'drink']
# Word Movers Distance: 0.6398
#
# Processing Pair 25:
# Sentence A: 25.  The library is quiet and peaceful.
# Processed Words A: ['library', 'quiet', 'peaceful']
# Sentence B: It's a calm place to study.
# Processed Words B: ['calm', 'place', 'study']
# Word Movers Distance: 0.9013
#
# Processing Pair 26:
# Sentence A: 26.  He runs every morning to stay fit.
# Processed Words A: ['runs', 'every', 'morning', 'stay', 'fit']
# Sentence B: Jogging keeps him healthy.
# Processed Words B: ['jogging', 'keeps', 'healthy']
# Word Movers Distance: 1.0620
#
# Processing Pair 27:
# Sentence A: 27.  The cake was sweet and delicious.
# Processed Words A: ['cake', 'sweet', 'delicious']
# Sentence B: It tasted sugary and delightful.
# Processed Words B: ['tasted', 'sugary', 'delightful']
# Word Movers Distance: 0.9559
#
# Processing Pair 28:
# Sentence A: 28.  She writes poems in her free time.
# Processed Words A: ['writes', 'poems', 'free', 'time']
# Sentence B: Her hobby is composing verses.
# Processed Words B: ['hobby', 'composing', 'verses']
# Word Movers Distance: 1.1098
#
# Processing Pair 29:
# Sentence A: 29.  The river flows gently through the valley.
# Processed Words A: ['river', 'flows', 'gently', 'valley']
# Sentence B: Water moves smoothly across the land.
# Processed Words B: ['water', 'moves', 'smoothly', 'across', 'land']
# Word Movers Distance: 1.0171
#
# Processing Pair 30:
# Sentence A: 30.  He enjoys playing video games.
# Processed Words A: ['enjoys', 'playing', 'video', 'games']
# Sentence B: Gaming is his favorite activity.
# Processed Words B: ['gaming', 'favorite', 'activity']
# Word Movers Distance: 1.0829
#
# Processing Pair 31:
# Sentence A: 31.  The house has a red roof.
# Processed Words A: ['house', 'red', 'roof']
# Sentence B: Its top is crimson-colored.
# Processed Words B: ['top', 'crimsoncolored']
# Word Movers Distance: 1.0241
#
# Processing Pair 32:
# Sentence A: 32.  They celebrated their anniversary with dinner.
# Processed Words A: ['celebrated', 'anniversary', 'dinner']
# Sentence B: The couple marked their special day with a meal.
# Processed Words B: ['couple', 'marked', 'special', 'day', 'meal']
# Word Movers Distance: 0.9171
#
# Processing Pair 33:
# Sentence A: 33.  The book is full of interesting stories.
# Processed Words A: ['book', 'full', 'interesting', 'stories']
# Sentence B: It contains many fascinating tales.
# Processed Words B: ['contains', 'many', 'fascinating', 'tales']
# Word Movers Distance: 0.7637
#
# Processing Pair 34:
# Sentence A: 34.  She danced gracefully at the party.
# Processed Words A: ['danced', 'gracefully', 'party']
# Sentence B: Her movements were elegant during the event.
# Processed Words B: ['movements', 'elegant', 'event']
# Word Movers Distance: 1.1721
#
# Processing Pair 35:
# Sentence A: 35.  The storm caused heavy rain.
# Processed Words A: ['storm', 'caused', 'heavy', 'rain']
# Sentence B: Bad weather led to intense precipitation.
# Processed Words B: ['bad', 'weather', 'led', 'intense', 'precipitation']
# Word Movers Distance: 0.9094
#
# Processing Pair 36:
# Sentence A: 36.  He works as a software engineer.
# Processed Words A: ['works', 'software', 'engineer']
# Sentence B: His job involves coding and programming.
# Processed Words B: ['job', 'involves', 'coding', 'programming']
# Word Movers Distance: 1.0687
#
# Processing Pair 37:
# Sentence A: 37.  The lamp provides bright light.
# Processed Words A: ['lamp', 'provides', 'bright', 'light']
# Sentence B: It illuminates the room well.
# Processed Words B: ['illuminates', 'room', 'well']
# Word Movers Distance: 1.0269
#
# Processing Pair 38:
# Sentence A: 38.  She loves traveling to new places.
# Processed Words A: ['loves', 'traveling', 'new', 'places']
# Sentence B: Exploring different locations is her passion.
# Processed Words B: ['exploring', 'different', 'locations', 'passion']
# Word Movers Distance: 0.9053
#
# Processing Pair 39:
# Sentence A: 39.  The dog barked loudly at the stranger.
# Processed Words A: ['dog', 'barked', 'loudly', 'stranger']
# Sentence B: It growled noisily at the unknown person.
# Processed Words B: ['growled', 'noisily', 'unknown', 'person']
# Word Movers Distance: 0.9488
#
# Processing Pair 40:
# Sentence A: 40.  He built a wooden table for his home.
# Processed Words A: ['built', 'wooden', 'table', 'home']
# Sentence B: A furniture piece was crafted by him.
# Processed Words B: ['furniture', 'piece', 'crafted']
# Word Movers Distance: 1.0675
#
# Processing Pair 41:
# Sentence A: 41.  The clouds drifted lazily in the sky.
# Processed Words A: ['clouds', 'drifted', 'lazily', 'sky']
# Sentence B: They moved slowly above the ground.
# Processed Words B: ['moved', 'slowly', 'ground']
# Word Movers Distance: 1.0990
#
# Processing Pair 42:
# Sentence A: 42.  She learned to play the guitar.
# Processed Words A: ['learned', 'play', 'guitar']
# Sentence B: Mastering the instrument was her goal.
# Processed Words B: ['mastering', 'instrument', 'goal']
# Word Movers Distance: 0.9791
#
# Processing Pair 43:
# Sentence A: 43.  The ocean waves crashed against the shore.
# Processed Words A: ['ocean', 'waves', 'crashed', 'shore']
# Sentence B: Water hit the beach forcefully.
# Processed Words B: ['water', 'hit', 'beach', 'forcefully']
# Word Movers Distance: 1.0207
#
# Processing Pair 44:
# Sentence A: 44.  He enjoys watching movies on weekends.
# Processed Words A: ['enjoys', 'watching', 'movies', 'weekends']
# Sentence B: Films are his favorite weekend activity.
# Processed Words B: ['films', 'favorite', 'weekend', 'activity']
# Word Movers Distance: 0.8794
#
# Processing Pair 45:
# Sentence A: 45.  The tree lost its leaves in autumn.
# Processed Words A: ['tree', 'lost', 'leaves', 'autumn']
# Sentence B: Foliage fell from the plant during fall.
# Processed Words B: ['foliage', 'fell', 'plant', 'fall']
# Word Movers Distance: 0.8975
#
# Processing Pair 46:
# Sentence A: 46.  She baked cookies for her friends.
# Processed Words A: ['baked', 'cookies', 'friends']
# Sentence B: Homemade treats were prepared for her companions.
# Processed Words B: ['homemade', 'treats', 'prepared', 'companions']
# Word Movers Distance: 0.9980
#
# Processing Pair 47:
# Sentence A: 47.  The phone rang continuously.
# Processed Words A: ['phone', 'rang', 'continuously']
# Sentence B: It kept buzzing repeatedly.
# Processed Words B: ['kept', 'buzzing', 'repeatedly']
# Word Movers Distance: 1.0765
#
# Processing Pair 48:
# Sentence A: 48.  He dreamed of becoming a pilot.
# Processed Words A: ['dreamed', 'becoming', 'pilot']
# Sentence B: Flying planes was his aspiration.
# Processed Words B: ['flying', 'planes', 'aspiration']
# Word Movers Distance: 1.1079
#
# Processing Pair 49:
# Sentence A: 49.  The clock ticked quietly in the room.
# Processed Words A: ['clock', 'ticked', 'quietly', 'room']
# Sentence B: Time passed silently in the space.
# Processed Words B: ['time', 'passed', 'silently', 'space']
# Word Movers Distance: 0.9790
#
# Processing Pair 50:
# Sentence A: 50.  She planted flowers in the garden.
# Processed Words A: ['planted', 'flowers', 'garden']
# Sentence B: Blooms were added to the outdoor area.
# Processed Words B: ['blooms', 'added', 'outdoor', 'area']
# Word Movers Distance: 0.9977

# %% [markdown]
# #### Explanation of Optimised Word Mover's Distance Algorithm
# Imagine again that you have those LEGO towers, but now, you’re smarter about which blocks to move.
#
# Let’s say some blocks have special stickers on them—like “NOUN” or “VERB”—to show what type of word they are, like naming things (NOUN, like “cat” or “dog”) or actions (VERB, like “run” or “jump”). You realize that some blocks are more important for building the tower’s shape than others.
#
# For example, in the sentence “The cat is jumping,” the important words are “cat” (a NOUN) and “jumping” (a VERB). Words like “the” and “is” are like tiny connector blocks that don’t change the tower’s shape much.
#
# So, in the **optimized Word Mover’s Distance (WMD)**, you decide to:
# 1. Focus mainly on the important blocks with stickers like NOUN (NN, NNS), VERB (VBG, VBZ), and ADJECTIVE (JJ).
# 2. Ignore or give less importance to tiny connector blocks like “the,” “is,” or “and” because they don’t change the meaning much.
#
# By being picky about which blocks to move, you need fewer steps to make the towers look the same, and you get the answer faster! This is how the optimized version makes comparing sentence meanings quicker and more accurate.

# %%
import spacy
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import time

# Load SpaCy's English model for dependency parsing
nlp = spacy.load("en_core_web_sm")

# Define stopwords
stop_words = set(stopwords.words('english'))

# Initialize WordNet Lemmatizer
lmtzr = WordNetLemmatizer()

print("Extra packages imported successfully.")
# Out:
# Extra packages imported successfully.

# %%
def preprocess_sentence(sentence):
    # Convert to lowercase and remove punctuation
    sentence = sentence.lower()
    sentence = re.sub(r'[^a-z\s]', '', sentence)

    # Tokenize and extract words with specific POS tags
    doc = nlp(sentence)
    tag_list = ['NN', 'NNS', 'VBD', 'VBG', 'VBZ', 'VB']
    selected_words = [token.text for token in doc if token.tag_ in tag_list]

    # Remove stopwords
    selected_words = [word for word in selected_words if word not in stop_words]

    # Lemmatize words
    selected_words = [lmtzr.lemmatize(word, 'v') for word in selected_words]

    return selected_words

print("Preprocessing function defined.")
# Out:
# Preprocessing function defined.

# %%
import nltk
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer

# Initialize the lemmatizer
lmtzr = WordNetLemmatizer()

# Test lemmatization
print(lmtzr.lemmatize("running", 'v'))  # Output should be "run"
def calculate_owmd(sentence_a, sentence_b):
    # Preprocess sentences
    words_a = preprocess_sentence(sentence_a)
    words_b = preprocess_sentence(sentence_b)

    # Print the list of words being passed to the model
    print(f"Sentence A: {sentence_a}")
    print(f"Selected Words A: {words_a}")
    print(f"Sentence B: {sentence_b}")
    print(f"Selected Words B: {words_b}")

    # Calculate OWMD
    if len(words_a) == 0 or len(words_b) == 0:
        print("One or both sentences have no valid words after preprocessing. Skipping...")
        return None

    owmd_distance = glove_model.wmdistance(words_a, words_b)
    print(f"Optimized Word Movers Distance: {owmd_distance:.4f}\n")
    return owmd_distance

# Calculate OWMD for all sentence pairs
results = []
for idx, (sentence_a, sentence_b) in enumerate(sentence_pairs, start=1):
    print(f"Processing Pair {idx}:")
    owmd_score = calculate_owmd(sentence_a, sentence_b)
    results.append((sentence_a, sentence_b, owmd_score))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# run
# Processing Pair 1:
# Sentence A: 1.  The cat sleeps on the couch.
# Selected Words A: ['cat', 'sleep', 'couch']
# Sentence B: A dog rests on the sofa.
# Selected Words B: ['dog', 'rest', 'sofa']
# Optimized Word Movers Distance: 0.7678
#
# Processing Pair 2:
# Sentence A: 2.  She enjoys reading books in the park.
# Selected Words A: ['enjoy', 'read', 'book', 'park']
# Sentence B: He likes to read novels outdoors.
# Selected Words B: ['like', 'read', 'novels']
# Optimized Word Movers Distance: 0.7218
#
# Processing Pair 3:
# Sentence A: 3.  The weather is sunny today.
# Selected Words A: ['weather', 'today']
# Sentence B: It's a bright and clear day.
# Selected Words B: ['day']
# Optimized Word Movers Distance: 0.8302
#
# Processing Pair 4:
# Sentence A: 4.  I love eating pizza with friends.
# Selected Words A: ['eat', 'pizza', 'friends']
# Sentence B: My favorite food is pizza.
# Selected Words B: ['food', 'pizza']
# Optimized Word Movers Distance: 0.6661
#
# Processing Pair 5:
# Sentence A: 5.  The boy plays soccer in the yard.
# Selected Words A: ['boy', 'play', 'soccer', 'yard']
# Sentence B: A child kicks a ball in the garden.
# Selected Words B: ['child', 'kick', 'ball', 'garden']
# Optimized Word Movers Distance: 0.9197
#
# Processing Pair 6:
# Sentence A: 6.  She drives a red car to work.
# Selected Words A: ['drive', 'car', 'work']
# Sentence B: Her vehicle is crimson.
# Selected Words B: ['vehicle', 'crimson']
# Optimized Word Movers Distance: 1.0028
#
# Processing Pair 7:
# Sentence A: 7.  They went hiking in the mountains.
# Selected Words A: ['go', 'hike', 'mountains']
# Sentence B: The group climbed hills for fun.
# Selected Words B: ['group', 'climb', 'hill', 'fun']
# Optimized Word Movers Distance: 0.9973
#
# Processing Pair 8:
# Sentence A: 8.  The movie was very entertaining.
# Selected Words A: ['movie']
# Sentence B: It was an enjoyable film.
# Selected Words B: ['film']
# Optimized Word Movers Distance: 0.4347
#
# Processing Pair 9:
# Sentence A: 9.  He bought a new laptop for school.
# Selected Words A: ['buy', 'laptop', 'school']
# Sentence B: His computer is brand new.
# Selected Words B: ['computer', 'brand']
# Optimized Word Movers Distance: 0.9448
#
# Processing Pair 10:
# Sentence A: 10.  The teacher explained the lesson clearly.
# Selected Words A: ['teacher', 'explain', 'lesson']
# Sentence B: The instructor made the topic easy to understand.
# Selected Words B: ['instructor', 'make', 'topic', 'understand']
# Optimized Word Movers Distance: 0.8420
#
# Processing Pair 11:
# Sentence A: 11.  The flowers bloom in spring.
# Selected Words A: ['flower', 'spring']
# Sentence B: Blossoms appear during the warmer months.
# Selected Words B: ['blossom', 'months']
# Optimized Word Movers Distance: 0.9065
#
# Processing Pair 12:
# Sentence A: 12.  We visited Paris last summer.
# Selected Words A: ['visit', 'summer']
# Sentence B: Our trip to France was amazing.
# Selected Words B: ['trip']
# Optimized Word Movers Distance: 0.7184
#
# Processing Pair 13:
# Sentence A: 13.  The baby cried all night.
# Selected Words A: ['baby', 'cry', 'night']
# Sentence B: The infant was upset throughout the evening.
# Selected Words B: ['infant', 'even']
# Optimized Word Movers Distance: 0.9048
#
# Processing Pair 14:
# Sentence A: 14.  She painted a beautiful picture.
# Selected Words A: ['paint', 'picture']
# Sentence B: Her artwork was stunning.
# Selected Words B: ['artwork']
# Optimized Word Movers Distance: 0.9748
#
# Processing Pair 15:
# Sentence A: 15.  The man wore a black suit to the wedding.
# Selected Words A: ['man', 'wear', 'suit', 'wed']
# Sentence B: He dressed formally for the event.
# Selected Words B: ['dress', 'event']
# Optimized Word Movers Distance: 0.9850
#
# Processing Pair 16:
# Sentence A: 16.  I need to buy groceries for dinner.
# Selected Words A: ['buy', 'groceries', 'dinner']
# Sentence B: Shopping for food is necessary tonight.
# Selected Words B: ['shop', 'food', 'tonight']
# Optimized Word Movers Distance: 0.9790
#
# Processing Pair 17:
# Sentence A: 17.  The train arrived late at the station.
# Selected Words A: ['train', 'arrive', 'station']
# Sentence B: The locomotive was delayed.
# Selected Words B: []
# One or both sentences have no valid words after preprocessing. Skipping...
# Processing Pair 18:
# Sentence A: 18.  She sings beautifully in the choir.
# Selected Words A: ['sing', 'choir']
# Sentence B: Her voice is lovely during performances.
# Selected Words B: ['voice', 'performances']
# Optimized Word Movers Distance: 0.9443
#
# Processing Pair 19:
# Sentence A: 19.  The restaurant serves delicious pasta.
# Selected Words A: ['restaurant', 'serve', 'pasta']
# Sentence B: Their spaghetti is fantastic.
# Selected Words B: ['spaghetti']
# Optimized Word Movers Distance: 1.0928
#
# Processing Pair 20:
# Sentence A: 20.  He fixed the broken chair with glue.
# Selected Words A: ['fix', 'chair', 'glue']
# Sentence B: The damaged seat was repaired.
# Selected Words B: ['seat']
# Optimized Word Movers Distance: 1.1591
#
# Processing Pair 21:
# Sentence A: 21.  The sun sets in the west.
# Selected Words A: ['sun', 'set', 'west']
# Sentence B: Sunset occurs over the horizon.
# Selected Words B: ['sunset', 'occur', 'horizon']
# Optimized Word Movers Distance: 1.1198
#
# Processing Pair 22:
# Sentence A: 22.  She studies biology at university.
# Selected Words A: ['study', 'biology', 'university']
# Sentence B: Her major is life sciences.
# Selected Words B: ['life', 'sciences']
# Optimized Word Movers Distance: 0.8691
#
# Processing Pair 23:
# Sentence A: 23.  The bird flew high in the sky.
# Selected Words A: ['bird', 'fly', 'sky']
# Sentence B: A feathered creature soared above.
# Selected Words B: ['creature', 'soar']
# Optimized Word Movers Distance: 1.1238
#
# Processing Pair 24:
# Sentence A: 24.  I prefer coffee over tea.
# Selected Words A: ['coffee', 'tea']
# Sentence B: Coffee is my favorite drink.
# Selected Words B: ['coffee', 'drink']
# Optimized Word Movers Distance: 0.4072
#
# Processing Pair 25:
# Sentence A: 25.  The library is quiet and peaceful.
# Selected Words A: ['library']
# Sentence B: It's a calm place to study.
# Selected Words B: ['place', 'study']
# Optimized Word Movers Distance: 1.0663
#
# Processing Pair 26:
# Sentence A: 26.  He runs every morning to stay fit.
# Selected Words A: ['run', 'morning', 'stay']
# Sentence B: Jogging keeps him healthy.
# Selected Words B: ['jog', 'keep']
# Optimized Word Movers Distance: 0.9757
#
# Processing Pair 27:
# Sentence A: 27.  The cake was sweet and delicious.
# Selected Words A: ['cake']
# Sentence B: It tasted sugary and delightful.
# Selected Words B: ['taste']
# Optimized Word Movers Distance: 0.9932
#
# Processing Pair 28:
# Sentence A: 28.  She writes poems in her free time.
# Selected Words A: ['write', 'poems', 'time']
# Sentence B: Her hobby is composing verses.
# Selected Words B: ['hobby', 'compose', 'verse']
# Optimized Word Movers Distance: 0.9439
#
# Processing Pair 29:
# Sentence A: 29.  The river flows gently through the valley.
# Selected Words A: ['river', 'flow', 'valley']
# Sentence B: Water moves smoothly across the land.
# Selected Words B: ['water', 'move', 'land']
# Optimized Word Movers Distance: 0.9696
#
# Processing Pair 30:
# Sentence A: 30.  He enjoys playing video games.
# Selected Words A: ['enjoy', 'play', 'video', 'game']
# Sentence B: Gaming is his favorite activity.
# Selected Words B: ['game', 'activity']
# Optimized Word Movers Distance: 0.7250
#
# Processing Pair 31:
# Sentence A: 31.  The house has a red roof.
# Selected Words A: ['house', 'roof']
# Sentence B: Its top is crimson-colored.
# Selected Words B: ['top']
# Optimized Word Movers Distance: 1.0603
#
# Processing Pair 32:
# Sentence A: 32.  They celebrated their anniversary with dinner.
# Selected Words A: ['celebrate', 'anniversary', 'dinner']
# Sentence B: The couple marked their special day with a meal.
# Selected Words B: ['couple', 'mark', 'day', 'meal']
# Optimized Word Movers Distance: 0.9348
#
# Processing Pair 33:
# Sentence A: 33.  The book is full of interesting stories.
# Selected Words A: ['book', 'stories']
# Sentence B: It contains many fascinating tales.
# Selected Words B: ['contain', 'tales']
# Optimized Word Movers Distance: 0.8715
#
# Processing Pair 34:
# Sentence A: 34.  She danced gracefully at the party.
# Selected Words A: ['dance', 'party']
# Sentence B: Her movements were elegant during the event.
# Selected Words B: ['movements', 'event']
# Optimized Word Movers Distance: 1.0420
#
# Processing Pair 35:
# Sentence A: 35.  The storm caused heavy rain.
# Selected Words A: ['storm', 'cause', 'rain']
# Sentence B: Bad weather led to intense precipitation.
# Selected Words B: ['weather', 'lead', 'precipitation']
# Optimized Word Movers Distance: 0.9062
#
# Processing Pair 36:
# Sentence A: 36.  He works as a software engineer.
# Selected Words A: ['work', 'software', 'engineer']
# Sentence B: His job involves coding and programming.
# Selected Words B: ['job', 'involve', 'cod', 'program']
# Optimized Word Movers Distance: 1.0736
#
# Processing Pair 37:
# Sentence A: 37.  The lamp provides bright light.
# Selected Words A: ['lamp', 'provide', 'light']
# Sentence B: It illuminates the room well.
# Selected Words B: ['illuminate', 'room']
# Optimized Word Movers Distance: 1.0544
#
# Processing Pair 38:
# Sentence A: 38.  She loves traveling to new places.
# Selected Words A: ['love', 'travel', 'place']
# Sentence B: Exploring different locations is her passion.
# Selected Words B: ['explore', 'locations', 'passion']
# Optimized Word Movers Distance: 0.9343
#
# Processing Pair 39:
# Sentence A: 39.  The dog barked loudly at the stranger.
# Selected Words A: ['dog', 'bark', 'stranger']
# Sentence B: It growled noisily at the unknown person.
# Selected Words B: ['growl', 'person']
# Optimized Word Movers Distance: 1.0563
#
# Processing Pair 40:
# Sentence A: 40.  He built a wooden table for his home.
# Selected Words A: ['build', 'table', 'home']
# Sentence B: A furniture piece was crafted by him.
# Selected Words B: ['furniture', 'piece']
# Optimized Word Movers Distance: 1.0674
#
# Processing Pair 41:
# Sentence A: 41.  The clouds drifted lazily in the sky.
# Selected Words A: ['cloud', 'drift', 'sky']
# Sentence B: They moved slowly above the ground.
# Selected Words B: ['move', 'grind']
# Optimized Word Movers Distance: 1.1758
#
# Processing Pair 42:
# Sentence A: 42.  She learned to play the guitar.
# Selected Words A: ['learn', 'play', 'guitar']
# Sentence B: Mastering the instrument was her goal.
# Selected Words B: ['master', 'instrument', 'goal']
# Optimized Word Movers Distance: 0.9396
#
# Processing Pair 43:
# Sentence A: 43.  The ocean waves crashed against the shore.
# Selected Words A: ['ocean', 'wave', 'crash', 'shore']
# Sentence B: Water hit the beach forcefully.
# Selected Words B: ['water', 'hit', 'beach']
# Optimized Word Movers Distance: 0.9631
#
# Processing Pair 44:
# Sentence A: 44.  He enjoys watching movies on weekends.
# Selected Words A: ['enjoy', 'watch', 'movies', 'weekend']
# Sentence B: Films are his favorite weekend activity.
# Selected Words B: ['film', 'weekend', 'activity']
# Optimized Word Movers Distance: 0.7145
#
# Processing Pair 45:
# Sentence A: 45.  The tree lost its leaves in autumn.
# Selected Words A: ['tree', 'lose', 'leave', 'autumn']
# Sentence B: Foliage fell from the plant during fall.
# Selected Words B: ['foliage', 'fell', 'plant', 'fall']
# Optimized Word Movers Distance: 0.9640
#
# Processing Pair 46:
# Sentence A: 46.  She baked cookies for her friends.
# Selected Words A: ['bake', 'cookies', 'friends']
# Sentence B: Homemade treats were prepared for her companions.
# Selected Words B: ['treat', 'companion']
# Optimized Word Movers Distance: 1.1832
#
# Processing Pair 47:
# Sentence A: 47.  The phone rang continuously.
# Selected Words A: ['phone', 'ring']
# Sentence B: It kept buzzing repeatedly.
# Selected Words B: ['keep', 'buzz']
# Optimized Word Movers Distance: 1.1198
#
# Processing Pair 48:
# Sentence A: 48.  He dreamed of becoming a pilot.
# Selected Words A: ['dream', 'become', 'pilot']
# Sentence B: Flying planes was his aspiration.
# Selected Words B: ['fly', 'plan', 'aspiration']
# Optimized Word Movers Distance: 1.0658
#
# Processing Pair 49:
# Sentence A: 49.  The clock ticked quietly in the room.
# Selected Words A: ['clock', 'tick', 'room']
# Sentence B: Time passed silently in the space.
# Selected Words B: ['time', 'pass', 'space']
# Optimized Word Movers Distance: 1.0530
#
# Processing Pair 50:
# Sentence A: 50.  She planted flowers in the garden.
# Selected Words A: ['plant', 'flower', 'garden']
# Sentence B: Blooms were added to the outdoor area.
# Selected Words B: ['bloom', 'area']
# Optimized Word Movers Distance: 1.0115

# %%
import pandas as pd
import numpy as np

# Original WMD and Optimized WMD values
original_wmd = [
    0.8288, 0.9093, 0.8642, 0.7091, 0.9616, 0.9414, 0.9951, 0.5238, 0.6899, 0.8994,
    0.9841, 0.9311, 0.9201, 0.9410, 0.9971, 0.8812, 1.0207, 0.8753, 1.0900, 1.0601,
    1.1504, 0.9402, 1.1475, 0.6398, 0.9013, 1.0620, 0.9559, 1.1098, 1.0171, 1.0829,
    1.0241, 0.9171, 0.7637, 1.1721, 0.9094, 1.0687, 1.0269, 0.9053, 0.9488, 1.0675,
    1.0990, 0.9791, 1.0207, 0.8794, 0.8975, 0.9980, 1.0765, 1.1079, 0.9790, 0.9977
]
optimized_wmd = [
    0.7678, 0.7218, 0.8302, 0.6661, 0.9197, 1.0028, 0.9973, 0.4347, 0.9448, 0.8420,
    0.9065, 0.7184, 0.9048, 0.9748, 0.9850, 0.9790, np.nan, 0.9443, 1.0928, 1.1591,
    1.1198, 0.8691, 1.1238, 0.4072, 1.0663, 0.9757, 0.9932, 0.9439, 0.9696, 0.7250,
    1.0603, 0.9348, 0.8715, 1.0420, 0.9062, 1.0736, 1.0544, 0.9343, 1.0563, 1.0674,
    1.1758, 0.9396, 0.9631, 0.7145, 0.9640, 1.1832, 1.1198, 1.0658, 1.0530, 1.0115
]

# Create a DataFrame for comparison
data = {
    "Pair": range(1, len(original_wmd) + 1),
    "Original WMD": original_wmd,
    "Optimized WMD": optimized_wmd,
}

df = pd.DataFrame(data)

# Add columns to indicate if OWMD is better and why
df["OWMD Better?"] = df.apply(
    lambda row: "Yes" if pd.notna(row["Optimized WMD"]) and row["Optimized WMD"] < row["Original WMD"]
    else ("No" if pd.notna(row["Optimized WMD"]) else "N/A"),
    axis=1
)

# Count how many times OWMD is better
owmd_better_count = df[df["OWMD Better?"] == "Yes"].shape[0]
wmd_better_count = df[df["OWMD Better?"] == "No"].shape[0]
not_comparable_count = df[df["OWMD Better?"] == "N/A"].shape[0]

# Display the DataFrame
print("Comparison of WMD and OWMD:")
print(df[["Pair", "Original WMD", "Optimized WMD", "OWMD Better?"]])

# Summary
print("\nSummary:")
print(f"OWMD is better than WMD in {owmd_better_count} pairs (OWMD distance is less).")
print(f"WMD is better than OWMD in {wmd_better_count} pairs (OWMD distance is greater or equal).")
print(f"Not comparable in {not_comparable_count} pair (OWMD is not computable).")

# Justification for Yes/No/N/A at the end
print("\nJustification:")
print("- 'Yes': OWMD distance is less than WMD.")
print("- 'No': OWMD distance is greater than or equal to WMD.")
print("- 'N/A': OWMD is not computable (value is NaN).")
# Out:
# Comparison of WMD and OWMD:
#     Pair  Original WMD  Optimized WMD OWMD Better?
# 0      1        0.8288         0.7678          Yes
# 1      2        0.9093         0.7218          Yes
# 2      3        0.8642         0.8302          Yes
# 3      4        0.7091         0.6661          Yes
# 4      5        0.9616         0.9197          Yes
# 5      6        0.9414         1.0028           No
# 6      7        0.9951         0.9973           No
# 7      8        0.5238         0.4347          Yes
# 8      9        0.6899         0.9448           No
# 9     10        0.8994         0.8420          Yes
# 10    11        0.9841         0.9065          Yes
# 11    12        0.9311         0.7184          Yes
# 12    13        0.9201         0.9048          Yes
# 13    14        0.9410         0.9748           No
# 14    15        0.9971         0.9850          Yes
# 15    16        0.8812         0.9790           No
# 16    17        1.0207            NaN          N/A
# 17    18        0.8753         0.9443           No
# 18    19        1.0900         1.0928           No
# 19    20        1.0601         1.1591           No
# 20    21        1.1504         1.1198          Yes
# 21    22        0.9402         0.8691          Yes
# 22    23        1.1475         1.1238          Yes
# 23    24        0.6398         0.4072          Yes
# 24    25        0.9013         1.0663           No
# 25    26        1.0620         0.9757          Yes
# 26    27        0.9559         0.9932           No
# 27    28        1.1098         0.9439          Yes
# 28    29        1.0171         0.9696          Yes
# 29    30        1.0829         0.7250          Yes
# 30    31        1.0241         1.0603           No
# 31    32        0.9171         0.9348           No
# 32    33        0.7637         0.8715           No
# 33    34        1.1721         1.0420          Yes
# 34    35        0.9094         0.9062          Yes
# 35    36        1.0687         1.0736           No
# 36    37        1.0269         1.0544           No
# 37    38        0.9053         0.9343           No
# 38    39        0.9488         1.0563           No
# 39    40        1.0675         1.0674          Yes
# 40    41        1.0990         1.1758           No
# 41    42        0.9791         0.9396          Yes
# 42    43        1.0207         0.9631          Yes
# 43    44        0.8794         0.7145          Yes
# 44    45        0.8975         0.9640           No
# 45    46        0.9980         1.1832           No
# 46    47        1.0765         1.1198           No
# 47    48        1.1079         1.0658          Yes
# 48    49        0.9790         1.0530           No
# 49    50        0.9977         1.0115           No
#
# Summary:
# OWMD is better than WMD in 26 pairs (OWMD distance is less).
# WMD is better than OWMD in 23 pairs (OWMD distance is greater or equal).
# Not comparable in 1 pair (OWMD is not computable).
#
# Justification:
# - 'Yes': OWMD distance is less than WMD.
# - 'No': OWMD distance is greater than or equal to WMD.
# - 'N/A': OWMD is not computable (value is NaN).

# %%
import matplotlib.pyplot as plt

# Original WMD and Optimized WMD values
original_wmd = [
    0.8288, 0.9093, 0.8642, 0.7091, 0.9616, 0.9414, 0.9951, 0.5238, 0.6899, 0.8994,
    0.9841, 0.9311, 0.9201, 0.9410, 0.9971, 0.8812, 1.0207, 0.8753, 1.0900, 1.0601,
    1.1504, 0.9402, 1.1475, 0.6398, 0.9013, 1.0620, 0.9559, 1.1098, 1.0171, 1.0829,
    1.0241, 0.9171, 0.7637, 1.1721, 0.9094, 1.0687, 1.0269, 0.9053, 0.9488, 1.0675,
    1.0990, 0.9791, 1.0207, 0.8794, 0.8975, 0.9980, 1.0765, 1.1079, 0.9790, 0.9977
]
optimized_wmd = [
    0.7678, 0.7218, 0.8302, 0.6661, 0.9197, 1.0028, 0.9973, 0.4347, 0.9448, 0.8420,
    0.9065, 0.7184, 0.9048, 0.9748, 0.9850, 0.9790, None, 0.9443, 1.0928, 1.1591,
    1.1198, 0.8691, 1.1238, 0.4072, 1.0663, 0.9757, 0.9932, 0.9439, 0.9696, 0.7250,
    1.0603, 0.9348, 0.8715, 1.0420, 0.9062, 1.0736, 1.0544, 0.9343, 1.0563, 1.0674,
    1.1758, 0.9396, 0.9631, 0.7145, 0.9640, 1.1832, 1.1198, 1.0658, 1.0530, 1.0115
]

# Remove None values for visualization
valid_indices = [i for i, value in enumerate(optimized_wmd) if value is not None]
original_wmd_valid = [original_wmd[i] for i in valid_indices]
optimized_wmd_valid = [optimized_wmd[i] for i in valid_indices]

# Create the plot
plt.figure(figsize=(12, 6))

# Plot WMD curve
plt.plot(range(1, len(original_wmd_valid) + 1), original_wmd_valid, label="WMD", marker='o', linestyle='-', color='blue')

# Plot OWMD curve
plt.plot(range(1, len(optimized_wmd_valid) + 1), optimized_wmd_valid, label="OWMD", marker='x', linestyle='--', color='green')

# Add labels and title
plt.title("Comparison of WMD vs OWMD", fontsize=16)
plt.xlabel("Sentence Pair", fontsize=12)
plt.ylabel("Distance", fontsize=12)

# Add legend and grid
plt.legend(fontsize=12)
plt.grid(alpha=0.3)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Word Mover Distance Algorithm in Bengali Language
# FastText helps implement Word Mover's Distance (WMD) in Bengali by providing word embeddings that capture both the meaning and structure of words, even for rare or out-of-vocabulary terms. Unlike traditional word embeddings, FastText represents words as character n-grams, which is especially useful for Bengali due to its complex morphology and word variations. This ability to generate meaningful embeddings for a wide range of words makes it an ideal choice for calculating WMD in Bengali, allowing for more accurate text comparisons based on semantic similarity.

# %%
import re
import pandas as pd

# Set the file path for the Bengali dataset
file_path = r"C:\Users\KIIT\PycharmProjects\JupyterProject\data\BengaliDataset.txt"

# Read the dataset into a DataFrame, assuming each line has Sentence A and Sentence B separated by a TAB.
df = pd.read_csv(file_path, sep="\t", header=None, names=["Sentence1", "Sentence2"], encoding="utf-8")

print("Dataset loaded successfully!")
print("Dataset preview:")
print(df.head())
# Out:
# Dataset loaded successfully!
# Dataset preview:
#                                  Sentence1  \
# 0                             আমি বই পড়ি।
# 1            সে বাজারে গিয়ে সবজি কিনেছিল।
# 2                          আজ আকাশ স্পষ্ট।
# 3  আমরা সাঁতার কাটতে জলের কাছে গিয়েছিলাম।
# 4                 সে প্রতিদিন সকালে হাঁটে।
#
#                                         Sentence2
# 0                        আমি গল্প পড়তে ভালোবাসি।
# 1                     সে সেরা সবজি সংগ্রহ করেছিল।
# 2                      আজ দিনটি একেবারে পরিষ্কার।
# 3  আমরা পুকুরের ধারে সাঁতার কাটার মজা নিয়েছিলাম।
# 4                সে দৈনিক হাঁটার অভ্যাস পোষণ করে।

# %%
def tokenize_bengali(text):
    """
    Tokenizes Bengali text by removing punctuation and splitting by whitespace.
    You can extend this function to handle more punctuation or other cleaning.
    """
    # Remove some common punctuation (adjust as necessary)
    text_clean = re.sub(r'[।,?!]', '', text)
    tokens = text_clean.lower().split()
    return tokens

# Test tokenizer on a sample sentence
sample = df.iloc[0]["Sentence1"]
print("Sample Sentence:", sample)
print("Tokenized Sample:", tokenize_bengali(sample))
# Out:
# Sample Sentence: আমি বই পড়ি।
# Tokenized Sample: ['আমি', 'বই', 'পড়ি']

# %%
from gensim.models import FastText

# Build a corpus by tokenizing both Sentence1 and Sentence2 of each pair.
corpus = []
for _, row in df.iterrows():
    corpus.append(tokenize_bengali(row["Sentence1"]))
    corpus.append(tokenize_bengali(row["Sentence2"]))

print("Total sentences in corpus:", len(corpus))
print("Example tokenized sentence from corpus:", corpus[0])

# Train a FastText model on the corpus.
fasttext_model = FastText(
    sentences=corpus,
    vector_size=50,   # Adjust vector size as needed
    window=3,
    min_count=1,      # Using min_count=1 because our dataset is small
    epochs=20
)

print("FastText model trained successfully!")
print("Vocabulary size:", len(fasttext_model.wv))
# Out:
# Total sentences in corpus: 240
# Example tokenized sentence from corpus: ['আমি', 'বই', 'পড়ি']
# FastText model trained successfully!
# Vocabulary size: 494

# %%
def select_words(sentence, model):
    """
    Tokenizes the sentence and selects words that are present in the model's vocabulary.
    """
    tokens = tokenize_bengali(sentence)
    selected = [token for token in tokens if token in model.wv]
    return selected

def compute_wmd(words_a, words_b, model):
    """
    Computes the Word Mover's Distance between two lists of words using the model.
    Returns infinity if one of the lists is empty.
    """
    if words_a and words_b:
        return model.wv.wmdistance(words_a, words_b)
    else:
        return float("inf")
print("Computing Word Mover's Distance...")
# Out:
# Computing Word Mover's Distance...

# %%
# Process each sentence pair, display selected words and the WMD score.
for idx, row in df.iterrows():
    pair_num = idx + 1
    sent_a = row["Sentence1"]
    sent_b = row["Sentence2"]

    # Select words based on model vocabulary
    selected_words_a = select_words(sent_a, fasttext_model)
    selected_words_b = select_words(sent_b, fasttext_model)

    # Compute the Word Mover's Distance
    wmd_score = compute_wmd(selected_words_a, selected_words_b, fasttext_model)

    # Print detailed information for the current pair.
    print(f"Processing Pair {pair_num}:")
    print(f"Sentence A: {sent_a}")
    print(f"Selected Words A: {selected_words_a}")
    print(f"Sentence B: {sent_b}")
    print(f"Selected Words B: {selected_words_b}")
    if wmd_score == float("inf"):
        print("Word Mover's Distance: Infinity (Insufficient valid tokens)")
    else:
        print(f"Word Mover's Distance: {wmd_score:.4f}")
    print("-" * 50)
# Out:
# Processing Pair 1:
# Sentence A: আমি বই পড়ি।
# Selected Words A: ['আমি', 'বই', 'পড়ি']
# Sentence B: আমি গল্প পড়তে ভালোবাসি।
# Selected Words B: ['আমি', 'গল্প', 'পড়তে', 'ভালোবাসি']
# Word Mover's Distance: 0.6919
# --------------------------------------------------
# Processing Pair 2:
# Sentence A: সে বাজারে গিয়ে সবজি কিনেছিল।
# Selected Words A: ['সে', 'বাজারে', 'গিয়ে', 'সবজি', 'কিনেছিল']
# Sentence B: সে সেরা সবজি সংগ্রহ করেছিল।
# Selected Words B: ['সে', 'সেরা', 'সবজি', 'সংগ্রহ', 'করেছিল']
# Word Mover's Distance: 0.4666
# --------------------------------------------------
# Processing Pair 3:
# Sentence A: আজ আকাশ স্পষ্ট।
# Selected Words A: ['আজ', 'আকাশ', 'স্পষ্ট']
# Sentence B: আজ দিনটি একেবারে পরিষ্কার।
# Selected Words B: ['আজ', 'দিনটি', 'একেবারে', 'পরিষ্কার']
# Word Mover's Distance: 0.5781
# --------------------------------------------------
# Processing Pair 4:
# Sentence A: আমরা সাঁতার কাটতে জলের কাছে গিয়েছিলাম।
# Selected Words A: ['আমরা', 'সাঁতার', 'কাটতে', 'জলের', 'কাছে', 'গিয়েছিলাম']
# Sentence B: আমরা পুকুরের ধারে সাঁতার কাটার মজা নিয়েছিলাম।
# Selected Words B: ['আমরা', 'পুকুরের', 'ধারে', 'সাঁতার', 'কাটার', 'মজা', 'নিয়েছিলাম']
# Word Mover's Distance: 0.4049
# --------------------------------------------------
# Processing Pair 5:
# Sentence A: সে প্রতিদিন সকালে হাঁটে।
# Selected Words A: ['সে', 'প্রতিদিন', 'সকালে', 'হাঁটে']
# Sentence B: সে দৈনিক হাঁটার অভ্যাস পোষণ করে।
# Selected Words B: ['সে', 'দৈনিক', 'হাঁটার', 'অভ্যাস', 'পোষণ', 'করে']
# Word Mover's Distance: 0.7144
# --------------------------------------------------
# Processing Pair 6:
# Sentence A: বৃক্ষগুলি শীতে পাতলা হয়ে যায়।
# Selected Words A: ['বৃক্ষগুলি', 'শীতে', 'পাতলা', 'হয়ে', 'যায়']
# Sentence B: শীতে গাছের পাতা ঝরে যায়।
# Selected Words B: ['শীতে', 'গাছের', 'পাতা', 'ঝরে', 'যায়']
# Word Mover's Distance: 0.4757
# --------------------------------------------------
# Processing Pair 7:
# Sentence A: সে তার চুল কাটিয়ে নতুন স্টাইল নিল।
# Selected Words A: ['সে', 'তার', 'চুল', 'কাটিয়ে', 'নতুন', 'স্টাইল', 'নিল']
# Sentence B: তার চুলের নতুন কাটা চেহারা আলাদা ছিল।
# Selected Words B: ['তার', 'চুলের', 'নতুন', 'কাটা', 'চেহারা', 'আলাদা', 'ছিল']
# Word Mover's Distance: 0.6380
# --------------------------------------------------
# Processing Pair 8:
# Sentence A: আমি চা পান করতে পছন্দ করি।
# Selected Words A: ['আমি', 'চা', 'পান', 'করতে', 'পছন্দ', 'করি']
# Sentence B: চা আমার প্রিয় পানীয়।
# Selected Words B: ['চা', 'আমার', 'প্রিয়', 'পানীয়']
# Word Mover's Distance: 0.5921
# --------------------------------------------------
# Processing Pair 9:
# Sentence A: ছেলেটি স্কুলে নতুন জুতো পরে।
# Selected Words A: ['ছেলেটি', 'স্কুলে', 'নতুন', 'জুতো', 'পরে']
# Sentence B: স্কুলে তার নতুন জুতোর প্রশংসা হয়।
# Selected Words B: ['স্কুলে', 'তার', 'নতুন', 'জুতোর', 'প্রশংসা', 'হয়']
# Word Mover's Distance: 0.5353
# --------------------------------------------------
# Processing Pair 10:
# Sentence A: সে তার বাড়ির সামনে ফুল বাগান তৈরি করেছে।
# Selected Words A: ['সে', 'তার', 'বাড়ির', 'সামনে', 'ফুল', 'বাগান', 'তৈরি', 'করেছে']
# Sentence B: তার বাড়ির পাশে একটি সুন্দর ফুলের বাগান আছে।
# Selected Words B: ['তার', 'বাড়ির', 'পাশে', 'একটি', 'সুন্দর', 'ফুলের', 'বাগান', 'আছে']
# Word Mover's Distance: 0.4970
# --------------------------------------------------
# Processing Pair 11:
# Sentence A: আমি গান শুনতে ভালোবাসি।
# Selected Words A: ['আমি', 'গান', 'শুনতে', 'ভালোবাসি']
# Sentence B: সঙ্গীত আমার মনকে প্রশান্ত করে।
# Selected Words B: ['সঙ্গীত', 'আমার', 'মনকে', 'প্রশান্ত', 'করে']
# Word Mover's Distance: 0.6216
# --------------------------------------------------
# Processing Pair 12:
# Sentence A: সে রাস্তায় সাবধানতার সাথে চলে।
# Selected Words A: ['সে', 'রাস্তায়', 'সাবধানতার', 'সাথে', 'চলে']
# Sentence B: সে পথ চলতে সতর্ক।
# Selected Words B: ['সে', 'পথ', 'চলতে', 'সতর্ক']
# Word Mover's Distance: 0.9141
# --------------------------------------------------
# Processing Pair 13:
# Sentence A: আমাদের দলের খেলাটি জয়ী হয়েছিল।
# Selected Words A: ['আমাদের', 'দলের', 'খেলাটি', 'জয়ী', 'হয়েছিল']
# Sentence B: আমরা খেলার মাধ্যমে বিজয় অর্জন করেছিলাম।
# Selected Words B: ['আমরা', 'খেলার', 'মাধ্যমে', 'বিজয়', 'অর্জন', 'করেছিলাম']
# Word Mover's Distance: 0.6205
# --------------------------------------------------
# Processing Pair 14:
# Sentence A: সে পেন্সিলে চিত্র আঁকে।
# Selected Words A: ['সে', 'পেন্সিলে', 'চিত্র', 'আঁকে']
# Sentence B: তার অঙ্কন কাজটি খুবই মনোরম।
# Selected Words B: ['তার', 'অঙ্কন', 'কাজটি', 'খুবই', 'মনোরম']
# Word Mover's Distance: 0.9442
# --------------------------------------------------
# Processing Pair 15:
# Sentence A: রাস্তায় হালকা বৃষ্টি হচ্ছে।
# Selected Words A: ['রাস্তায়', 'হালকা', 'বৃষ্টি', 'হচ্ছে']
# Sentence B: মেঘলা আকাশে বৃষ্টি ফোটে।
# Selected Words B: ['মেঘলা', 'আকাশে', 'বৃষ্টি', 'ফোটে']
# Word Mover's Distance: 0.7834
# --------------------------------------------------
# Processing Pair 16:
# Sentence A: সে নিজের বাড়ি সাজিয়েছে।
# Selected Words A: ['সে', 'নিজের', 'বাড়ি', 'সাজিয়েছে']
# Sentence B: তার বাসা নতুন রঙে রাঙানো।
# Selected Words B: ['তার', 'বাসা', 'নতুন', 'রঙে', 'রাঙানো']
# Word Mover's Distance: 0.8938
# --------------------------------------------------
# Processing Pair 17:
# Sentence A: আমি সিনেমা দেখতে গিয়েছিলাম।
# Selected Words A: ['আমি', 'সিনেমা', 'দেখতে', 'গিয়েছিলাম']
# Sentence B: চলচ্চিত্র দেখার অভিজ্ঞতা অসাধারণ ছিল।
# Selected Words B: ['চলচ্চিত্র', 'দেখার', 'অভিজ্ঞতা', 'অসাধারণ', 'ছিল']
# Word Mover's Distance: 0.7652
# --------------------------------------------------
# Processing Pair 18:
# Sentence A: সে দুপুরে খাবার করে।
# Selected Words A: ['সে', 'দুপুরে', 'খাবার', 'করে']
# Sentence B: দুপুরের আহার তার শক্তির উৎস।
# Selected Words B: ['দুপুরের', 'আহার', 'তার', 'শক্তির', 'উৎস']
# Word Mover's Distance: 0.6331
# --------------------------------------------------
# Processing Pair 19:
# Sentence A: আজ আমার মন ভালো।
# Selected Words A: ['আজ', 'আমার', 'মন', 'ভালো']
# Sentence B: আজ আমার মেজাজ একদম সুন্দর।
# Selected Words B: ['আজ', 'আমার', 'মেজাজ', 'একদম', 'সুন্দর']
# Word Mover's Distance: 0.5512
# --------------------------------------------------
# Processing Pair 20:
# Sentence A: সে নতুন বই কিনেছে।
# Selected Words A: ['সে', 'নতুন', 'বই', 'কিনেছে']
# Sentence B: তার পাঠ্যবই সমৃদ্ধ।
# Selected Words B: ['তার', 'পাঠ্যবই', 'সমৃদ্ধ']
# Word Mover's Distance: 0.7667
# --------------------------------------------------
# Processing Pair 21:
# Sentence A: আমরা পার্কে খেলাধুলা করি।
# Selected Words A: ['আমরা', 'পার্কে', 'খেলাধুলা', 'করি']
# Sentence B: পার্কে আমরা বিনোদনের সময় কাটাই।
# Selected Words B: ['পার্কে', 'আমরা', 'বিনোদনের', 'সময়', 'কাটাই']
# Word Mover's Distance: 0.4681
# --------------------------------------------------
# Processing Pair 22:
# Sentence A: সে তার বন্ধুদের সাথে সময় কাটায়।
# Selected Words A: ['সে', 'তার', 'বন্ধুদের', 'সাথে', 'সময়', 'কাটায়']
# Sentence B: তার সঙ্গীরা তার প্রিয়।
# Selected Words B: ['তার', 'সঙ্গীরা', 'তার', 'প্রিয়']
# Word Mover's Distance: 0.4913
# --------------------------------------------------
# Processing Pair 23:
# Sentence A: আমি সঙ্গীত বাজাই।
# Selected Words A: ['আমি', 'সঙ্গীত', 'বাজাই']
# Sentence B: সঙ্গীত আমার আবেগ প্রকাশ করে।
# Selected Words B: ['সঙ্গীত', 'আমার', 'আবেগ', 'প্রকাশ', 'করে']
# Word Mover's Distance: 0.6316
# --------------------------------------------------
# Processing Pair 24:
# Sentence A: সে নতুন ফোন কিনেছে।
# Selected Words A: ['সে', 'নতুন', 'ফোন', 'কিনেছে']
# Sentence B: তার মোবাইলটি একেবারে ঝকঝকে।
# Selected Words B: ['তার', 'মোবাইলটি', 'একেবারে', 'ঝকঝকে']
# Word Mover's Distance: 0.7018
# --------------------------------------------------
# Processing Pair 25:
# Sentence A: আমরা সকালে সূর্যোদয় দেখেছিলাম।
# Selected Words A: ['আমরা', 'সকালে', 'সূর্যোদয়', 'দেখেছিলাম']
# Sentence B: সকালে সূর্যের প্রথম আলো আমাদের অভিভূত করেছিল।
# Selected Words B: ['সকালে', 'সূর্যের', 'প্রথম', 'আলো', 'আমাদের', 'অভিভূত', 'করেছিল']
# Word Mover's Distance: 0.5049
# --------------------------------------------------
# Processing Pair 26:
# Sentence A: সে শহরে ভ্রমণ করে।
# Selected Words A: ['সে', 'শহরে', 'ভ্রমণ', 'করে']
# Sentence B: শহরের সৌন্দর্য তার দৃষ্টি আকর্ষণ করে।
# Selected Words B: ['শহরের', 'সৌন্দর্য', 'তার', 'দৃষ্টি', 'আকর্ষণ', 'করে']
# Word Mover's Distance: 0.5947
# --------------------------------------------------
# Processing Pair 27:
# Sentence A: আমি আর্ট গ্যালারিতে গিয়েছিলাম।
# Selected Words A: ['আমি', 'আর্ট', 'গ্যালারিতে', 'গিয়েছিলাম']
# Sentence B: শিল্প প্রদর্শনী আমার মনের প্রশান্তি দেয়।
# Selected Words B: ['শিল্প', 'প্রদর্শনী', 'আমার', 'মনের', 'প্রশান্তি', 'দেয়']
# Word Mover's Distance: 0.6451
# --------------------------------------------------
# Processing Pair 28:
# Sentence A: সে সাঁতার কাটা শিখেছে।
# Selected Words A: ['সে', 'সাঁতার', 'কাটা', 'শিখেছে']
# Sentence B: তার সাঁতার কাটার দক্ষতা বৃদ্ধি পেয়েছে।
# Selected Words B: ['তার', 'সাঁতার', 'কাটার', 'দক্ষতা', 'বৃদ্ধি', 'পেয়েছে']
# Word Mover's Distance: 0.4766
# --------------------------------------------------
# Processing Pair 29:
# Sentence A: আজকে ঠাণ্ডা বৃষ্টি হচ্ছে।
# Selected Words A: ['আজকে', 'ঠাণ্ডা', 'বৃষ্টি', 'হচ্ছে']
# Sentence B: আবহাওয়া একদম শীতল।
# Selected Words B: ['আবহাওয়া', 'একদম', 'শীতল']
# Word Mover's Distance: 0.9244
# --------------------------------------------------
# Processing Pair 30:
# Sentence A: সে হাসতে ভালোবাসে।
# Selected Words A: ['সে', 'হাসতে', 'ভালোবাসে']
# Sentence B: তার হাসি সবাইকে আনন্দ দেয়।
# Selected Words B: ['তার', 'হাসি', 'সবাইকে', 'আনন্দ', 'দেয়']
# Word Mover's Distance: 0.7085
# --------------------------------------------------
# Processing Pair 31:
# Sentence A: আমি প্রতিদিন লেখা অনুশীলন করি।
# Selected Words A: ['আমি', 'প্রতিদিন', 'লেখা', 'অনুশীলন', 'করি']
# Sentence B: লেখা আমার সৃজনশীলতার প্রকাশ।
# Selected Words B: ['লেখা', 'আমার', 'সৃজনশীলতার', 'প্রকাশ']
# Word Mover's Distance: 0.4695
# --------------------------------------------------
# Processing Pair 32:
# Sentence A: সে রান্না করতে ভালোবাসে।
# Selected Words A: ['সে', 'রান্না', 'করতে', 'ভালোবাসে']
# Sentence B: তার রান্নার স্বাদ অসাধারণ।
# Selected Words B: ['তার', 'রান্নার', 'স্বাদ', 'অসাধারণ']
# Word Mover's Distance: 0.5936
# --------------------------------------------------
# Processing Pair 33:
# Sentence A: আমরা বইমেলায় গিয়েছিলাম।
# Selected Words A: ['আমরা', 'বইমেলায়', 'গিয়েছিলাম']
# Sentence B: বইমেলায় নতুন বই আবিষ্কার করেছি।
# Selected Words B: ['বইমেলায়', 'নতুন', 'বই', 'আবিষ্কার', 'করেছি']
# Word Mover's Distance: 0.5128
# --------------------------------------------------
# Processing Pair 34:
# Sentence A: সে মাঠে ফুটবল খেলেছে।
# Selected Words A: ['সে', 'মাঠে', 'ফুটবল', 'খেলেছে']
# Sentence B: তার ফুটবল খেলার চপলতা মুগ্ধকর।
# Selected Words B: ['তার', 'ফুটবল', 'খেলার', 'চপলতা', 'মুগ্ধকর']
# Word Mover's Distance: 0.5813
# --------------------------------------------------
# Processing Pair 35:
# Sentence A: আমি নিজের মতো করে চিন্তা করি।
# Selected Words A: ['আমি', 'নিজের', 'মতো', 'করে', 'চিন্তা', 'করি']
# Sentence B: আমার দৃষ্টিভঙ্গি ভিন্ন।
# Selected Words B: ['আমার', 'দৃষ্টিভঙ্গি', 'ভিন্ন']
# Word Mover's Distance: 0.7103
# --------------------------------------------------
# Processing Pair 36:
# Sentence A: সে সঙ্গীতের ক্লাসে যায়।
# Selected Words A: ['সে', 'সঙ্গীতের', 'ক্লাসে', 'যায়']
# Sentence B: তার সুরেলা কণ্ঠস্বর ক্লাসে প্রশংসিত।
# Selected Words B: ['তার', 'সুরেলা', 'কণ্ঠস্বর', 'ক্লাসে', 'প্রশংসিত']
# Word Mover's Distance: 0.4402
# --------------------------------------------------
# Processing Pair 37:
# Sentence A: আজকের রাতটি শান্ত।
# Selected Words A: ['আজকের', 'রাতটি', 'শান্ত']
# Sentence B: রাত্রি একেবারে নিরিবিলি।
# Selected Words B: ['রাত্রি', 'একেবারে', 'নিরিবিলি']
# Word Mover's Distance: 0.7389
# --------------------------------------------------
# Processing Pair 38:
# Sentence A: সে পাখিদের কথা শুনে।
# Selected Words A: ['সে', 'পাখিদের', 'কথা', 'শুনে']
# Sentence B: তার পরিবেশের প্রতি গভীর আকর্ষণ আছে।
# Selected Words B: ['তার', 'পরিবেশের', 'প্রতি', 'গভীর', 'আকর্ষণ', 'আছে']
# Word Mover's Distance: 0.8491
# --------------------------------------------------
# Processing Pair 39:
# Sentence A: আমি ছবি আঁকতে ভালোবাসি।
# Selected Words A: ['আমি', 'ছবি', 'আঁকতে', 'ভালোবাসি']
# Sentence B: আমার আঁকা ছবি মনোমুগ্ধকর।
# Selected Words B: ['আমার', 'আঁকা', 'ছবি', 'মনোমুগ্ধকর']
# Word Mover's Distance: 0.5352
# --------------------------------------------------
# Processing Pair 40:
# Sentence A: সে প্রতিদিন ব্যায়াম করে।
# Selected Words A: ['সে', 'প্রতিদিন', 'ব্যায়াম', 'করে']
# Sentence B: তার শরীরচর্চা নিয়মিত।
# Selected Words B: ['তার', 'শরীরচর্চা', 'নিয়মিত']
# Word Mover's Distance: 0.6967
# --------------------------------------------------
# Processing Pair 41:
# Sentence A: আমরা বাগানে ঘুমাই।
# Selected Words A: ['আমরা', 'বাগানে', 'ঘুমাই']
# Sentence B: প্রকৃতির মাঝে বিশ্রাম পাই।
# Selected Words B: ['প্রকৃতির', 'মাঝে', 'বিশ্রাম', 'পাই']
# Word Mover's Distance: 0.9325
# --------------------------------------------------
# Processing Pair 42:
# Sentence A: সে নতুন গান রচনা করেছে।
# Selected Words A: ['সে', 'নতুন', 'গান', 'রচনা', 'করেছে']
# Sentence B: তার সুরেলা সঙ্গীত সবাইকে স্পর্শ করেছে।
# Selected Words B: ['তার', 'সুরেলা', 'সঙ্গীত', 'সবাইকে', 'স্পর্শ', 'করেছে']
# Word Mover's Distance: 0.6413
# --------------------------------------------------
# Processing Pair 43:
# Sentence A: আমি কবিতা লিখি।
# Selected Words A: ['আমি', 'কবিতা', 'লিখি']
# Sentence B: কবিতা আমার হৃদয়ের ভাষা।
# Selected Words B: ['কবিতা', 'আমার', 'হৃদয়ের', 'ভাষা']
# Word Mover's Distance: 0.6530
# --------------------------------------------------
# Processing Pair 44:
# Sentence A: সে দোকানে নতুন জামাকাপড় কিনেছে।
# Selected Words A: ['সে', 'দোকানে', 'নতুন', 'জামাকাপড়', 'কিনেছে']
# Sentence B: তার পোশাক সংগ্রহে নতুনত্ব আছে।
# Selected Words B: ['তার', 'পোশাক', 'সংগ্রহে', 'নতুনত্ব', 'আছে']
# Word Mover's Distance: 0.8055
# --------------------------------------------------
# Processing Pair 45:
# Sentence A: আজ বৃষ্টি ঝরে পড়ছে।
# Selected Words A: ['আজ', 'বৃষ্টি', 'ঝরে', 'পড়ছে']
# Sentence B: আবহাওয়া একদম রোমান্টিক।
# Selected Words B: ['আবহাওয়া', 'একদম', 'রোমান্টিক']
# Word Mover's Distance: 0.9076
# --------------------------------------------------
# Processing Pair 46:
# Sentence A: সে কলেজে ভাল মেধাবী।
# Selected Words A: ['সে', 'কলেজে', 'ভাল', 'মেধাবী']
# Sentence B: তার পড়াশোনায় উৎকর্ষতা রয়েছে।
# Selected Words B: ['তার', 'পড়াশোনায়', 'উৎকর্ষতা', 'রয়েছে']
# Word Mover's Distance: 0.8584
# --------------------------------------------------
# Processing Pair 47:
# Sentence A: আমি বাগানে কাজ করি।
# Selected Words A: ['আমি', 'বাগানে', 'কাজ', 'করি']
# Sentence B: প্রকৃতির মাঝে আমার শান্তি।
# Selected Words B: ['প্রকৃতির', 'মাঝে', 'আমার', 'শান্তি']
# Word Mover's Distance: 0.6149
# --------------------------------------------------
# Processing Pair 48:
# Sentence A: সে বাজারে নতুন ফল কিনেছে।
# Selected Words A: ['সে', 'বাজারে', 'নতুন', 'ফল', 'কিনেছে']
# Sentence B: তার তাজা ফলের ভান্ডার সমৃদ্ধ।
# Selected Words B: ['তার', 'তাজা', 'ফলের', 'ভান্ডার', 'সমৃদ্ধ']
# Word Mover's Distance: 0.5913
# --------------------------------------------------
# Processing Pair 49:
# Sentence A: আমরা বন্ধুদের সাথে সিনেমা দেখলাম।
# Selected Words A: ['আমরা', 'বন্ধুদের', 'সাথে', 'সিনেমা', 'দেখলাম']
# Sentence B: সিনেমা আমাদের মিলনের মুহূর্ত।
# Selected Words B: ['সিনেমা', 'আমাদের', 'মিলনের', 'মুহূর্ত']
# Word Mover's Distance: 0.4962
# --------------------------------------------------
# Processing Pair 50:
# Sentence A: সে প্রতিদিন সকালে মেডিটেশন করে।
# Selected Words A: ['সে', 'প্রতিদিন', 'সকালে', 'মেডিটেশন', 'করে']
# Sentence B: তার মনের শান্তি নিশ্চিত হয়।
# Selected Words B: ['তার', 'মনের', 'শান্তি', 'নিশ্চিত', 'হয়']
# Word Mover's Distance: 0.6184
# --------------------------------------------------
# Processing Pair 51:
# Sentence A: আমি হস্তশিল্প করি।
# Selected Words A: ['আমি', 'হস্তশিল্প', 'করি']
# Sentence B: হস্তশিল্প আমার সৃজনশীল প্রকাশ।
# Selected Words B: ['হস্তশিল্প', 'আমার', 'সৃজনশীল', 'প্রকাশ']
# Word Mover's Distance: 0.4420
# --------------------------------------------------
# Processing Pair 52:
# Sentence A: সে তার আর্ট প্রোজেক্ট সম্পন্ন করেছে।
# Selected Words A: ['সে', 'তার', 'আর্ট', 'প্রোজেক্ট', 'সম্পন্ন', 'করেছে']
# Sentence B: তার চিত্রকর্ম প্রশংসিত হয়েছে।
# Selected Words B: ['তার', 'চিত্রকর্ম', 'প্রশংসিত', 'হয়েছে']
# Word Mover's Distance: 0.4832
# --------------------------------------------------
# Processing Pair 53:
# Sentence A: আজকের দিনটি উজ্জ্বল।
# Selected Words A: ['আজকের', 'দিনটি', 'উজ্জ্বল']
# Sentence B: আলো দিনের ছোঁয়া মুগ্ধকর।
# Selected Words B: ['আলো', 'দিনের', 'ছোঁয়া', 'মুগ্ধকর']
# Word Mover's Distance: 0.5555
# --------------------------------------------------
# Processing Pair 54:
# Sentence A: সে প্রাকৃতিক সঙ্গীত উপভোগ করে।
# Selected Words A: ['সে', 'প্রাকৃতিক', 'সঙ্গীত', 'উপভোগ', 'করে']
# Sentence B: প্রকৃতির শব্দ তার মনের প্রশান্তি দেয়।
# Selected Words B: ['প্রকৃতির', 'শব্দ', 'তার', 'মনের', 'প্রশান্তি', 'দেয়']
# Word Mover's Distance: 0.6134
# --------------------------------------------------
# Processing Pair 55:
# Sentence A: আমি ভ্রমণ পছন্দ করি।
# Selected Words A: ['আমি', 'ভ্রমণ', 'পছন্দ', 'করি']
# Sentence B: নতুন জায়গা অন্বেষণ আমার রুচির।
# Selected Words B: ['নতুন', 'জায়গা', 'অন্বেষণ', 'আমার', 'রুচির']
# Word Mover's Distance: 0.8782
# --------------------------------------------------
# Processing Pair 56:
# Sentence A: সে তার ডায়েরি লিখে।
# Selected Words A: ['সে', 'তার', 'ডায়েরি', 'লিখে']
# Sentence B: তার প্রতিদিনের অভিজ্ঞতা বইতে রূপান্তরিত।
# Selected Words B: ['তার', 'প্রতিদিনের', 'অভিজ্ঞতা', 'বইতে', 'রূপান্তরিত']
# Word Mover's Distance: 0.6391
# --------------------------------------------------
# Processing Pair 57:
# Sentence A: আজকের সকালের বাতাস সতেজ।
# Selected Words A: ['আজকের', 'সকালের', 'বাতাস', 'সতেজ']
# Sentence B: সকালে হাওয়া প্রাণবন্ত।
# Selected Words B: ['সকালে', 'হাওয়া', 'প্রাণবন্ত']
# Word Mover's Distance: 0.7045
# --------------------------------------------------
# Processing Pair 58:
# Sentence A: সে তার নতুন ব্লগ শুরু করেছে।
# Selected Words A: ['সে', 'তার', 'নতুন', 'ব্লগ', 'শুরু', 'করেছে']
# Sentence B: তার লেখাগুলি অনন্য অভিজ্ঞতা প্রকাশ করে।
# Selected Words B: ['তার', 'লেখাগুলি', 'অনন্য', 'অভিজ্ঞতা', 'প্রকাশ', 'করে']
# Word Mover's Distance: 0.6587
# --------------------------------------------------
# Processing Pair 59:
# Sentence A: আমি সাপ্তাহিক বাজারে যাই।
# Selected Words A: ['আমি', 'সাপ্তাহিক', 'বাজারে', 'যাই']
# Sentence B: বাজারের রঙিনতা আমাকে মুগ্ধ করে।
# Selected Words B: ['বাজারের', 'রঙিনতা', 'আমাকে', 'মুগ্ধ', 'করে']
# Word Mover's Distance: 0.7170
# --------------------------------------------------
# Processing Pair 60:
# Sentence A: সে তার প্রিয় গান গায়।
# Selected Words A: ['সে', 'তার', 'প্রিয়', 'গান', 'গায়']
# Sentence B: তার সুরেলা কণ্ঠস্বর সবাইকে আকৃষ্ট করে।
# Selected Words B: ['তার', 'সুরেলা', 'কণ্ঠস্বর', 'সবাইকে', 'আকৃষ্ট', 'করে']
# Word Mover's Distance: 0.4966
# --------------------------------------------------
# Processing Pair 61:
# Sentence A: আজকের মিটিং সফল হয়েছে।
# Selected Words A: ['আজকের', 'মিটিং', 'সফল', 'হয়েছে']
# Sentence B: আলোচনায় সবাই সম্মত হয়েছে।
# Selected Words B: ['আলোচনায়', 'সবাই', 'সম্মত', 'হয়েছে']
# Word Mover's Distance: 0.6531
# --------------------------------------------------
# Processing Pair 62:
# Sentence A: সে নতুন বন্ধু বানিয়েছে।
# Selected Words A: ['সে', 'নতুন', 'বন্ধু', 'বানিয়েছে']
# Sentence B: তার সামাজিকতা চমৎকার।
# Selected Words B: ['তার', 'সামাজিকতা', 'চমৎকার']
# Word Mover's Distance: 0.6465
# --------------------------------------------------
# Processing Pair 63:
# Sentence A: আমি প্রাকৃতিক দৃশ্যের ছবি তুলি।
# Selected Words A: ['আমি', 'প্রাকৃতিক', 'দৃশ্যের', 'ছবি', 'তুলি']
# Sentence B: ফটোগ্রাফি আমার শখ।
# Selected Words B: ['ফটোগ্রাফি', 'আমার', 'শখ']
# Word Mover's Distance: 0.9090
# --------------------------------------------------
# Processing Pair 64:
# Sentence A: সে তার প্রোজেক্টে পরিশ্রম করেছে।
# Selected Words A: ['সে', 'তার', 'প্রোজেক্টে', 'পরিশ্রম', 'করেছে']
# Sentence B: তার কাজের ফলাফল সন্তোষজনক।
# Selected Words B: ['তার', 'কাজের', 'ফলাফল', 'সন্তোষজনক']
# Word Mover's Distance: 0.6159
# --------------------------------------------------
# Processing Pair 65:
# Sentence A: আজকের খাওয়াদাওয়া সুস্বাদু।
# Selected Words A: ['আজকের', 'খাওয়াদাওয়া', 'সুস্বাদু']
# Sentence B: ভোজনের স্বাদ একেবারে মনোমুগ্ধকর।
# Selected Words B: ['ভোজনের', 'স্বাদ', 'একেবারে', 'মনোমুগ্ধকর']
# Word Mover's Distance: 0.6200
# --------------------------------------------------
# Processing Pair 66:
# Sentence A: সে তার কর্মক্ষেত্রে সফল হয়েছে।
# Selected Words A: ['সে', 'তার', 'কর্মক্ষেত্রে', 'সফল', 'হয়েছে']
# Sentence B: তার প্রফেশনাল জীবন উজ্জ্বল।
# Selected Words B: ['তার', 'প্রফেশনাল', 'জীবন', 'উজ্জ্বল']
# Word Mover's Distance: 0.6075
# --------------------------------------------------
# Processing Pair 67:
# Sentence A: আমি প্রতিদিন সাঁতার কাটি।
# Selected Words A: ['আমি', 'প্রতিদিন', 'সাঁতার', 'কাটি']
# Sentence B: সাঁতার আমার শরীরকে সুস্থ রাখে।
# Selected Words B: ['সাঁতার', 'আমার', 'শরীরকে', 'সুস্থ', 'রাখে']
# Word Mover's Distance: 0.6166
# --------------------------------------------------
# Processing Pair 68:
# Sentence A: সে তার বাড়ির ছাদে বসে গল্প করে।
# Selected Words A: ['সে', 'তার', 'বাড়ির', 'ছাদে', 'বসে', 'গল্প', 'করে']
# Sentence B: তার রাত্রির আলাপ সবাইকে মুগ্ধ করে।
# Selected Words B: ['তার', 'রাত্রির', 'আলাপ', 'সবাইকে', 'মুগ্ধ', 'করে']
# Word Mover's Distance: 0.6229
# --------------------------------------------------
# Processing Pair 69:
# Sentence A: আজকের পাঠ্যসূচি অত্যন্ত তথ্যবহুল।
# Selected Words A: ['আজকের', 'পাঠ্যসূচি', 'অত্যন্ত', 'তথ্যবহুল']
# Sentence B: শিক্ষা আজকের আলোচনার কেন্দ্রবিন্দু।
# Selected Words B: ['শিক্ষা', 'আজকের', 'আলোচনার', 'কেন্দ্রবিন্দু']
# Word Mover's Distance: 0.6737
# --------------------------------------------------
# Processing Pair 70:
# Sentence A: সে তার প্রতিদিনের অভ্যাস রেকর্ড করে।
# Selected Words A: ['সে', 'তার', 'প্রতিদিনের', 'অভ্যাস', 'রেকর্ড', 'করে']
# Sentence B: তার ডায়েরিতে প্রতিটি দিন সংরক্ষিত।
# Selected Words B: ['তার', 'ডায়েরিতে', 'প্রতিটি', 'দিন', 'সংরক্ষিত']
# Word Mover's Distance: 0.5793
# --------------------------------------------------
# Processing Pair 71:
# Sentence A: আমি আমার প্রিয় সঙ্গীত শুনি।
# Selected Words A: ['আমি', 'আমার', 'প্রিয়', 'সঙ্গীত', 'শুনি']
# Sentence B: সঙ্গীত আমার জীবনের সুর।
# Selected Words B: ['সঙ্গীত', 'আমার', 'জীবনের', 'সুর']
# Word Mover's Distance: 0.4029
# --------------------------------------------------
# Processing Pair 72:
# Sentence A: সে তার মোবাইল ফোন আপডেট করেছে।
# Selected Words A: ['সে', 'তার', 'মোবাইল', 'ফোন', 'আপডেট', 'করেছে']
# Sentence B: তার টেকনোলজি ভালোভাবে পরিচালিত।
# Selected Words B: ['তার', 'টেকনোলজি', 'ভালোভাবে', 'পরিচালিত']
# Word Mover's Distance: 0.7613
# --------------------------------------------------
# Processing Pair 73:
# Sentence A: আজকের সন্ধ্যা একেবারে মনোমুগ্ধকর।
# Selected Words A: ['আজকের', 'সন্ধ্যা', 'একেবারে', 'মনোমুগ্ধকর']
# Sentence B: সন্ধ্যার আলো আমাকে মুগ্ধ করে।
# Selected Words B: ['সন্ধ্যার', 'আলো', 'আমাকে', 'মুগ্ধ', 'করে']
# Word Mover's Distance: 0.5665
# --------------------------------------------------
# Processing Pair 74:
# Sentence A: সে তার প্রোগ্রামিং কোড লিখেছে।
# Selected Words A: ['সে', 'তার', 'প্রোগ্রামিং', 'কোড', 'লিখেছে']
# Sentence B: তার সফটওয়্যার দক্ষতা অসাধারণ।
# Selected Words B: ['তার', 'সফটওয়্যার', 'দক্ষতা', 'অসাধারণ']
# Word Mover's Distance: 0.6523
# --------------------------------------------------
# Processing Pair 75:
# Sentence A: আমি নতুন রেসিপি চেষ্টা করি।
# Selected Words A: ['আমি', 'নতুন', 'রেসিপি', 'চেষ্টা', 'করি']
# Sentence B: রান্নাঘরে নতুনত্ব আমার সৃজনশীলতা।
# Selected Words B: ['রান্নাঘরে', 'নতুনত্ব', 'আমার', 'সৃজনশীলতা']
# Word Mover's Distance: 0.7828
# --------------------------------------------------
# Processing Pair 76:
# Sentence A: সে তার গাড়ি পরিষ্কার করেছে।
# Selected Words A: ['সে', 'তার', 'গাড়ি', 'পরিষ্কার', 'করেছে']
# Sentence B: তার যানবাহন ঝকঝকে করে তুলেছে।
# Selected Words B: ['তার', 'যানবাহন', 'ঝকঝকে', 'করে', 'তুলেছে']
# Word Mover's Distance: 0.5843
# --------------------------------------------------
# Processing Pair 77:
# Sentence A: আজকের আবহাওয়া চমৎকার।
# Selected Words A: ['আজকের', 'আবহাওয়া', 'চমৎকার']
# Sentence B: আকাশে রৌদ্রের উজ্জ্বলতা স্পষ্ট।
# Selected Words B: ['আকাশে', 'রৌদ্রের', 'উজ্জ্বলতা', 'স্পষ্ট']
# Word Mover's Distance: 0.6772
# --------------------------------------------------
# Processing Pair 78:
# Sentence A: সে তার প্রতিযোগিতায় জয়ী হয়েছে।
# Selected Words A: ['সে', 'তার', 'প্রতিযোগিতায়', 'জয়ী', 'হয়েছে']
# Sentence B: তার কঠোর পরিশ্রম ফলপ্রসূ হয়েছে।
# Selected Words B: ['তার', 'কঠোর', 'পরিশ্রম', 'ফলপ্রসূ', 'হয়েছে']
# Word Mover's Distance: 0.5402
# --------------------------------------------------
# Processing Pair 79:
# Sentence A: আমি বইয়ের দোকানে ভ্রমণ করি।
# Selected Words A: ['আমি', 'বইয়ের', 'দোকানে', 'ভ্রমণ', 'করি']
# Sentence B: নতুন বই আমার আনন্দের উৎস।
# Selected Words B: ['নতুন', 'বই', 'আমার', 'আনন্দের', 'উৎস']
# Word Mover's Distance: 0.7156
# --------------------------------------------------
# Processing Pair 80:
# Sentence A: সে তার পরীক্ষায় উচ্চতম নম্বর অর্জন করেছে।
# Selected Words A: ['সে', 'তার', 'পরীক্ষায়', 'উচ্চতম', 'নম্বর', 'অর্জন', 'করেছে']
# Sentence B: তার অধ্যবসায় সফলতার চাবিকাঠি।
# Selected Words B: ['তার', 'অধ্যবসায়', 'সফলতার', 'চাবিকাঠি']
# Word Mover's Distance: 0.5988
# --------------------------------------------------
# Processing Pair 81:
# Sentence A: আজকের রাত্রি নিরিবিলি।
# Selected Words A: ['আজকের', 'রাত্রি', 'নিরিবিলি']
# Sentence B: চাঁদের আলো শান্তির বার্তা দেয়।
# Selected Words B: ['চাঁদের', 'আলো', 'শান্তির', 'বার্তা', 'দেয়']
# Word Mover's Distance: 0.6448
# --------------------------------------------------
# Processing Pair 82:
# Sentence A: সে তার প্রজেক্টের উপস্থাপনা দিয়েছে।
# Selected Words A: ['সে', 'তার', 'প্রজেক্টের', 'উপস্থাপনা', 'দিয়েছে']
# Sentence B: তার বক্তব্য সবাইকে অনুপ্রাণিত করেছে।
# Selected Words B: ['তার', 'বক্তব্য', 'সবাইকে', 'অনুপ্রাণিত', 'করেছে']
# Word Mover's Distance: 0.4688
# --------------------------------------------------
# Processing Pair 83:
# Sentence A: আমি পার্কে দৌড়াদৌড়ি করি।
# Selected Words A: ['আমি', 'পার্কে', 'দৌড়াদৌড়ি', 'করি']
# Sentence B: ব্যায়াম আমার স্বাস্থ্য রক্ষায় সহায়ক।
# Selected Words B: ['ব্যায়াম', 'আমার', 'স্বাস্থ্য', 'রক্ষায়', 'সহায়ক']
# Word Mover's Distance: 0.7007
# --------------------------------------------------
# Processing Pair 84:
# Sentence A: সে তার যাত্রার গল্প শেয়ার করে।
# Selected Words A: ['সে', 'তার', 'যাত্রার', 'গল্প', 'শেয়ার', 'করে']
# Sentence B: তার অভিজ্ঞতা সকলের জন্য প্রেরণাদায়ক।
# Selected Words B: ['তার', 'অভিজ্ঞতা', 'সকলের', 'জন্য', 'প্রেরণাদায়ক']
# Word Mover's Distance: 0.5381
# --------------------------------------------------
# Processing Pair 85:
# Sentence A: আজকের সকালে পাখির গান শুনি।
# Selected Words A: ['আজকের', 'সকালে', 'পাখির', 'গান', 'শুনি']
# Sentence B: প্রকৃতির সুর আমার মনকে ছুঁয়ে যায়।
# Selected Words B: ['প্রকৃতির', 'সুর', 'আমার', 'মনকে', 'ছুঁয়ে', 'যায়']
# Word Mover's Distance: 0.6823
# --------------------------------------------------
# Processing Pair 86:
# Sentence A: সে তার সৃজনশীল কাজ প্রদর্শন করে।
# Selected Words A: ['সে', 'তার', 'সৃজনশীল', 'কাজ', 'প্রদর্শন', 'করে']
# Sentence B: তার শিল্পকর্ম সকলের নজর কেড়ে নেয়।
# Selected Words B: ['তার', 'শিল্পকর্ম', 'সকলের', 'নজর', 'কেড়ে', 'নেয়']
# Word Mover's Distance: 0.6309
# --------------------------------------------------
# Processing Pair 87:
# Sentence A: আমি ট্রেনের মাধ্যমে ভ্রমণ করি।
# Selected Words A: ['আমি', 'ট্রেনের', 'মাধ্যমে', 'ভ্রমণ', 'করি']
# Sentence B: যাত্রাপথের অভিজ্ঞতা অনন্য।
# Selected Words B: ['যাত্রাপথের', 'অভিজ্ঞতা', 'অনন্য']
# Word Mover's Distance: 0.6744
# --------------------------------------------------
# Processing Pair 88:
# Sentence A: সে তার অফিসে সময়মত পৌঁছায়।
# Selected Words A: ['সে', 'তার', 'অফিসে', 'সময়মত', 'পৌঁছায়']
# Sentence B: তার পেশাগত দায়িত্ব পালনে দক্ষ।
# Selected Words B: ['তার', 'পেশাগত', 'দায়িত্ব', 'পালনে', 'দক্ষ']
# Word Mover's Distance: 0.7606
# --------------------------------------------------
# Processing Pair 89:
# Sentence A: আজকের দুপুরের খাবার স্বাস্থ্যকর।
# Selected Words A: ['আজকের', 'দুপুরের', 'খাবার', 'স্বাস্থ্যকর']
# Sentence B: পুষ্টিকর আহার আমার শক্তির উৎস।
# Selected Words B: ['পুষ্টিকর', 'আহার', 'আমার', 'শক্তির', 'উৎস']
# Word Mover's Distance: 0.6613
# --------------------------------------------------
# Processing Pair 90:
# Sentence A: সে তার স্কুলে নতুন পরিকল্পনা উপস্থাপন করে।
# Selected Words A: ['সে', 'তার', 'স্কুলে', 'নতুন', 'পরিকল্পনা', 'উপস্থাপন', 'করে']
# Sentence B: তার আইডিয়া সকলকে অনুপ্রাণিত করে।
# Selected Words B: ['তার', 'আইডিয়া', 'সকলকে', 'অনুপ্রাণিত', 'করে']
# Word Mover's Distance: 0.4847
# --------------------------------------------------
# Processing Pair 91:
# Sentence A: আমি সাপ্তাহিক বাজারে তাজা ফল কিনি।
# Selected Words A: ['আমি', 'সাপ্তাহিক', 'বাজারে', 'তাজা', 'ফল', 'কিনি']
# Sentence B: ফল আমার দিনের তাজা উপাদান।
# Selected Words B: ['ফল', 'আমার', 'দিনের', 'তাজা', 'উপাদান']
# Word Mover's Distance: 0.4827
# --------------------------------------------------
# Processing Pair 92:
# Sentence A: সে তার বাড়ির সামনে পেইন্টিং করে।
# Selected Words A: ['সে', 'তার', 'বাড়ির', 'সামনে', 'পেইন্টিং', 'করে']
# Sentence B: তার রংয়ের সমাহার মনোমুগ্ধকর।
# Selected Words B: ['তার', 'রংয়ের', 'সমাহার', 'মনোমুগ্ধকর']
# Word Mover's Distance: 0.6228
# --------------------------------------------------
# Processing Pair 93:
# Sentence A: আজকের রাতের খাওয়াদাওয়া মনোরম।
# Selected Words A: ['আজকের', 'রাতের', 'খাওয়াদাওয়া', 'মনোরম']
# Sentence B: ভোজনের সাথেই মিলনের মুহূর্ত সৃষ্টি হয়।
# Selected Words B: ['ভোজনের', 'সাথেই', 'মিলনের', 'মুহূর্ত', 'সৃষ্টি', 'হয়']
# Word Mover's Distance: 0.6045
# --------------------------------------------------
# Processing Pair 94:
# Sentence A: সে তার প্রিয় ব্লগে নতুন পোস্ট লিখেছে।
# Selected Words A: ['সে', 'তার', 'প্রিয়', 'ব্লগে', 'নতুন', 'পোস্ট', 'লিখেছে']
# Sentence B: তার লেখাগুলি পাঠকদের আনন্দ দেয়।
# Selected Words B: ['তার', 'লেখাগুলি', 'পাঠকদের', 'আনন্দ', 'দেয়']
# Word Mover's Distance: 0.6080
# --------------------------------------------------
# Processing Pair 95:
# Sentence A: আমি প্রতিদিন কিছু না কিছু শিখি।
# Selected Words A: ['আমি', 'প্রতিদিন', 'কিছু', 'না', 'কিছু', 'শিখি']
# Sentence B: শিক্ষা আমার জীবনের অংশ।
# Selected Words B: ['শিক্ষা', 'আমার', 'জীবনের', 'অংশ']
# Word Mover's Distance: 0.7939
# --------------------------------------------------
# Processing Pair 96:
# Sentence A: সে তার বন্ধুদের সাথে খেলা করে।
# Selected Words A: ['সে', 'তার', 'বন্ধুদের', 'সাথে', 'খেলা', 'করে']
# Sentence B: তার হাসিখুশি মিলনের সময়।
# Selected Words B: ['তার', 'হাসিখুশি', 'মিলনের', 'সময়']
# Word Mover's Distance: 0.5804
# --------------------------------------------------
# Processing Pair 97:
# Sentence A: আজকের সকালের আর্দ্রতা স্বচ্ছ।
# Selected Words A: ['আজকের', 'সকালের', 'আর্দ্রতা', 'স্বচ্ছ']
# Sentence B: সকালে মাটির গন্ধ প্রশান্তিদায়ক।
# Selected Words B: ['সকালে', 'মাটির', 'গন্ধ', 'প্রশান্তিদায়ক']
# Word Mover's Distance: 0.6944
# --------------------------------------------------
# Processing Pair 98:
# Sentence A: সে তার সৃজনশীল ধারণা প্রকাশ করে।
# Selected Words A: ['সে', 'তার', 'সৃজনশীল', 'ধারণা', 'প্রকাশ', 'করে']
# Sentence B: তার আইডিয়া সত্যিই অনন্য।
# Selected Words B: ['তার', 'আইডিয়া', 'সত্যিই', 'অনন্য']
# Word Mover's Distance: 0.6383
# --------------------------------------------------
# Processing Pair 99:
# Sentence A: আমি তারাতারি রান্না করি।
# Selected Words A: ['আমি', 'তারাতারি', 'রান্না', 'করি']
# Sentence B: রান্নাঘরে তাড়াতাড়ি স্বাদের খোঁজ।
# Selected Words B: ['রান্নাঘরে', 'তাড়াতাড়ি', 'স্বাদের', 'খোঁজ']
# Word Mover's Distance: 0.7042
# --------------------------------------------------
# Processing Pair 100:
# Sentence A: সে তার যন্ত্রপাতি ঠিক করে।
# Selected Words A: ['সে', 'তার', 'যন্ত্রপাতি', 'ঠিক', 'করে']
# Sentence B: তার মেকানিক্যাল কাজ দক্ষতার পরিচয় দেয়।
# Selected Words B: ['তার', 'মেকানিক্যাল', 'কাজ', 'দক্ষতার', 'পরিচয়', 'দেয়']
# Word Mover's Distance: 0.6430
# --------------------------------------------------
# Processing Pair 101:
# Sentence A: আজকের দিনটি উদযাপনের মতো।
# Selected Words A: ['আজকের', 'দিনটি', 'উদযাপনের', 'মতো']
# Sentence B: উৎসবমুখর পরিবেশ সবাইকে আনন্দ দেয়।
# Selected Words B: ['উৎসবমুখর', 'পরিবেশ', 'সবাইকে', 'আনন্দ', 'দেয়']
# Word Mover's Distance: 0.7415
# --------------------------------------------------
# Processing Pair 102:
# Sentence A: সে তার স্বপ্নের চাকরি পেয়েছে।
# Selected Words A: ['সে', 'তার', 'স্বপ্নের', 'চাকরি', 'পেয়েছে']
# Sentence B: তার পরিশ্রম সফলতার ফল।
# Selected Words B: ['তার', 'পরিশ্রম', 'সফলতার', 'ফল']
# Word Mover's Distance: 0.5545
# --------------------------------------------------
# Processing Pair 103:
# Sentence A: আমি প্রাকৃতিক দৃশ্য উপভোগ করি।
# Selected Words A: ['আমি', 'প্রাকৃতিক', 'দৃশ্য', 'উপভোগ', 'করি']
# Sentence B: প্রকৃতির সৌন্দর্য আমাকে মুগ্ধ করে।
# Selected Words B: ['প্রকৃতির', 'সৌন্দর্য', 'আমাকে', 'মুগ্ধ', 'করে']
# Word Mover's Distance: 0.6567
# --------------------------------------------------
# Processing Pair 104:
# Sentence A: সে তার কর্মজীবনে উদ্যমী।
# Selected Words A: ['সে', 'তার', 'কর্মজীবনে', 'উদ্যমী']
# Sentence B: তার কাজের প্রতি নিবেদিত মনোভাব প্রশংসনীয়।
# Selected Words B: ['তার', 'কাজের', 'প্রতি', 'নিবেদিত', 'মনোভাব', 'প্রশংসনীয়']
# Word Mover's Distance: 0.6385
# --------------------------------------------------
# Processing Pair 105:
# Sentence A: আজকের আলো সকালে একেবারে দীপ্ত।
# Selected Words A: ['আজকের', 'আলো', 'সকালে', 'একেবারে', 'দীপ্ত']
# Sentence B: সকালের সূর্যোদয় মনোহর।
# Selected Words B: ['সকালের', 'সূর্যোদয়', 'মনোহর']
# Word Mover's Distance: 0.7120
# --------------------------------------------------
# Processing Pair 106:
# Sentence A: সে তার প্রোজেক্টে সৃজনশীলতা দেখায়।
# Selected Words A: ['সে', 'তার', 'প্রোজেক্টে', 'সৃজনশীলতা', 'দেখায়']
# Sentence B: তার কাজের নতুনত্ব সবাইকে আকৃষ্ট করে।
# Selected Words B: ['তার', 'কাজের', 'নতুনত্ব', 'সবাইকে', 'আকৃষ্ট', 'করে']
# Word Mover's Distance: 0.4311
# --------------------------------------------------
# Processing Pair 107:
# Sentence A: আমি প্রতিদিন নতুন কিছু জানি।
# Selected Words A: ['আমি', 'প্রতিদিন', 'নতুন', 'কিছু', 'জানি']
# Sentence B: জ্ঞান আমার জীবনের আলো।
# Selected Words B: ['জ্ঞান', 'আমার', 'জীবনের', 'আলো']
# Word Mover's Distance: 0.7192
# --------------------------------------------------
# Processing Pair 108:
# Sentence A: সে তার সৃজনশীলতা নিয়ে কাজ করে।
# Selected Words A: ['সে', 'তার', 'সৃজনশীলতা', 'নিয়ে', 'কাজ', 'করে']
# Sentence B: তার নতুন ধারণা প্রত্যাশিত।
# Selected Words B: ['তার', 'নতুন', 'ধারণা', 'প্রত্যাশিত']
# Word Mover's Distance: 0.4696
# --------------------------------------------------
# Processing Pair 109:
# Sentence A: আজকের আবহাওয়া আনন্দদায়ক।
# Selected Words A: ['আজকের', 'আবহাওয়া', 'আনন্দদায়ক']
# Sentence B: প্রকৃতির ছোঁয়া আমাকে প্রশান্ত করে।
# Selected Words B: ['প্রকৃতির', 'ছোঁয়া', 'আমাকে', 'প্রশান্ত', 'করে']
# Word Mover's Distance: 0.5021
# --------------------------------------------------
# Processing Pair 110:
# Sentence A: সে তার দৈনন্দিন কাজ নিয়মিত সম্পন্ন করে।
# Selected Words A: ['সে', 'তার', 'দৈনন্দিন', 'কাজ', 'নিয়মিত', 'সম্পন্ন', 'করে']
# Sentence B: তার শৃঙ্খলাবদ্ধতা মুগ্ধকর।
# Selected Words B: ['তার', 'শৃঙ্খলাবদ্ধতা', 'মুগ্ধকর']
# Word Mover's Distance: 0.6256
# --------------------------------------------------
# Processing Pair 111:
# Sentence A: আমি নতুন বই পড়ার অভিজ্ঞতা সংগ্রহ করি।
# Selected Words A: ['আমি', 'নতুন', 'বই', 'পড়ার', 'অভিজ্ঞতা', 'সংগ্রহ', 'করি']
# Sentence B: পাঠ্যবই আমার মনের খোরাক।
# Selected Words B: ['পাঠ্যবই', 'আমার', 'মনের', 'খোরাক']
# Word Mover's Distance: 0.7233
# --------------------------------------------------
# Processing Pair 112:
# Sentence A: সে তার অফিসের কাজ সাবলীলভাবে সম্পন্ন করে।
# Selected Words A: ['সে', 'তার', 'অফিসের', 'কাজ', 'সাবলীলভাবে', 'সম্পন্ন', 'করে']
# Sentence B: তার পেশাগত দক্ষতা সবাইকে অনুপ্রাণিত করে।
# Selected Words B: ['তার', 'পেশাগত', 'দক্ষতা', 'সবাইকে', 'অনুপ্রাণিত', 'করে']
# Word Mover's Distance: 0.4811
# --------------------------------------------------
# Processing Pair 113:
# Sentence A: আজকের দিনের আলো উজ্জ্বল।
# Selected Words A: ['আজকের', 'দিনের', 'আলো', 'উজ্জ্বল']
# Sentence B: সকালে রৌদ্রের আলোকসজ্জা মনোমুগ্ধকর।
# Selected Words B: ['সকালে', 'রৌদ্রের', 'আলোকসজ্জা', 'মনোমুগ্ধকর']
# Word Mover's Distance: 0.5591
# --------------------------------------------------
# Processing Pair 114:
# Sentence A: সে তার সৃজনশীল লেখালেখি করে।
# Selected Words A: ['সে', 'তার', 'সৃজনশীল', 'লেখালেখি', 'করে']
# Sentence B: তার লেখা সকলকে ভাবতে বাধ্য করে।
# Selected Words B: ['তার', 'লেখা', 'সকলকে', 'ভাবতে', 'বাধ্য', 'করে']
# Word Mover's Distance: 0.4713
# --------------------------------------------------
# Processing Pair 115:
# Sentence A: আমি সৃজনশীল কাজের প্রতি উৎসাহী।
# Selected Words A: ['আমি', 'সৃজনশীল', 'কাজের', 'প্রতি', 'উৎসাহী']
# Sentence B: আমার সৃজনশীলতা আমার পরিচয়।
# Selected Words B: ['আমার', 'সৃজনশীলতা', 'আমার', 'পরিচয়']
# Word Mover's Distance: 0.5037
# --------------------------------------------------
# Processing Pair 116:
# Sentence A: সে তার প্রিয় সঙ্গীতে মগ্ন।
# Selected Words A: ['সে', 'তার', 'প্রিয়', 'সঙ্গীতে', 'মগ্ন']
# Sentence B: তার সুরেলা কণ্ঠস্বর সবাইকে স্পর্শ করে।
# Selected Words B: ['তার', 'সুরেলা', 'কণ্ঠস্বর', 'সবাইকে', 'স্পর্শ', 'করে']
# Word Mover's Distance: 0.6015
# --------------------------------------------------
# Processing Pair 117:
# Sentence A: আজকের দিনটি উদ্দীপ্ত।
# Selected Words A: ['আজকের', 'দিনটি', 'উদ্দীপ্ত']
# Sentence B: আলো দিনের ছোঁয়ায় মন ভালো হয়ে যায়।
# Selected Words B: ['আলো', 'দিনের', 'ছোঁয়ায়', 'মন', 'ভালো', 'হয়ে', 'যায়']
# Word Mover's Distance: 0.6199
# --------------------------------------------------
# Processing Pair 118:
# Sentence A: সে তার নতুন পরিকল্পনা নিয়ে আলোচনা করে।
# Selected Words A: ['সে', 'তার', 'নতুন', 'পরিকল্পনা', 'নিয়ে', 'আলোচনা', 'করে']
# Sentence B: তার আইডিয়া দলের সকলকে অনুপ্রাণিত করে।
# Selected Words B: ['তার', 'আইডিয়া', 'দলের', 'সকলকে', 'অনুপ্রাণিত', 'করে']
# Word Mover's Distance: 0.4290
# --------------------------------------------------
# Processing Pair 119:
# Sentence A: আমি প্রতিদিন প্রাকৃতিক পরিবেশে ভ্রমণ করি।
# Selected Words A: ['আমি', 'প্রতিদিন', 'প্রাকৃতিক', 'পরিবেশে', 'ভ্রমণ', 'করি']
# Sentence B: প্রকৃতির সৌন্দর্য আমাকে রোমাঞ্চিত করে।
# Selected Words B: ['প্রকৃতির', 'সৌন্দর্য', 'আমাকে', 'রোমাঞ্চিত', 'করে']
# Word Mover's Distance: 0.6186
# --------------------------------------------------
# Processing Pair 120:
# Sentence A: সে শহরে দ্রুত চলাফেরা করে।
# Selected Words A: ['সে', 'শহরে', 'দ্রুত', 'চলাফেরা', 'করে']
# Sentence B: শহরের চাঞ্চল্য তার মনকে উদ্দীপিত করে।
# Selected Words B: ['শহরের', 'চাঞ্চল্য', 'তার', 'মনকে', 'উদ্দীপিত', 'করে']
# Word Mover's Distance: 0.6731
# --------------------------------------------------

# %% [markdown]
# ### **Optimized Word Mover’s Distance (OWMD) on Bengali Text Using POS Tag-Based Classification**
#
# <p align="justify">
# Optimized Word Mover’s Distance (OWMD) is a refined version of Word Mover’s Distance (WMD) that improves similarity measurement between two text samples. In our approach, we apply OWMD to Bengali text by first performing tokenization and Part-of-Speech (POS) tagging using a Bengali POS tagger. To enhance accuracy, we classify words based on their POS tags, selecting <b>nouns (NN), verbs (VM), adjectives (JJ), and adverbs (RB)</b> as relevant words for similarity computation. If no such words exist, we fall back to using all tokens to avoid empty inputs that cause infinite distance values. We then compute the Word Mover’s Distance (WMD) using FastText word embeddings, followed by converting it into <b>Optimized Word Mover’s Similarity (OWMS) using an exponential function</b>. This process ensures a robust semantic similarity measurement, effectively handling Bengali linguistic structures while mitigating errors due to insufficient content-bearing words.
# </p>

# %%
import nltk

# Download the Indian POS dataset (if not already downloaded)
nltk.download('indian')
nltk.download('punkt')
nltk.download('punkt_tab')
print("Completed")
# Out:
# Completed
# [nltk_data] Downloading package indian to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package indian is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Load the tagged Bengali sentences from the NLTK Indian corpus
tagged_sents = nltk.corpus.indian.tagged_sents(fileids="bangla.pos")

# Train a Unigram POS Tagger
bengali_tagger = nltk.tag.UnigramTagger(tagged_sents)

print("Bengali POS Tagger is Ready!")
# Out:
# Bengali POS Tagger is Ready!

# %%
# Define the file path (Update this path if needed)
file_path = "C:\\Users\\KIIT\\PycharmProjects\\JupyterProject\\data\\BengaliDataset.txt"

# Read the dataset file
with open(file_path, "r", encoding="utf-8") as file:
    sentence_pairs = file.readlines()

print(f"Loaded {len(sentence_pairs)} sentence pairs from dataset.")
# Out:
# Loaded 120 sentence pairs from dataset.

# %%
# Process each sentence pair
for i, pair in enumerate(sentence_pairs):
    sentences = pair.strip().split("\t")  # Split by tab character

    if len(sentences) != 2:
        print(f"Skipping invalid pair {i+1}: {pair}")
        continue

    sentence_A, sentence_B = sentences

    # Tokenize and tag each sentence
    tagged_A = bengali_tagger.tag(nltk.word_tokenize(sentence_A))
    tagged_B = bengali_tagger.tag(nltk.word_tokenize(sentence_B))

    # Print results
    print(f"\nProcessing Pair {i+1}:")
    print(f"Sentence A: {sentence_A}")
    print(f"POS Tags A: {tagged_A}")

    print(f"Sentence B: {sentence_B}")
    print(f"POS Tags B: {tagged_B}")
# Out:
# Processing Pair 1:
# Sentence A: আমি বই পড়ি।
# POS Tags A: [('আমি', 'PRP'), ('বই', 'NN'), ('পড়ি।', None)]
# Sentence B: আমি গল্প পড়তে ভালোবাসি।
# POS Tags B: [('আমি', 'PRP'), ('গল্প', None), ('পড়তে', 'VM'), ('ভালোবাসি।', None)]
#
# Processing Pair 2:
# Sentence A: সে বাজারে গিয়ে সবজি কিনেছিল।
# POS Tags A: [('সে', 'PRP'), ('বাজারে', None), ('গিয়ে', None), ('সবজি', 'NN'), ('কিনেছিল।', None)]
# Sentence B: সে সেরা সবজি সংগ্রহ করেছিল।
# POS Tags B: [('সে', 'PRP'), ('সেরা', None), ('সবজি', 'NN'), ('সংগ্রহ', 'NN'), ('করেছিল।', None)]
#
# Processing Pair 3:
# Sentence A: আজ আকাশ স্পষ্ট।
# POS Tags A: [('আজ', 'NN'), ('আকাশ', 'NN'), ('স্পষ্ট।', None)]
# Sentence B: আজ দিনটি একেবারে পরিষ্কার।
# POS Tags B: [('আজ', 'NN'), ('দিনটি', None), ('একেবারে', 'RB'), ('পরিষ্কার।', None)]
#
# Processing Pair 4:
# Sentence A: আমরা সাঁতার কাটতে জলের কাছে গিয়েছিলাম।
# POS Tags A: [('আমরা', 'PRP'), ('সাঁতার', None), ('কাটতে', 'VM'), ('জলের', 'NN'), ('কাছে', 'NST'), ('গিয়েছিলাম।', None)]
# Sentence B: আমরা পুকুরের ধারে সাঁতার কাটার মজা নিয়েছিলাম।
# POS Tags B: [('আমরা', 'PRP'), ('পুকুরের', None), ('ধারে', None), ('সাঁতার', None), ('কাটার', 'VM'), ('মজা', None), ('নিয়েছিলাম।', None)]
#
# Processing Pair 5:
# Sentence A: সে প্রতিদিন সকালে হাঁটে।
# POS Tags A: [('সে', 'PRP'), ('প্রতিদিন', None), ('সকালে', None), ('হাঁটে।', None)]
# Sentence B: সে দৈনিক হাঁটার অভ্যাস পোষণ করে।
# POS Tags B: [('সে', 'PRP'), ('দৈনিক', None), ('হাঁটার', None), ('অভ্যাস', None), ('পোষণ', None), ('করে।', None)]
#
# Processing Pair 6:
# Sentence A: বৃক্ষগুলি শীতে পাতলা হয়ে যায়।
# POS Tags A: [('বৃক্ষগুলি', None), ('শীতে', None), ('পাতলা', 'JJ'), ('হয়ে', None), ('যায়।', None)]
# Sentence B: শীতে গাছের পাতা ঝরে যায়।
# POS Tags B: [('শীতে', None), ('গাছের', 'NN'), ('পাতা', 'NN'), ('ঝরে', 'VM'), ('যায়।', None)]
#
# Processing Pair 7:
# Sentence A: সে তার চুল কাটিয়ে নতুন স্টাইল নিল।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('চুল', 'NN'), ('কাটিয়ে', None), ('নতুন', 'JJ'), ('স্টাইল', None), ('নিল।', None)]
# Sentence B: তার চুলের নতুন কাটা চেহারা আলাদা ছিল।
# POS Tags B: [('তার', 'PRP'), ('চুলের', None), ('নতুন', 'JJ'), ('কাটা', None), ('চেহারা', None), ('আলাদা', 'JJ'), ('ছিল।', None)]
#
# Processing Pair 8:
# Sentence A: আমি চা পান করতে পছন্দ করি।
# POS Tags A: [('আমি', 'PRP'), ('চা', None), ('পান', 'VM'), ('করতে', 'VM'), ('পছন্দ', 'NN'), ('করি।', None)]
# Sentence B: চা আমার প্রিয় পানীয়।
# POS Tags B: [('চা', None), ('আমার', 'PRP'), ('প্রিয়', None), ('পানীয়।', None)]
#
# Processing Pair 9:
# Sentence A: ছেলেটি স্কুলে নতুন জুতো পরে।
# POS Tags A: [('ছেলেটি', None), ('স্কুলে', None), ('নতুন', 'JJ'), ('জুতো', None), ('পরে।', None)]
# Sentence B: স্কুলে তার নতুন জুতোর প্রশংসা হয়।
# POS Tags B: [('স্কুলে', None), ('তার', 'PRP'), ('নতুন', 'JJ'), ('জুতোর', None), ('প্রশংসা', None), ('হয়।', None)]
#
# Processing Pair 10:
# Sentence A: সে তার বাড়ির সামনে ফুল বাগান তৈরি করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('বাড়ির', 'NN'), ('সামনে', 'NST'), ('ফুল', 'NN'), ('বাগান', None), ('তৈরি', 'VM'), ('করেছে।', None)]
# Sentence B: তার বাড়ির পাশে একটি সুন্দর ফুলের বাগান আছে।
# POS Tags B: [('তার', 'PRP'), ('বাড়ির', 'NN'), ('পাশে', 'NST'), ('একটি', 'QC'), ('সুন্দর', 'JJ'), ('ফুলের', None), ('বাগান', None), ('আছে।', None)]
#
# Processing Pair 11:
# Sentence A: আমি গান শুনতে ভালোবাসি।
# POS Tags A: [('আমি', 'PRP'), ('গান', 'NN'), ('শুনতে', 'VM'), ('ভালোবাসি।', None)]
# Sentence B: সঙ্গীত আমার মনকে প্রশান্ত করে।
# POS Tags B: [('সঙ্গীত', None), ('আমার', 'PRP'), ('মনকে', None), ('প্রশান্ত', None), ('করে।', None)]
#
# Processing Pair 12:
# Sentence A: সে রাস্তায় সাবধানতার সাথে চলে।
# POS Tags A: [('সে', 'PRP'), ('রাস্তায়', None), ('সাবধানতার', None), ('সাথে', 'PSP'), ('চলে।', None)]
# Sentence B: সে পথ চলতে সতর্ক।
# POS Tags B: [('সে', 'PRP'), ('পথ', 'NN'), ('চলতে', 'VM'), ('সতর্ক।', None)]
#
# Processing Pair 13:
# Sentence A: আমাদের দলের খেলাটি জয়ী হয়েছিল।
# POS Tags A: [('আমাদের', 'PRP'), ('দলের', None), ('খেলাটি', None), ('জয়ী', None), ('হয়েছিল।', None)]
# Sentence B: আমরা খেলার মাধ্যমে বিজয় অর্জন করেছিলাম।
# POS Tags B: [('আমরা', 'PRP'), ('খেলার', None), ('মাধ্যমে', 'PSP'), ('বিজয়', None), ('অর্জন', None), ('করেছিলাম।', None)]
#
# Processing Pair 14:
# Sentence A: সে পেন্সিলে চিত্র আঁকে।
# POS Tags A: [('সে', 'PRP'), ('পেন্সিলে', None), ('চিত্র', 'NN'), ('আঁকে।', None)]
# Sentence B: তার অঙ্কন কাজটি খুবই মনোরম।
# POS Tags B: [('তার', 'PRP'), ('অঙ্কন', None), ('কাজটি', None), ('খুবই', 'RB'), ('মনোরম।', None)]
#
# Processing Pair 15:
# Sentence A: রাস্তায় হালকা বৃষ্টি হচ্ছে।
# POS Tags A: [('রাস্তায়', None), ('হালকা', None), ('বৃষ্টি', 'NN'), ('হচ্ছে।', None)]
# Sentence B: মেঘলা আকাশে বৃষ্টি ফোটে।
# POS Tags B: [('মেঘলা', None), ('আকাশে', 'NN'), ('বৃষ্টি', 'NN'), ('ফোটে।', None)]
#
# Processing Pair 16:
# Sentence A: সে নিজের বাড়ি সাজিয়েছে।
# POS Tags A: [('সে', 'PRP'), ('নিজের', 'PRP'), ('বাড়ি', None), ('সাজিয়েছে।', None)]
# Sentence B: তার বাসা নতুন রঙে রাঙানো।
# POS Tags B: [('তার', 'PRP'), ('বাসা', None), ('নতুন', 'JJ'), ('রঙে', None), ('রাঙানো।', None)]
#
# Processing Pair 17:
# Sentence A: আমি সিনেমা দেখতে গিয়েছিলাম।
# POS Tags A: [('আমি', 'PRP'), ('সিনেমা', None), ('দেখতে', 'VM'), ('গিয়েছিলাম।', None)]
# Sentence B: চলচ্চিত্র দেখার অভিজ্ঞতা অসাধারণ ছিল।
# POS Tags B: [('চলচ্চিত্র', None), ('দেখার', 'VM'), ('অভিজ্ঞতা', None), ('অসাধারণ', None), ('ছিল।', None)]
#
# Processing Pair 18:
# Sentence A: সে দুপুরে খাবার করে।
# POS Tags A: [('সে', 'PRP'), ('দুপুরে', None), ('খাবার', None), ('করে।', None)]
# Sentence B: দুপুরের আহার তার শক্তির উৎস।
# POS Tags B: [('দুপুরের', None), ('আহার', None), ('তার', 'PRP'), ('শক্তির', None), ('উৎস।', None)]
#
# Processing Pair 19:
# Sentence A: আজ আমার মন ভালো।
# POS Tags A: [('আজ', 'NN'), ('আমার', 'PRP'), ('মন', 'NN'), ('ভালো।', None)]
# Sentence B: আজ আমার মেজাজ একদম সুন্দর।
# POS Tags B: [('আজ', 'NN'), ('আমার', 'PRP'), ('মেজাজ', None), ('একদম', None), ('সুন্দর।', None)]
#
# Processing Pair 20:
# Sentence A: সে নতুন বই কিনেছে।
# POS Tags A: [('সে', 'PRP'), ('নতুন', 'JJ'), ('বই', 'NN'), ('কিনেছে।', None)]
# Sentence B: তার পাঠ্যবই সমৃদ্ধ।
# POS Tags B: [('তার', 'PRP'), ('পাঠ্যবই', None), ('সমৃদ্ধ।', None)]
#
# Processing Pair 21:
# Sentence A: আমরা পার্কে খেলাধুলা করি।
# POS Tags A: [('আমরা', 'PRP'), ('পার্কে', None), ('খেলাধুলা', None), ('করি।', None)]
# Sentence B: পার্কে আমরা বিনোদনের সময় কাটাই।
# POS Tags B: [('পার্কে', None), ('আমরা', 'PRP'), ('বিনোদনের', None), ('সময়', None), ('কাটাই।', None)]
#
# Processing Pair 22:
# Sentence A: সে তার বন্ধুদের সাথে সময় কাটায়।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('বন্ধুদের', 'NN'), ('সাথে', 'PSP'), ('সময়', None), ('কাটায়।', None)]
# Sentence B: তার সঙ্গীরা তার প্রিয়।
# POS Tags B: [('তার', 'PRP'), ('সঙ্গীরা', None), ('তার', 'PRP'), ('প্রিয়।', None)]
#
# Processing Pair 23:
# Sentence A: আমি সঙ্গীত বাজাই।
# POS Tags A: [('আমি', 'PRP'), ('সঙ্গীত', None), ('বাজাই।', None)]
# Sentence B: সঙ্গীত আমার আবেগ প্রকাশ করে।
# POS Tags B: [('সঙ্গীত', None), ('আমার', 'PRP'), ('আবেগ', None), ('প্রকাশ', 'NN'), ('করে।', None)]
#
# Processing Pair 24:
# Sentence A: সে নতুন ফোন কিনেছে।
# POS Tags A: [('সে', 'PRP'), ('নতুন', 'JJ'), ('ফোন', None), ('কিনেছে।', None)]
# Sentence B: তার মোবাইলটি একেবারে ঝকঝকে।
# POS Tags B: [('তার', 'PRP'), ('মোবাইলটি', None), ('একেবারে', 'RB'), ('ঝকঝকে।', None)]
#
# Processing Pair 25:
# Sentence A: আমরা সকালে সূর্যোদয় দেখেছিলাম।
# POS Tags A: [('আমরা', 'PRP'), ('সকালে', None), ('সূর্যোদয়', None), ('দেখেছিলাম।', None)]
# Sentence B: সকালে সূর্যের প্রথম আলো আমাদের অভিভূত করেছিল।
# POS Tags B: [('সকালে', None), ('সূর্যের', None), ('প্রথম', 'QO'), ('আলো', 'NN'), ('আমাদের', 'PRP'), ('অভিভূত', None), ('করেছিল।', None)]
#
# Processing Pair 26:
# Sentence A: সে শহরে ভ্রমণ করে।
# POS Tags A: [('সে', 'PRP'), ('শহরে', None), ('ভ্রমণ', None), ('করে।', None)]
# Sentence B: শহরের সৌন্দর্য তার দৃষ্টি আকর্ষণ করে।
# POS Tags B: [('শহরের', None), ('সৌন্দর্য', None), ('তার', 'PRP'), ('দৃষ্টি', 'NN'), ('আকর্ষণ', None), ('করে।', None)]
#
# Processing Pair 27:
# Sentence A: আমি আর্ট গ্যালারিতে গিয়েছিলাম।
# POS Tags A: [('আমি', 'PRP'), ('আর্ট', None), ('গ্যালারিতে', None), ('গিয়েছিলাম।', None)]
# Sentence B: শিল্প প্রদর্শনী আমার মনের প্রশান্তি দেয়।
# POS Tags B: [('শিল্প', None), ('প্রদর্শনী', None), ('আমার', 'PRP'), ('মনের', 'NN'), ('প্রশান্তি', None), ('দেয়।', None)]
#
# Processing Pair 28:
# Sentence A: সে সাঁতার কাটা শিখেছে।
# POS Tags A: [('সে', 'PRP'), ('সাঁতার', None), ('কাটা', None), ('শিখেছে।', None)]
# Sentence B: তার সাঁতার কাটার দক্ষতা বৃদ্ধি পেয়েছে।
# POS Tags B: [('তার', 'PRP'), ('সাঁতার', None), ('কাটার', 'VM'), ('দক্ষতা', None), ('বৃদ্ধি', 'NN'), ('পেয়েছে।', None)]
#
# Processing Pair 29:
# Sentence A: আজকে ঠাণ্ডা বৃষ্টি হচ্ছে।
# POS Tags A: [('আজকে', 'NN'), ('ঠাণ্ডা', 'JJ'), ('বৃষ্টি', 'NN'), ('হচ্ছে।', None)]
# Sentence B: আবহাওয়া একদম শীতল।
# POS Tags B: [('আবহাওয়া', None), ('একদম', None), ('শীতল।', None)]
#
# Processing Pair 30:
# Sentence A: সে হাসতে ভালোবাসে।
# POS Tags A: [('সে', 'PRP'), ('হাসতে', None), ('ভালোবাসে।', None)]
# Sentence B: তার হাসি সবাইকে আনন্দ দেয়।
# POS Tags B: [('তার', 'PRP'), ('হাসি', 'NN'), ('সবাইকে', 'PRP'), ('আনন্দ', 'NN'), ('দেয়।', None)]
#
# Processing Pair 31:
# Sentence A: আমি প্রতিদিন লেখা অনুশীলন করি।
# POS Tags A: [('আমি', 'PRP'), ('প্রতিদিন', None), ('লেখা', 'VM'), ('অনুশীলন', 'NN'), ('করি।', None)]
# Sentence B: লেখা আমার সৃজনশীলতার প্রকাশ।
# POS Tags B: [('লেখা', 'VM'), ('আমার', 'PRP'), ('সৃজনশীলতার', None), ('প্রকাশ।', None)]
#
# Processing Pair 32:
# Sentence A: সে রান্না করতে ভালোবাসে।
# POS Tags A: [('সে', 'PRP'), ('রান্না', 'NN'), ('করতে', 'VM'), ('ভালোবাসে।', None)]
# Sentence B: তার রান্নার স্বাদ অসাধারণ।
# POS Tags B: [('তার', 'PRP'), ('রান্নার', 'NN'), ('স্বাদ', 'NN'), ('অসাধারণ।', None)]
#
# Processing Pair 33:
# Sentence A: আমরা বইমেলায় গিয়েছিলাম।
# POS Tags A: [('আমরা', 'PRP'), ('বইমেলায়', None), ('গিয়েছিলাম।', None)]
# Sentence B: বইমেলায় নতুন বই আবিষ্কার করেছি।
# POS Tags B: [('বইমেলায়', None), ('নতুন', 'JJ'), ('বই', 'NN'), ('আবিষ্কার', None), ('করেছি।', None)]
#
# Processing Pair 34:
# Sentence A: সে মাঠে ফুটবল খেলেছে।
# POS Tags A: [('সে', 'PRP'), ('মাঠে', None), ('ফুটবল', None), ('খেলেছে।', None)]
# Sentence B: তার ফুটবল খেলার চপলতা মুগ্ধকর।
# POS Tags B: [('তার', 'PRP'), ('ফুটবল', None), ('খেলার', None), ('চপলতা', None), ('মুগ্ধকর।', None)]
#
# Processing Pair 35:
# Sentence A: আমি নিজের মতো করে চিন্তা করি।
# POS Tags A: [('আমি', 'PRP'), ('নিজের', 'PRP'), ('মতো', 'PSP'), ('করে', 'VM'), ('চিন্তা', None), ('করি।', None)]
# Sentence B: আমার দৃষ্টিভঙ্গি ভিন্ন।
# POS Tags B: [('আমার', 'PRP'), ('দৃষ্টিভঙ্গি', None), ('ভিন্ন।', None)]
#
# Processing Pair 36:
# Sentence A: সে সঙ্গীতের ক্লাসে যায়।
# POS Tags A: [('সে', 'PRP'), ('সঙ্গীতের', None), ('ক্লাসে', None), ('যায়।', None)]
# Sentence B: তার সুরেলা কণ্ঠস্বর ক্লাসে প্রশংসিত।
# POS Tags B: [('তার', 'PRP'), ('সুরেলা', None), ('কণ্ঠস্বর', None), ('ক্লাসে', None), ('প্রশংসিত।', None)]
#
# Processing Pair 37:
# Sentence A: আজকের রাতটি শান্ত।
# POS Tags A: [('আজকের', 'NN'), ('রাতটি', None), ('শান্ত।', None)]
# Sentence B: রাত্রি একেবারে নিরিবিলি।
# POS Tags B: [('রাত্রি', 'NN'), ('একেবারে', 'RB'), ('নিরিবিলি।', None)]
#
# Processing Pair 38:
# Sentence A: সে পাখিদের কথা শুনে।
# POS Tags A: [('সে', 'PRP'), ('পাখিদের', None), ('কথা', 'NN'), ('শুনে।', None)]
# Sentence B: তার পরিবেশের প্রতি গভীর আকর্ষণ আছে।
# POS Tags B: [('তার', 'PRP'), ('পরিবেশের', None), ('প্রতি', 'QF'), ('গভীর', 'JJ'), ('আকর্ষণ', None), ('আছে।', None)]
#
# Processing Pair 39:
# Sentence A: আমি ছবি আঁকতে ভালোবাসি।
# POS Tags A: [('আমি', 'PRP'), ('ছবি', 'NN'), ('আঁকতে', None), ('ভালোবাসি।', None)]
# Sentence B: আমার আঁকা ছবি মনোমুগ্ধকর।
# POS Tags B: [('আমার', 'PRP'), ('আঁকা', 'VM'), ('ছবি', 'NN'), ('মনোমুগ্ধকর।', None)]
#
# Processing Pair 40:
# Sentence A: সে প্রতিদিন ব্যায়াম করে।
# POS Tags A: [('সে', 'PRP'), ('প্রতিদিন', None), ('ব্যায়াম', None), ('করে।', None)]
# Sentence B: তার শরীরচর্চা নিয়মিত।
# POS Tags B: [('তার', 'PRP'), ('শরীরচর্চা', None), ('নিয়মিত।', None)]
#
# Processing Pair 41:
# Sentence A: আমরা বাগানে ঘুমাই।
# POS Tags A: [('আমরা', 'PRP'), ('বাগানে', None), ('ঘুমাই।', None)]
# Sentence B: প্রকৃতির মাঝে বিশ্রাম পাই।
# POS Tags B: [('প্রকৃতির', None), ('মাঝে', 'RDP'), ('বিশ্রাম', 'NN'), ('পাই।', None)]
#
# Processing Pair 42:
# Sentence A: সে নতুন গান রচনা করেছে।
# POS Tags A: [('সে', 'PRP'), ('নতুন', 'JJ'), ('গান', 'NN'), ('রচনা', 'NN'), ('করেছে।', None)]
# Sentence B: তার সুরেলা সঙ্গীত সবাইকে স্পর্শ করেছে।
# POS Tags B: [('তার', 'PRP'), ('সুরেলা', None), ('সঙ্গীত', None), ('সবাইকে', 'PRP'), ('স্পর্শ', 'NN'), ('করেছে।', None)]
#
# Processing Pair 43:
# Sentence A: আমি কবিতা লিখি।
# POS Tags A: [('আমি', 'PRP'), ('কবিতা', None), ('লিখি।', None)]
# Sentence B: কবিতা আমার হৃদয়ের ভাষা।
# POS Tags B: [('কবিতা', None), ('আমার', 'PRP'), ('হৃদয়ের', None), ('ভাষা।', None)]
#
# Processing Pair 44:
# Sentence A: সে দোকানে নতুন জামাকাপড় কিনেছে।
# POS Tags A: [('সে', 'PRP'), ('দোকানে', 'NN'), ('নতুন', 'JJ'), ('জামাকাপড়', None), ('কিনেছে।', None)]
# Sentence B: তার পোশাক সংগ্রহে নতুনত্ব আছে।
# POS Tags B: [('তার', 'PRP'), ('পোশাক', 'NN'), ('সংগ্রহে', None), ('নতুনত্ব', None), ('আছে।', None)]
#
# Processing Pair 45:
# Sentence A: আজ বৃষ্টি ঝরে পড়ছে।
# POS Tags A: [('আজ', 'NN'), ('বৃষ্টি', 'NN'), ('ঝরে', 'VM'), ('পড়ছে।', None)]
# Sentence B: আবহাওয়া একদম রোমান্টিক।
# POS Tags B: [('আবহাওয়া', None), ('একদম', None), ('রোমান্টিক।', None)]
#
# Processing Pair 46:
# Sentence A: সে কলেজে ভাল মেধাবী।
# POS Tags A: [('সে', 'PRP'), ('কলেজে', None), ('ভাল', 'JJ'), ('মেধাবী।', None)]
# Sentence B: তার পড়াশোনায় উৎকর্ষতা রয়েছে।
# POS Tags B: [('তার', 'PRP'), ('পড়াশোনায়', None), ('উৎকর্ষতা', None), ('রয়েছে।', None)]
#
# Processing Pair 47:
# Sentence A: আমি বাগানে কাজ করি।
# POS Tags A: [('আমি', 'PRP'), ('বাগানে', None), ('কাজ', 'NN'), ('করি।', None)]
# Sentence B: প্রকৃতির মাঝে আমার শান্তি।
# POS Tags B: [('প্রকৃতির', None), ('মাঝে', 'RDP'), ('আমার', 'PRP'), ('শান্তি।', None)]
#
# Processing Pair 48:
# Sentence A: সে বাজারে নতুন ফল কিনেছে।
# POS Tags A: [('সে', 'PRP'), ('বাজারে', None), ('নতুন', 'JJ'), ('ফল', 'NN'), ('কিনেছে।', None)]
# Sentence B: তার তাজা ফলের ভান্ডার সমৃদ্ধ।
# POS Tags B: [('তার', 'PRP'), ('তাজা', None), ('ফলের', 'NN'), ('ভান্ডার', None), ('সমৃদ্ধ।', None)]
#
# Processing Pair 49:
# Sentence A: আমরা বন্ধুদের সাথে সিনেমা দেখলাম।
# POS Tags A: [('আমরা', 'PRP'), ('বন্ধুদের', 'NN'), ('সাথে', 'PSP'), ('সিনেমা', None), ('দেখলাম।', None)]
# Sentence B: সিনেমা আমাদের মিলনের মুহূর্ত।
# POS Tags B: [('সিনেমা', None), ('আমাদের', 'PRP'), ('মিলনের', None), ('মুহূর্ত।', None)]
#
# Processing Pair 50:
# Sentence A: সে প্রতিদিন সকালে মেডিটেশন করে।
# POS Tags A: [('সে', 'PRP'), ('প্রতিদিন', None), ('সকালে', None), ('মেডিটেশন', None), ('করে।', None)]
# Sentence B: তার মনের শান্তি নিশ্চিত হয়।
# POS Tags B: [('তার', 'PRP'), ('মনের', 'NN'), ('শান্তি', 'NN'), ('নিশ্চিত', 'JJ'), ('হয়।', None)]
#
# Processing Pair 51:
# Sentence A: আমি হস্তশিল্প করি।
# POS Tags A: [('আমি', 'PRP'), ('হস্তশিল্প', None), ('করি।', None)]
# Sentence B: হস্তশিল্প আমার সৃজনশীল প্রকাশ।
# POS Tags B: [('হস্তশিল্প', None), ('আমার', 'PRP'), ('সৃজনশীল', None), ('প্রকাশ।', None)]
#
# Processing Pair 52:
# Sentence A: সে তার আর্ট প্রোজেক্ট সম্পন্ন করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('আর্ট', None), ('প্রোজেক্ট', None), ('সম্পন্ন', 'JJ'), ('করেছে।', None)]
# Sentence B: তার চিত্রকর্ম প্রশংসিত হয়েছে।
# POS Tags B: [('তার', 'PRP'), ('চিত্রকর্ম', None), ('প্রশংসিত', None), ('হয়েছে।', None)]
#
# Processing Pair 53:
# Sentence A: আজকের দিনটি উজ্জ্বল।
# POS Tags A: [('আজকের', 'NN'), ('দিনটি', None), ('উজ্জ্বল।', None)]
# Sentence B: আলো দিনের ছোঁয়া মুগ্ধকর।
# POS Tags B: [('আলো', 'NN'), ('দিনের', 'NN'), ('ছোঁয়া', None), ('মুগ্ধকর।', None)]
#
# Processing Pair 54:
# Sentence A: সে প্রাকৃতিক সঙ্গীত উপভোগ করে।
# POS Tags A: [('সে', 'PRP'), ('প্রাকৃতিক', None), ('সঙ্গীত', None), ('উপভোগ', None), ('করে।', None)]
# Sentence B: প্রকৃতির শব্দ তার মনের প্রশান্তি দেয়।
# POS Tags B: [('প্রকৃতির', None), ('শব্দ', 'NN'), ('তার', 'PRP'), ('মনের', 'NN'), ('প্রশান্তি', None), ('দেয়।', None)]
#
# Processing Pair 55:
# Sentence A: আমি ভ্রমণ পছন্দ করি।
# POS Tags A: [('আমি', 'PRP'), ('ভ্রমণ', None), ('পছন্দ', 'NN'), ('করি।', None)]
# Sentence B: নতুন জায়গা অন্বেষণ আমার রুচির।
# POS Tags B: [('নতুন', 'JJ'), ('জায়গা', None), ('অন্বেষণ', None), ('আমার', 'PRP'), ('রুচির।', None)]
#
# Processing Pair 56:
# Sentence A: সে তার ডায়েরি লিখে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('ডায়েরি', None), ('লিখে।', None)]
# Sentence B: তার প্রতিদিনের অভিজ্ঞতা বইতে রূপান্তরিত।
# POS Tags B: [('তার', 'PRP'), ('প্রতিদিনের', None), ('অভিজ্ঞতা', None), ('বইতে', None), ('রূপান্তরিত।', None)]
#
# Processing Pair 57:
# Sentence A: আজকের সকালের বাতাস সতেজ।
# POS Tags A: [('আজকের', 'NN'), ('সকালের', None), ('বাতাস', None), ('সতেজ।', None)]
# Sentence B: সকালে হাওয়া প্রাণবন্ত।
# POS Tags B: [('সকালে', None), ('হাওয়া', None), ('প্রাণবন্ত।', None)]
#
# Processing Pair 58:
# Sentence A: সে তার নতুন ব্লগ শুরু করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('নতুন', 'JJ'), ('ব্লগ', None), ('শুরু', 'NN'), ('করেছে।', None)]
# Sentence B: তার লেখাগুলি অনন্য অভিজ্ঞতা প্রকাশ করে।
# POS Tags B: [('তার', 'PRP'), ('লেখাগুলি', None), ('অনন্য', None), ('অভিজ্ঞতা', None), ('প্রকাশ', 'NN'), ('করে।', None)]
#
# Processing Pair 59:
# Sentence A: আমি সাপ্তাহিক বাজারে যাই।
# POS Tags A: [('আমি', 'PRP'), ('সাপ্তাহিক', None), ('বাজারে', None), ('যাই।', None)]
# Sentence B: বাজারের রঙিনতা আমাকে মুগ্ধ করে।
# POS Tags B: [('বাজারের', 'NN'), ('রঙিনতা', None), ('আমাকে', 'PRP'), ('মুগ্ধ', None), ('করে।', None)]
#
# Processing Pair 60:
# Sentence A: সে তার প্রিয় গান গায়।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রিয়', None), ('গান', 'NN'), ('গায়।', None)]
# Sentence B: তার সুরেলা কণ্ঠস্বর সবাইকে আকৃষ্ট করে।
# POS Tags B: [('তার', 'PRP'), ('সুরেলা', None), ('কণ্ঠস্বর', None), ('সবাইকে', 'PRP'), ('আকৃষ্ট', None), ('করে।', None)]
#
# Processing Pair 61:
# Sentence A: আজকের মিটিং সফল হয়েছে।
# POS Tags A: [('আজকের', 'NN'), ('মিটিং', None), ('সফল', 'JJ'), ('হয়েছে।', None)]
# Sentence B: আলোচনায় সবাই সম্মত হয়েছে।
# POS Tags B: [('আলোচনায়', None), ('সবাই', 'PRP'), ('সম্মত', None), ('হয়েছে।', None)]
#
# Processing Pair 62:
# Sentence A: সে নতুন বন্ধু বানিয়েছে।
# POS Tags A: [('সে', 'PRP'), ('নতুন', 'JJ'), ('বন্ধু', 'NN'), ('বানিয়েছে।', None)]
# Sentence B: তার সামাজিকতা চমৎকার।
# POS Tags B: [('তার', 'PRP'), ('সামাজিকতা', None), ('চমৎকার।', None)]
#
# Processing Pair 63:
# Sentence A: আমি প্রাকৃতিক দৃশ্যের ছবি তুলি।
# POS Tags A: [('আমি', 'PRP'), ('প্রাকৃতিক', None), ('দৃশ্যের', None), ('ছবি', 'NN'), ('তুলি।', None)]
# Sentence B: ফটোগ্রাফি আমার শখ।
# POS Tags B: [('ফটোগ্রাফি', None), ('আমার', 'PRP'), ('শখ।', None)]
#
# Processing Pair 64:
# Sentence A: সে তার প্রোজেক্টে পরিশ্রম করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রোজেক্টে', None), ('পরিশ্রম', 'NN'), ('করেছে।', None)]
# Sentence B: তার কাজের ফলাফল সন্তোষজনক।
# POS Tags B: [('তার', 'PRP'), ('কাজের', 'NN'), ('ফলাফল', None), ('সন্তোষজনক।', None)]
#
# Processing Pair 65:
# Sentence A: আজকের খাওয়াদাওয়া সুস্বাদু।
# POS Tags A: [('আজকের', 'NN'), ('খাওয়াদাওয়া', None), ('সুস্বাদু।', None)]
# Sentence B: ভোজনের স্বাদ একেবারে মনোমুগ্ধকর।
# POS Tags B: [('ভোজনের', None), ('স্বাদ', 'NN'), ('একেবারে', 'RB'), ('মনোমুগ্ধকর।', None)]
#
# Processing Pair 66:
# Sentence A: সে তার কর্মক্ষেত্রে সফল হয়েছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('কর্মক্ষেত্রে', None), ('সফল', 'JJ'), ('হয়েছে।', None)]
# Sentence B: তার প্রফেশনাল জীবন উজ্জ্বল।
# POS Tags B: [('তার', 'PRP'), ('প্রফেশনাল', None), ('জীবন', 'NN'), ('উজ্জ্বল।', None)]
#
# Processing Pair 67:
# Sentence A: আমি প্রতিদিন সাঁতার কাটি।
# POS Tags A: [('আমি', 'PRP'), ('প্রতিদিন', None), ('সাঁতার', None), ('কাটি।', None)]
# Sentence B: সাঁতার আমার শরীরকে সুস্থ রাখে।
# POS Tags B: [('সাঁতার', None), ('আমার', 'PRP'), ('শরীরকে', None), ('সুস্থ', None), ('রাখে।', None)]
#
# Processing Pair 68:
# Sentence A: সে তার বাড়ির ছাদে বসে গল্প করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('বাড়ির', 'NN'), ('ছাদে', None), ('বসে', 'VM'), ('গল্প', None), ('করে।', None)]
# Sentence B: তার রাত্রির আলাপ সবাইকে মুগ্ধ করে।
# POS Tags B: [('তার', 'PRP'), ('রাত্রির', 'NN'), ('আলাপ', None), ('সবাইকে', 'PRP'), ('মুগ্ধ', None), ('করে।', None)]
#
# Processing Pair 69:
# Sentence A: আজকের পাঠ্যসূচি অত্যন্ত তথ্যবহুল।
# POS Tags A: [('আজকের', 'NN'), ('পাঠ্যসূচি', None), ('অত্যন্ত', 'INTF'), ('তথ্যবহুল।', None)]
# Sentence B: শিক্ষা আজকের আলোচনার কেন্দ্রবিন্দু।
# POS Tags B: [('শিক্ষা', 'NN'), ('আজকের', 'NN'), ('আলোচনার', None), ('কেন্দ্রবিন্দু।', None)]
#
# Processing Pair 70:
# Sentence A: সে তার প্রতিদিনের অভ্যাস রেকর্ড করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রতিদিনের', None), ('অভ্যাস', None), ('রেকর্ড', None), ('করে।', None)]
# Sentence B: তার ডায়েরিতে প্রতিটি দিন সংরক্ষিত।
# POS Tags B: [('তার', 'PRP'), ('ডায়েরিতে', None), ('প্রতিটি', 'QF'), ('দিন', 'NN'), ('সংরক্ষিত।', None)]
#
# Processing Pair 71:
# Sentence A: আমি আমার প্রিয় সঙ্গীত শুনি।
# POS Tags A: [('আমি', 'PRP'), ('আমার', 'PRP'), ('প্রিয়', None), ('সঙ্গীত', None), ('শুনি।', None)]
# Sentence B: সঙ্গীত আমার জীবনের সুর।
# POS Tags B: [('সঙ্গীত', None), ('আমার', 'PRP'), ('জীবনের', 'NN'), ('সুর।', None)]
#
# Processing Pair 72:
# Sentence A: সে তার মোবাইল ফোন আপডেট করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('মোবাইল', None), ('ফোন', None), ('আপডেট', None), ('করেছে।', None)]
# Sentence B: তার টেকনোলজি ভালোভাবে পরিচালিত।
# POS Tags B: [('তার', 'PRP'), ('টেকনোলজি', None), ('ভালোভাবে', 'RB'), ('পরিচালিত।', None)]
#
# Processing Pair 73:
# Sentence A: আজকের সন্ধ্যা একেবারে মনোমুগ্ধকর।
# POS Tags A: [('আজকের', 'NN'), ('সন্ধ্যা', None), ('একেবারে', 'RB'), ('মনোমুগ্ধকর।', None)]
# Sentence B: সন্ধ্যার আলো আমাকে মুগ্ধ করে।
# POS Tags B: [('সন্ধ্যার', None), ('আলো', 'NN'), ('আমাকে', 'PRP'), ('মুগ্ধ', None), ('করে।', None)]
#
# Processing Pair 74:
# Sentence A: সে তার প্রোগ্রামিং কোড লিখেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রোগ্রামিং', None), ('কোড', None), ('লিখেছে।', None)]
# Sentence B: তার সফটওয়্যার দক্ষতা অসাধারণ।
# POS Tags B: [('তার', 'PRP'), ('সফটওয়্যার', None), ('দক্ষতা', None), ('অসাধারণ।', None)]
#
# Processing Pair 75:
# Sentence A: আমি নতুন রেসিপি চেষ্টা করি।
# POS Tags A: [('আমি', 'PRP'), ('নতুন', 'JJ'), ('রেসিপি', None), ('চেষ্টা', 'NN'), ('করি।', None)]
# Sentence B: রান্নাঘরে নতুনত্ব আমার সৃজনশীলতা।
# POS Tags B: [('রান্নাঘরে', None), ('নতুনত্ব', None), ('আমার', 'PRP'), ('সৃজনশীলতা।', None)]
#
# Processing Pair 76:
# Sentence A: সে তার গাড়ি পরিষ্কার করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('গাড়ি', None), ('পরিষ্কার', 'NN'), ('করেছে।', None)]
# Sentence B: তার যানবাহন ঝকঝকে করে তুলেছে।
# POS Tags B: [('তার', 'PRP'), ('যানবাহন', None), ('ঝকঝকে', None), ('করে', 'VM'), ('তুলেছে।', None)]
#
# Processing Pair 77:
# Sentence A: আজকের আবহাওয়া চমৎকার।
# POS Tags A: [('আজকের', 'NN'), ('আবহাওয়া', None), ('চমৎকার।', None)]
# Sentence B: আকাশে রৌদ্রের উজ্জ্বলতা স্পষ্ট।
# POS Tags B: [('আকাশে', 'NN'), ('রৌদ্রের', None), ('উজ্জ্বলতা', None), ('স্পষ্ট।', None)]
#
# Processing Pair 78:
# Sentence A: সে তার প্রতিযোগিতায় জয়ী হয়েছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রতিযোগিতায়', None), ('জয়ী', None), ('হয়েছে।', None)]
# Sentence B: তার কঠোর পরিশ্রম ফলপ্রসূ হয়েছে।
# POS Tags B: [('তার', 'PRP'), ('কঠোর', None), ('পরিশ্রম', 'NN'), ('ফলপ্রসূ', None), ('হয়েছে।', None)]
#
# Processing Pair 79:
# Sentence A: আমি বইয়ের দোকানে ভ্রমণ করি।
# POS Tags A: [('আমি', 'PRP'), ('বইয়ের', None), ('দোকানে', 'NN'), ('ভ্রমণ', None), ('করি।', None)]
# Sentence B: নতুন বই আমার আনন্দের উৎস।
# POS Tags B: [('নতুন', 'JJ'), ('বই', 'NN'), ('আমার', 'PRP'), ('আনন্দের', 'NN'), ('উৎস।', None)]
#
# Processing Pair 80:
# Sentence A: সে তার পরীক্ষায় উচ্চতম নম্বর অর্জন করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('পরীক্ষায়', None), ('উচ্চতম', None), ('নম্বর', None), ('অর্জন', None), ('করেছে।', None)]
# Sentence B: তার অধ্যবসায় সফলতার চাবিকাঠি।
# POS Tags B: [('তার', 'PRP'), ('অধ্যবসায়', None), ('সফলতার', None), ('চাবিকাঠি।', None)]
#
# Processing Pair 81:
# Sentence A: আজকের রাত্রি নিরিবিলি।
# POS Tags A: [('আজকের', 'NN'), ('রাত্রি', 'NN'), ('নিরিবিলি।', None)]
# Sentence B: চাঁদের আলো শান্তির বার্তা দেয়।
# POS Tags B: [('চাঁদের', None), ('আলো', 'NN'), ('শান্তির', None), ('বার্তা', 'NN'), ('দেয়।', None)]
#
# Processing Pair 82:
# Sentence A: সে তার প্রজেক্টের উপস্থাপনা দিয়েছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রজেক্টের', None), ('উপস্থাপনা', None), ('দিয়েছে।', None)]
# Sentence B: তার বক্তব্য সবাইকে অনুপ্রাণিত করেছে।
# POS Tags B: [('তার', 'PRP'), ('বক্তব্য', 'NN'), ('সবাইকে', 'PRP'), ('অনুপ্রাণিত', None), ('করেছে।', None)]
#
# Processing Pair 83:
# Sentence A: আমি পার্কে দৌড়াদৌড়ি করি।
# POS Tags A: [('আমি', 'PRP'), ('পার্কে', None), ('দৌড়াদৌড়ি', None), ('করি।', None)]
# Sentence B: ব্যায়াম আমার স্বাস্থ্য রক্ষায় সহায়ক।
# POS Tags B: [('ব্যায়াম', None), ('আমার', 'PRP'), ('স্বাস্থ্য', None), ('রক্ষায়', None), ('সহায়ক।', None)]
#
# Processing Pair 84:
# Sentence A: সে তার যাত্রার গল্প শেয়ার করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('যাত্রার', None), ('গল্প', None), ('শেয়ার', None), ('করে।', None)]
# Sentence B: তার অভিজ্ঞতা সকলের জন্য প্রেরণাদায়ক।
# POS Tags B: [('তার', 'PRP'), ('অভিজ্ঞতা', None), ('সকলের', 'PRP'), ('জন্য', 'PSP'), ('প্রেরণাদায়ক।', None)]
#
# Processing Pair 85:
# Sentence A: আজকের সকালে পাখির গান শুনি।
# POS Tags A: [('আজকের', 'NN'), ('সকালে', None), ('পাখির', None), ('গান', 'NN'), ('শুনি।', None)]
# Sentence B: প্রকৃতির সুর আমার মনকে ছুঁয়ে যায়।
# POS Tags B: [('প্রকৃতির', None), ('সুর', 'NN'), ('আমার', 'PRP'), ('মনকে', None), ('ছুঁয়ে', None), ('যায়।', None)]
#
# Processing Pair 86:
# Sentence A: সে তার সৃজনশীল কাজ প্রদর্শন করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('সৃজনশীল', None), ('কাজ', 'NN'), ('প্রদর্শন', None), ('করে।', None)]
# Sentence B: তার শিল্পকর্ম সকলের নজর কেড়ে নেয়।
# POS Tags B: [('তার', 'PRP'), ('শিল্পকর্ম', None), ('সকলের', 'PRP'), ('নজর', None), ('কেড়ে', None), ('নেয়।', None)]
#
# Processing Pair 87:
# Sentence A: আমি ট্রেনের মাধ্যমে ভ্রমণ করি।
# POS Tags A: [('আমি', 'PRP'), ('ট্রেনের', None), ('মাধ্যমে', 'PSP'), ('ভ্রমণ', None), ('করি।', None)]
# Sentence B: যাত্রাপথের অভিজ্ঞতা অনন্য।
# POS Tags B: [('যাত্রাপথের', None), ('অভিজ্ঞতা', None), ('অনন্য।', None)]
#
# Processing Pair 88:
# Sentence A: সে তার অফিসে সময়মত পৌঁছায়।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('অফিসে', None), ('সময়মত', None), ('পৌঁছায়।', None)]
# Sentence B: তার পেশাগত দায়িত্ব পালনে দক্ষ।
# POS Tags B: [('তার', 'PRP'), ('পেশাগত', None), ('দায়িত্ব', None), ('পালনে', None), ('দক্ষ।', None)]
#
# Processing Pair 89:
# Sentence A: আজকের দুপুরের খাবার স্বাস্থ্যকর।
# POS Tags A: [('আজকের', 'NN'), ('দুপুরের', None), ('খাবার', None), ('স্বাস্থ্যকর।', None)]
# Sentence B: পুষ্টিকর আহার আমার শক্তির উৎস।
# POS Tags B: [('পুষ্টিকর', None), ('আহার', None), ('আমার', 'PRP'), ('শক্তির', None), ('উৎস।', None)]
#
# Processing Pair 90:
# Sentence A: সে তার স্কুলে নতুন পরিকল্পনা উপস্থাপন করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('স্কুলে', None), ('নতুন', 'JJ'), ('পরিকল্পনা', None), ('উপস্থাপন', None), ('করে।', None)]
# Sentence B: তার আইডিয়া সকলকে অনুপ্রাণিত করে।
# POS Tags B: [('তার', 'PRP'), ('আইডিয়া', None), ('সকলকে', None), ('অনুপ্রাণিত', None), ('করে।', None)]
#
# Processing Pair 91:
# Sentence A: আমি সাপ্তাহিক বাজারে তাজা ফল কিনি।
# POS Tags A: [('আমি', 'PRP'), ('সাপ্তাহিক', None), ('বাজারে', None), ('তাজা', None), ('ফল', 'NN'), ('কিনি।', None)]
# Sentence B: ফল আমার দিনের তাজা উপাদান।
# POS Tags B: [('ফল', 'NN'), ('আমার', 'PRP'), ('দিনের', 'NN'), ('তাজা', None), ('উপাদান।', None)]
#
# Processing Pair 92:
# Sentence A: সে তার বাড়ির সামনে পেইন্টিং করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('বাড়ির', 'NN'), ('সামনে', 'NST'), ('পেইন্টিং', None), ('করে।', None)]
# Sentence B: তার রংয়ের সমাহার মনোমুগ্ধকর।
# POS Tags B: [('তার', 'PRP'), ('রংয়ের', None), ('সমাহার', None), ('মনোমুগ্ধকর।', None)]
#
# Processing Pair 93:
# Sentence A: আজকের রাতের খাওয়াদাওয়া মনোরম।
# POS Tags A: [('আজকের', 'NN'), ('রাতের', 'NN'), ('খাওয়াদাওয়া', None), ('মনোরম।', None)]
# Sentence B: ভোজনের সাথেই মিলনের মুহূর্ত সৃষ্টি হয়।
# POS Tags B: [('ভোজনের', None), ('সাথেই', None), ('মিলনের', None), ('মুহূর্ত', None), ('সৃষ্টি', 'NN'), ('হয়।', None)]
#
# Processing Pair 94:
# Sentence A: সে তার প্রিয় ব্লগে নতুন পোস্ট লিখেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রিয়', None), ('ব্লগে', None), ('নতুন', 'JJ'), ('পোস্ট', None), ('লিখেছে।', None)]
# Sentence B: তার লেখাগুলি পাঠকদের আনন্দ দেয়।
# POS Tags B: [('তার', 'PRP'), ('লেখাগুলি', None), ('পাঠকদের', 'NN'), ('আনন্দ', 'NN'), ('দেয়।', None)]
#
# Processing Pair 95:
# Sentence A: আমি প্রতিদিন কিছু না কিছু শিখি।
# POS Tags A: [('আমি', 'PRP'), ('প্রতিদিন', None), ('কিছু', 'QF'), ('না', 'NEG'), ('কিছু', 'QF'), ('শিখি।', None)]
# Sentence B: শিক্ষা আমার জীবনের অংশ।
# POS Tags B: [('শিক্ষা', 'NN'), ('আমার', 'PRP'), ('জীবনের', 'NN'), ('অংশ।', None)]
#
# Processing Pair 96:
# Sentence A: সে তার বন্ধুদের সাথে খেলা করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('বন্ধুদের', 'NN'), ('সাথে', 'PSP'), ('খেলা', None), ('করে।', None)]
# Sentence B: তার হাসিখুশি মিলনের সময়।
# POS Tags B: [('তার', 'PRP'), ('হাসিখুশি', None), ('মিলনের', None), ('সময়।', None)]
#
# Processing Pair 97:
# Sentence A: আজকের সকালের আর্দ্রতা স্বচ্ছ।
# POS Tags A: [('আজকের', 'NN'), ('সকালের', None), ('আর্দ্রতা', None), ('স্বচ্ছ।', None)]
# Sentence B: সকালে মাটির গন্ধ প্রশান্তিদায়ক।
# POS Tags B: [('সকালে', None), ('মাটির', 'NN'), ('গন্ধ', 'NN'), ('প্রশান্তিদায়ক।', None)]
#
# Processing Pair 98:
# Sentence A: সে তার সৃজনশীল ধারণা প্রকাশ করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('সৃজনশীল', None), ('ধারণা', 'NN'), ('প্রকাশ', 'NN'), ('করে।', None)]
# Sentence B: তার আইডিয়া সত্যিই অনন্য।
# POS Tags B: [('তার', 'PRP'), ('আইডিয়া', None), ('সত্যিই', 'RB'), ('অনন্য।', None)]
#
# Processing Pair 99:
# Sentence A: আমি তারাতারি রান্না করি।
# POS Tags A: [('আমি', 'PRP'), ('তারাতারি', None), ('রান্না', 'NN'), ('করি।', None)]
# Sentence B: রান্নাঘরে তাড়াতাড়ি স্বাদের খোঁজ।
# POS Tags B: [('রান্নাঘরে', None), ('তাড়াতাড়ি', 'RB'), ('স্বাদের', None), ('খোঁজ।', None)]
#
# Processing Pair 100:
# Sentence A: সে তার যন্ত্রপাতি ঠিক করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('যন্ত্রপাতি', None), ('ঠিক', 'RB'), ('করে।', None)]
# Sentence B: তার মেকানিক্যাল কাজ দক্ষতার পরিচয় দেয়।
# POS Tags B: [('তার', 'PRP'), ('মেকানিক্যাল', None), ('কাজ', 'NN'), ('দক্ষতার', None), ('পরিচয়', None), ('দেয়।', None)]
#
# Processing Pair 101:
# Sentence A: আজকের দিনটি উদযাপনের মতো।
# POS Tags A: [('আজকের', 'NN'), ('দিনটি', None), ('উদযাপনের', None), ('মতো।', None)]
# Sentence B: উৎসবমুখর পরিবেশ সবাইকে আনন্দ দেয়।
# POS Tags B: [('উৎসবমুখর', None), ('পরিবেশ', None), ('সবাইকে', 'PRP'), ('আনন্দ', 'NN'), ('দেয়।', None)]
#
# Processing Pair 102:
# Sentence A: সে তার স্বপ্নের চাকরি পেয়েছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('স্বপ্নের', None), ('চাকরি', 'NN'), ('পেয়েছে।', None)]
# Sentence B: তার পরিশ্রম সফলতার ফল।
# POS Tags B: [('তার', 'PRP'), ('পরিশ্রম', 'NN'), ('সফলতার', None), ('ফল।', None)]
#
# Processing Pair 103:
# Sentence A: আমি প্রাকৃতিক দৃশ্য উপভোগ করি।
# POS Tags A: [('আমি', 'PRP'), ('প্রাকৃতিক', None), ('দৃশ্য', None), ('উপভোগ', None), ('করি।', None)]
# Sentence B: প্রকৃতির সৌন্দর্য আমাকে মুগ্ধ করে।
# POS Tags B: [('প্রকৃতির', None), ('সৌন্দর্য', None), ('আমাকে', 'PRP'), ('মুগ্ধ', None), ('করে।', None)]
#
# Processing Pair 104:
# Sentence A: সে তার কর্মজীবনে উদ্যমী।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('কর্মজীবনে', None), ('উদ্যমী।', None)]
# Sentence B: তার কাজের প্রতি নিবেদিত মনোভাব প্রশংসনীয়।
# POS Tags B: [('তার', 'PRP'), ('কাজের', 'NN'), ('প্রতি', 'QF'), ('নিবেদিত', None), ('মনোভাব', None), ('প্রশংসনীয়।', None)]
#
# Processing Pair 105:
# Sentence A: আজকের আলো সকালে একেবারে দীপ্ত।
# POS Tags A: [('আজকের', 'NN'), ('আলো', 'NN'), ('সকালে', None), ('একেবারে', 'RB'), ('দীপ্ত।', None)]
# Sentence B: সকালের সূর্যোদয় মনোহর।
# POS Tags B: [('সকালের', None), ('সূর্যোদয়', None), ('মনোহর।', None)]
#
# Processing Pair 106:
# Sentence A: সে তার প্রোজেক্টে সৃজনশীলতা দেখায়।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রোজেক্টে', None), ('সৃজনশীলতা', None), ('দেখায়।', None)]
# Sentence B: তার কাজের নতুনত্ব সবাইকে আকৃষ্ট করে।
# POS Tags B: [('তার', 'PRP'), ('কাজের', 'NN'), ('নতুনত্ব', None), ('সবাইকে', 'PRP'), ('আকৃষ্ট', None), ('করে।', None)]
#
# Processing Pair 107:
# Sentence A: আমি প্রতিদিন নতুন কিছু জানি।
# POS Tags A: [('আমি', 'PRP'), ('প্রতিদিন', None), ('নতুন', 'JJ'), ('কিছু', 'QF'), ('জানি।', None)]
# Sentence B: জ্ঞান আমার জীবনের আলো।
# POS Tags B: [('জ্ঞান', 'XC'), ('আমার', 'PRP'), ('জীবনের', 'NN'), ('আলো।', None)]
#
# Processing Pair 108:
# Sentence A: সে তার সৃজনশীলতা নিয়ে কাজ করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('সৃজনশীলতা', None), ('নিয়ে', None), ('কাজ', 'NN'), ('করে।', None)]
# Sentence B: তার নতুন ধারণা প্রত্যাশিত।
# POS Tags B: [('তার', 'PRP'), ('নতুন', 'JJ'), ('ধারণা', 'NN'), ('প্রত্যাশিত।', None)]
#
# Processing Pair 109:
# Sentence A: আজকের আবহাওয়া আনন্দদায়ক।
# POS Tags A: [('আজকের', 'NN'), ('আবহাওয়া', None), ('আনন্দদায়ক।', None)]
# Sentence B: প্রকৃতির ছোঁয়া আমাকে প্রশান্ত করে।
# POS Tags B: [('প্রকৃতির', None), ('ছোঁয়া', None), ('আমাকে', 'PRP'), ('প্রশান্ত', None), ('করে।', None)]
#
# Processing Pair 110:
# Sentence A: সে তার দৈনন্দিন কাজ নিয়মিত সম্পন্ন করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('দৈনন্দিন', None), ('কাজ', 'NN'), ('নিয়মিত', None), ('সম্পন্ন', 'JJ'), ('করে।', None)]
# Sentence B: তার শৃঙ্খলাবদ্ধতা মুগ্ধকর।
# POS Tags B: [('তার', 'PRP'), ('শৃঙ্খলাবদ্ধতা', None), ('মুগ্ধকর।', None)]
#
# Processing Pair 111:
# Sentence A: আমি নতুন বই পড়ার অভিজ্ঞতা সংগ্রহ করি।
# POS Tags A: [('আমি', 'PRP'), ('নতুন', 'JJ'), ('বই', 'NN'), ('পড়ার', None), ('অভিজ্ঞতা', None), ('সংগ্রহ', 'NN'), ('করি।', None)]
# Sentence B: পাঠ্যবই আমার মনের খোরাক।
# POS Tags B: [('পাঠ্যবই', None), ('আমার', 'PRP'), ('মনের', 'NN'), ('খোরাক।', None)]
#
# Processing Pair 112:
# Sentence A: সে তার অফিসের কাজ সাবলীলভাবে সম্পন্ন করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('অফিসের', None), ('কাজ', 'NN'), ('সাবলীলভাবে', None), ('সম্পন্ন', 'JJ'), ('করে।', None)]
# Sentence B: তার পেশাগত দক্ষতা সবাইকে অনুপ্রাণিত করে।
# POS Tags B: [('তার', 'PRP'), ('পেশাগত', None), ('দক্ষতা', None), ('সবাইকে', 'PRP'), ('অনুপ্রাণিত', None), ('করে।', None)]
#
# Processing Pair 113:
# Sentence A: আজকের দিনের আলো উজ্জ্বল।
# POS Tags A: [('আজকের', 'NN'), ('দিনের', 'NN'), ('আলো', 'NN'), ('উজ্জ্বল।', None)]
# Sentence B: সকালে রৌদ্রের আলোকসজ্জা মনোমুগ্ধকর।
# POS Tags B: [('সকালে', None), ('রৌদ্রের', None), ('আলোকসজ্জা', None), ('মনোমুগ্ধকর।', None)]
#
# Processing Pair 114:
# Sentence A: সে তার সৃজনশীল লেখালেখি করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('সৃজনশীল', None), ('লেখালেখি', None), ('করে।', None)]
# Sentence B: তার লেখা সকলকে ভাবতে বাধ্য করে।
# POS Tags B: [('তার', 'PRP'), ('লেখা', 'VM'), ('সকলকে', None), ('ভাবতে', 'VM'), ('বাধ্য', 'JJ'), ('করে।', None)]
#
# Processing Pair 115:
# Sentence A: আমি সৃজনশীল কাজের প্রতি উৎসাহী।
# POS Tags A: [('আমি', 'PRP'), ('সৃজনশীল', None), ('কাজের', 'NN'), ('প্রতি', 'QF'), ('উৎসাহী।', None)]
# Sentence B: আমার সৃজনশীলতা আমার পরিচয়।
# POS Tags B: [('আমার', 'PRP'), ('সৃজনশীলতা', None), ('আমার', 'PRP'), ('পরিচয়।', None)]
#
# Processing Pair 116:
# Sentence A: সে তার প্রিয় সঙ্গীতে মগ্ন।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রিয়', None), ('সঙ্গীতে', None), ('মগ্ন।', None)]
# Sentence B: তার সুরেলা কণ্ঠস্বর সবাইকে স্পর্শ করে।
# POS Tags B: [('তার', 'PRP'), ('সুরেলা', None), ('কণ্ঠস্বর', None), ('সবাইকে', 'PRP'), ('স্পর্শ', 'NN'), ('করে।', None)]
#
# Processing Pair 117:
# Sentence A: আজকের দিনটি উদ্দীপ্ত।
# POS Tags A: [('আজকের', 'NN'), ('দিনটি', None), ('উদ্দীপ্ত।', None)]
# Sentence B: আলো দিনের ছোঁয়ায় মন ভালো হয়ে যায়।
# POS Tags B: [('আলো', 'NN'), ('দিনের', 'NN'), ('ছোঁয়ায়', None), ('মন', 'NN'), ('ভালো', 'JJ'), ('হয়ে', None), ('যায়।', None)]
#
# Processing Pair 118:
# Sentence A: সে তার নতুন পরিকল্পনা নিয়ে আলোচনা করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('নতুন', 'JJ'), ('পরিকল্পনা', None), ('নিয়ে', None), ('আলোচনা', 'NN'), ('করে।', None)]
# Sentence B: তার আইডিয়া দলের সকলকে অনুপ্রাণিত করে।
# POS Tags B: [('তার', 'PRP'), ('আইডিয়া', None), ('দলের', None), ('সকলকে', None), ('অনুপ্রাণিত', None), ('করে।', None)]
#
# Processing Pair 119:
# Sentence A: আমি প্রতিদিন প্রাকৃতিক পরিবেশে ভ্রমণ করি।
# POS Tags A: [('আমি', 'PRP'), ('প্রতিদিন', None), ('প্রাকৃতিক', None), ('পরিবেশে', None), ('ভ্রমণ', None), ('করি।', None)]
# Sentence B: প্রকৃতির সৌন্দর্য আমাকে রোমাঞ্চিত করে।
# POS Tags B: [('প্রকৃতির', None), ('সৌন্দর্য', None), ('আমাকে', 'PRP'), ('রোমাঞ্চিত', None), ('করে।', None)]
#
# Processing Pair 120:
# Sentence A: সে শহরে দ্রুত চলাফেরা করে।
# POS Tags A: [('সে', 'PRP'), ('শহরে', None), ('দ্রুত', None), ('চলাফেরা', 'NN'), ('করে।', None)]
# Sentence B: শহরের চাঞ্চল্য তার মনকে উদ্দীপিত করে।
# POS Tags B: [('শহরের', None), ('চাঞ্চল্য', None), ('তার', 'PRP'), ('মনকে', None), ('উদ্দীপিত', None), ('করে।', None)]

# %%
from gensim.models import FastText

# Build a corpus by tokenizing both Sentence1 and Sentence2 of each pair
corpus = []
for _, row in df.iterrows():
    corpus.append(tokenize_bengali(row["Sentence1"]))
    corpus.append(tokenize_bengali(row["Sentence2"]))

print("Total sentences in corpus:", len(corpus))
print("Example tokenized sentence from corpus:", corpus[0])

# Train a FastText model on the corpus
fasttext_model = FastText(
    sentences=corpus,
    vector_size=50,   # Adjust vector size as needed
    window=3,
    min_count=1,      # Using min_count=1 because our dataset is small
    epochs=20
)

print("FastText model trained successfully!")
print("Vocabulary size:", len(fasttext_model.wv))
# Out:
# Total sentences in corpus: 240
# Example tokenized sentence from corpus: ['আমি', 'বই', 'পড়ি']
# FastText model trained successfully!
# Vocabulary size: 494

# %%
import nltk
import numpy as np

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
def select_relevant_words(pos_tags):
    """
    Selects relevant words (nouns, verbs, adjectives, adverbs).
    Falls back to all tokens if no relevant words are found.
    """
    relevant_tags = {"NN", "VM", "JJ", "RB"}  # Content-bearing POS tags
    relevant_words = [word for word, tag in pos_tags if tag in relevant_tags]

    # If no relevant words found, use all words
    if not relevant_words:
        relevant_words = [word for word, _ in pos_tags]

    return relevant_words

print("select_relevant_words function defined successfully!")
# Out:
# select_relevant_words function defined successfully!

# %%
def compute_wmd(words_a, words_b, model):
    """
    Computes the Word Mover's Distance (WMD) between two lists of words using the model.
    Assumes both lists are non-empty due to preprocessing.
    """
    return model.wv.wmdistance(words_a, words_b)

print("compute_wmd function defined successfully!")
# Out:
# compute_wmd function defined successfully!

# %%
def compute_owms(owmd_score):
    """
    Converts OWMD dissimilarity score into OWMS similarity score using the exponential function.
    """
    return np.exp(-owmd_score)

print("compute_owms function defined successfully!")
# Out:
# compute_owms function defined successfully!

# %%
# Ensure df is already defined before running this block
print("Starting OWMD computation...")

for idx, row in df.iterrows():
    pair_num = idx + 1
    sent_a = row["Sentence1"]
    sent_b = row["Sentence2"]

    print(f"\nProcessing Pair {pair_num}:")

    # Tokenize and POS tag each sentence
    tokens_a = nltk.word_tokenize(sent_a)
    tokens_b = nltk.word_tokenize(sent_b)
    pos_tags_a = bengali_tagger.tag(tokens_a)
    pos_tags_b = bengali_tagger.tag(tokens_b)

    print(f"Sentence A: {sent_a}")
    print(f"POS Tags A: {pos_tags_a}")
    print(f"Sentence B: {sent_b}")
    print(f"POS Tags B: {pos_tags_b}")

    # Select relevant words based on expanded POS tags
    relevant_words_a = select_relevant_words(pos_tags_a)
    relevant_words_b = select_relevant_words(pos_tags_b)

    print(f"Relevant Words A: {relevant_words_a}")
    print(f"Relevant Words B: {relevant_words_b}")

    # Compute OWMD using the selected relevant words
    owmd_score = compute_wmd(relevant_words_a, relevant_words_b, fasttext_model)

    # Compute OWMS (Optimized Word Mover's Similarity)
    owms_score = compute_owms(owmd_score)

    # Print OWMD and OWMS results
    print(f"Optimized Word Mover's Distance (OWMD): {owmd_score:.4f}")
    print(f"Optimized Word Mover's Similarity (OWMS): {owms_score:.4f}")
    print("-" * 50)

print("OWMD computation completed!")
# Out:
# Starting OWMD computation...
#
# Processing Pair 1:
# Sentence A: আমি বই পড়ি।
# POS Tags A: [('আমি', 'PRP'), ('বই', 'NN'), ('পড়ি।', None)]
# Sentence B: আমি গল্প পড়তে ভালোবাসি।
# POS Tags B: [('আমি', 'PRP'), ('গল্প', None), ('পড়তে', 'VM'), ('ভালোবাসি।', None)]
# Relevant Words A: ['বই']
# Relevant Words B: ['পড়তে']
# Optimized Word Mover's Distance (OWMD): 1.1561
# Optimized Word Mover's Similarity (OWMS): 0.3147
# --------------------------------------------------
#
# Processing Pair 2:
# Sentence A: সে বাজারে গিয়ে সবজি কিনেছিল।
# POS Tags A: [('সে', 'PRP'), ('বাজারে', None), ('গিয়ে', None), ('সবজি', 'NN'), ('কিনেছিল।', None)]
# Sentence B: সে সেরা সবজি সংগ্রহ করেছিল।
# POS Tags B: [('সে', 'PRP'), ('সেরা', None), ('সবজি', 'NN'), ('সংগ্রহ', 'NN'), ('করেছিল।', None)]
# Relevant Words A: ['সবজি']
# Relevant Words B: ['সবজি', 'সংগ্রহ']
# Optimized Word Mover's Distance (OWMD): 0.5176
# Optimized Word Mover's Similarity (OWMS): 0.5959
# --------------------------------------------------
#
# Processing Pair 3:
# Sentence A: আজ আকাশ স্পষ্ট।
# POS Tags A: [('আজ', 'NN'), ('আকাশ', 'NN'), ('স্পষ্ট।', None)]
# Sentence B: আজ দিনটি একেবারে পরিষ্কার।
# POS Tags B: [('আজ', 'NN'), ('দিনটি', None), ('একেবারে', 'RB'), ('পরিষ্কার।', None)]
# Relevant Words A: ['আজ', 'আকাশ']
# Relevant Words B: ['আজ', 'একেবারে']
# Optimized Word Mover's Distance (OWMD): 0.4223
# Optimized Word Mover's Similarity (OWMS): 0.6555
# --------------------------------------------------
#
# Processing Pair 4:
# Sentence A: আমরা সাঁতার কাটতে জলের কাছে গিয়েছিলাম।
# POS Tags A: [('আমরা', 'PRP'), ('সাঁতার', None), ('কাটতে', 'VM'), ('জলের', 'NN'), ('কাছে', 'NST'), ('গিয়েছিলাম।', None)]
# Sentence B: আমরা পুকুরের ধারে সাঁতার কাটার মজা নিয়েছিলাম।
# POS Tags B: [('আমরা', 'PRP'), ('পুকুরের', None), ('ধারে', None), ('সাঁতার', None), ('কাটার', 'VM'), ('মজা', None), ('নিয়েছিলাম।', None)]
# Relevant Words A: ['কাটতে', 'জলের']
# Relevant Words B: ['কাটার']
# Optimized Word Mover's Distance (OWMD): 0.4905
# Optimized Word Mover's Similarity (OWMS): 0.6123
# --------------------------------------------------
#
# Processing Pair 5:
# Sentence A: সে প্রতিদিন সকালে হাঁটে।
# POS Tags A: [('সে', 'PRP'), ('প্রতিদিন', None), ('সকালে', None), ('হাঁটে।', None)]
# Sentence B: সে দৈনিক হাঁটার অভ্যাস পোষণ করে।
# POS Tags B: [('সে', 'PRP'), ('দৈনিক', None), ('হাঁটার', None), ('অভ্যাস', None), ('পোষণ', None), ('করে।', None)]
# Relevant Words A: ['সে', 'প্রতিদিন', 'সকালে', 'হাঁটে।']
# Relevant Words B: ['সে', 'দৈনিক', 'হাঁটার', 'অভ্যাস', 'পোষণ', 'করে।']
# Optimized Word Mover's Distance (OWMD): 0.7807
# Optimized Word Mover's Similarity (OWMS): 0.4581
# --------------------------------------------------
#
# Processing Pair 6:
# Sentence A: বৃক্ষগুলি শীতে পাতলা হয়ে যায়।
# POS Tags A: [('বৃক্ষগুলি', None), ('শীতে', None), ('পাতলা', 'JJ'), ('হয়ে', None), ('যায়।', None)]
# Sentence B: শীতে গাছের পাতা ঝরে যায়।
# POS Tags B: [('শীতে', None), ('গাছের', 'NN'), ('পাতা', 'NN'), ('ঝরে', 'VM'), ('যায়।', None)]
# Relevant Words A: ['পাতলা']
# Relevant Words B: ['গাছের', 'পাতা', 'ঝরে']
# Optimized Word Mover's Distance (OWMD): 0.8900
# Optimized Word Mover's Similarity (OWMS): 0.4107
# --------------------------------------------------
#
# Processing Pair 7:
# Sentence A: সে তার চুল কাটিয়ে নতুন স্টাইল নিল।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('চুল', 'NN'), ('কাটিয়ে', None), ('নতুন', 'JJ'), ('স্টাইল', None), ('নিল।', None)]
# Sentence B: তার চুলের নতুন কাটা চেহারা আলাদা ছিল।
# POS Tags B: [('তার', 'PRP'), ('চুলের', None), ('নতুন', 'JJ'), ('কাটা', None), ('চেহারা', None), ('আলাদা', 'JJ'), ('ছিল।', None)]
# Relevant Words A: ['চুল', 'নতুন']
# Relevant Words B: ['নতুন', 'আলাদা']
# Optimized Word Mover's Distance (OWMD): 0.5739
# Optimized Word Mover's Similarity (OWMS): 0.5633
# --------------------------------------------------
#
# Processing Pair 8:
# Sentence A: আমি চা পান করতে পছন্দ করি।
# POS Tags A: [('আমি', 'PRP'), ('চা', None), ('পান', 'VM'), ('করতে', 'VM'), ('পছন্দ', 'NN'), ('করি।', None)]
# Sentence B: চা আমার প্রিয় পানীয়।
# POS Tags B: [('চা', None), ('আমার', 'PRP'), ('প্রিয়', None), ('পানীয়।', None)]
# Relevant Words A: ['পান', 'করতে', 'পছন্দ']
# Relevant Words B: ['চা', 'আমার', 'প্রিয়', 'পানীয়।']
# Optimized Word Mover's Distance (OWMD): 0.9193
# Optimized Word Mover's Similarity (OWMS): 0.3988
# --------------------------------------------------
#
# Processing Pair 9:
# Sentence A: ছেলেটি স্কুলে নতুন জুতো পরে।
# POS Tags A: [('ছেলেটি', None), ('স্কুলে', None), ('নতুন', 'JJ'), ('জুতো', None), ('পরে।', None)]
# Sentence B: স্কুলে তার নতুন জুতোর প্রশংসা হয়।
# POS Tags B: [('স্কুলে', None), ('তার', 'PRP'), ('নতুন', 'JJ'), ('জুতোর', None), ('প্রশংসা', None), ('হয়।', None)]
# Relevant Words A: ['নতুন']
# Relevant Words B: ['নতুন']
# Optimized Word Mover's Distance (OWMD): 0.0000
# Optimized Word Mover's Similarity (OWMS): 1.0000
# --------------------------------------------------
#
# Processing Pair 10:
# Sentence A: সে তার বাড়ির সামনে ফুল বাগান তৈরি করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('বাড়ির', 'NN'), ('সামনে', 'NST'), ('ফুল', 'NN'), ('বাগান', None), ('তৈরি', 'VM'), ('করেছে।', None)]
# Sentence B: তার বাড়ির পাশে একটি সুন্দর ফুলের বাগান আছে।
# POS Tags B: [('তার', 'PRP'), ('বাড়ির', 'NN'), ('পাশে', 'NST'), ('একটি', 'QC'), ('সুন্দর', 'JJ'), ('ফুলের', None), ('বাগান', None), ('আছে।', None)]
# Relevant Words A: ['বাড়ির', 'ফুল', 'তৈরি']
# Relevant Words B: ['বাড়ির', 'সুন্দর']
# Optimized Word Mover's Distance (OWMD): 0.6975
# Optimized Word Mover's Similarity (OWMS): 0.4978
# --------------------------------------------------
#
# Processing Pair 11:
# Sentence A: আমি গান শুনতে ভালোবাসি।
# POS Tags A: [('আমি', 'PRP'), ('গান', 'NN'), ('শুনতে', 'VM'), ('ভালোবাসি।', None)]
# Sentence B: সঙ্গীত আমার মনকে প্রশান্ত করে।
# POS Tags B: [('সঙ্গীত', None), ('আমার', 'PRP'), ('মনকে', None), ('প্রশান্ত', None), ('করে।', None)]
# Relevant Words A: ['গান', 'শুনতে']
# Relevant Words B: ['সঙ্গীত', 'আমার', 'মনকে', 'প্রশান্ত', 'করে।']
# Optimized Word Mover's Distance (OWMD): 0.7614
# Optimized Word Mover's Similarity (OWMS): 0.4670
# --------------------------------------------------
#
# Processing Pair 12:
# Sentence A: সে রাস্তায় সাবধানতার সাথে চলে।
# POS Tags A: [('সে', 'PRP'), ('রাস্তায়', None), ('সাবধানতার', None), ('সাথে', 'PSP'), ('চলে।', None)]
# Sentence B: সে পথ চলতে সতর্ক।
# POS Tags B: [('সে', 'PRP'), ('পথ', 'NN'), ('চলতে', 'VM'), ('সতর্ক।', None)]
# Relevant Words A: ['সে', 'রাস্তায়', 'সাবধানতার', 'সাথে', 'চলে।']
# Relevant Words B: ['পথ', 'চলতে']
# Optimized Word Mover's Distance (OWMD): 1.1483
# Optimized Word Mover's Similarity (OWMS): 0.3172
# --------------------------------------------------
#
# Processing Pair 13:
# Sentence A: আমাদের দলের খেলাটি জয়ী হয়েছিল।
# POS Tags A: [('আমাদের', 'PRP'), ('দলের', None), ('খেলাটি', None), ('জয়ী', None), ('হয়েছিল।', None)]
# Sentence B: আমরা খেলার মাধ্যমে বিজয় অর্জন করেছিলাম।
# POS Tags B: [('আমরা', 'PRP'), ('খেলার', None), ('মাধ্যমে', 'PSP'), ('বিজয়', None), ('অর্জন', None), ('করেছিলাম।', None)]
# Relevant Words A: ['আমাদের', 'দলের', 'খেলাটি', 'জয়ী', 'হয়েছিল।']
# Relevant Words B: ['আমরা', 'খেলার', 'মাধ্যমে', 'বিজয়', 'অর্জন', 'করেছিলাম।']
# Optimized Word Mover's Distance (OWMD): 0.6426
# Optimized Word Mover's Similarity (OWMS): 0.5259
# --------------------------------------------------
#
# Processing Pair 14:
# Sentence A: সে পেন্সিলে চিত্র আঁকে।
# POS Tags A: [('সে', 'PRP'), ('পেন্সিলে', None), ('চিত্র', 'NN'), ('আঁকে।', None)]
# Sentence B: তার অঙ্কন কাজটি খুবই মনোরম।
# POS Tags B: [('তার', 'PRP'), ('অঙ্কন', None), ('কাজটি', None), ('খুবই', 'RB'), ('মনোরম।', None)]
# Relevant Words A: ['চিত্র']
# Relevant Words B: ['খুবই']
# Optimized Word Mover's Distance (OWMD): 1.1026
# Optimized Word Mover's Similarity (OWMS): 0.3320
# --------------------------------------------------
#
# Processing Pair 15:
# Sentence A: রাস্তায় হালকা বৃষ্টি হচ্ছে।
# POS Tags A: [('রাস্তায়', None), ('হালকা', None), ('বৃষ্টি', 'NN'), ('হচ্ছে।', None)]
# Sentence B: মেঘলা আকাশে বৃষ্টি ফোটে।
# POS Tags B: [('মেঘলা', None), ('আকাশে', 'NN'), ('বৃষ্টি', 'NN'), ('ফোটে।', None)]
# Relevant Words A: ['বৃষ্টি']
# Relevant Words B: ['আকাশে', 'বৃষ্টি']
# Optimized Word Mover's Distance (OWMD): 0.3877
# Optimized Word Mover's Similarity (OWMS): 0.6786
# --------------------------------------------------
#
# Processing Pair 16:
# Sentence A: সে নিজের বাড়ি সাজিয়েছে।
# POS Tags A: [('সে', 'PRP'), ('নিজের', 'PRP'), ('বাড়ি', None), ('সাজিয়েছে।', None)]
# Sentence B: তার বাসা নতুন রঙে রাঙানো।
# POS Tags B: [('তার', 'PRP'), ('বাসা', None), ('নতুন', 'JJ'), ('রঙে', None), ('রাঙানো।', None)]
# Relevant Words A: ['সে', 'নিজের', 'বাড়ি', 'সাজিয়েছে।']
# Relevant Words B: ['নতুন']
# Optimized Word Mover's Distance (OWMD): 0.5962
# Optimized Word Mover's Similarity (OWMS): 0.5509
# --------------------------------------------------
#
# Processing Pair 17:
# Sentence A: আমি সিনেমা দেখতে গিয়েছিলাম।
# POS Tags A: [('আমি', 'PRP'), ('সিনেমা', None), ('দেখতে', 'VM'), ('গিয়েছিলাম।', None)]
# Sentence B: চলচ্চিত্র দেখার অভিজ্ঞতা অসাধারণ ছিল।
# POS Tags B: [('চলচ্চিত্র', None), ('দেখার', 'VM'), ('অভিজ্ঞতা', None), ('অসাধারণ', None), ('ছিল।', None)]
# Relevant Words A: ['দেখতে']
# Relevant Words B: ['দেখার']
# Optimized Word Mover's Distance (OWMD): 0.8286
# Optimized Word Mover's Similarity (OWMS): 0.4367
# --------------------------------------------------
#
# Processing Pair 18:
# Sentence A: সে দুপুরে খাবার করে।
# POS Tags A: [('সে', 'PRP'), ('দুপুরে', None), ('খাবার', None), ('করে।', None)]
# Sentence B: দুপুরের আহার তার শক্তির উৎস।
# POS Tags B: [('দুপুরের', None), ('আহার', None), ('তার', 'PRP'), ('শক্তির', None), ('উৎস।', None)]
# Relevant Words A: ['সে', 'দুপুরে', 'খাবার', 'করে।']
# Relevant Words B: ['দুপুরের', 'আহার', 'তার', 'শক্তির', 'উৎস।']
# Optimized Word Mover's Distance (OWMD): 0.6698
# Optimized Word Mover's Similarity (OWMS): 0.5118
# --------------------------------------------------
#
# Processing Pair 19:
# Sentence A: আজ আমার মন ভালো।
# POS Tags A: [('আজ', 'NN'), ('আমার', 'PRP'), ('মন', 'NN'), ('ভালো।', None)]
# Sentence B: আজ আমার মেজাজ একদম সুন্দর।
# POS Tags B: [('আজ', 'NN'), ('আমার', 'PRP'), ('মেজাজ', None), ('একদম', None), ('সুন্দর।', None)]
# Relevant Words A: ['আজ', 'মন']
# Relevant Words B: ['আজ']
# Optimized Word Mover's Distance (OWMD): 0.4930
# Optimized Word Mover's Similarity (OWMS): 0.6108
# --------------------------------------------------
#
# Processing Pair 20:
# Sentence A: সে নতুন বই কিনেছে।
# POS Tags A: [('সে', 'PRP'), ('নতুন', 'JJ'), ('বই', 'NN'), ('কিনেছে।', None)]
# Sentence B: তার পাঠ্যবই সমৃদ্ধ।
# POS Tags B: [('তার', 'PRP'), ('পাঠ্যবই', None), ('সমৃদ্ধ।', None)]
# Relevant Words A: ['নতুন', 'বই']
# Relevant Words B: ['তার', 'পাঠ্যবই', 'সমৃদ্ধ।']
# Optimized Word Mover's Distance (OWMD): 0.8265
# Optimized Word Mover's Similarity (OWMS): 0.4376
# --------------------------------------------------
#
# Processing Pair 21:
# Sentence A: আমরা পার্কে খেলাধুলা করি।
# POS Tags A: [('আমরা', 'PRP'), ('পার্কে', None), ('খেলাধুলা', None), ('করি।', None)]
# Sentence B: পার্কে আমরা বিনোদনের সময় কাটাই।
# POS Tags B: [('পার্কে', None), ('আমরা', 'PRP'), ('বিনোদনের', None), ('সময়', None), ('কাটাই।', None)]
# Relevant Words A: ['আমরা', 'পার্কে', 'খেলাধুলা', 'করি।']
# Relevant Words B: ['পার্কে', 'আমরা', 'বিনোদনের', 'সময়', 'কাটাই।']
# Optimized Word Mover's Distance (OWMD): 0.5024
# Optimized Word Mover's Similarity (OWMS): 0.6051
# --------------------------------------------------
#
# Processing Pair 22:
# Sentence A: সে তার বন্ধুদের সাথে সময় কাটায়।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('বন্ধুদের', 'NN'), ('সাথে', 'PSP'), ('সময়', None), ('কাটায়।', None)]
# Sentence B: তার সঙ্গীরা তার প্রিয়।
# POS Tags B: [('তার', 'PRP'), ('সঙ্গীরা', None), ('তার', 'PRP'), ('প্রিয়।', None)]
# Relevant Words A: ['বন্ধুদের']
# Relevant Words B: ['তার', 'সঙ্গীরা', 'তার', 'প্রিয়।']
# Optimized Word Mover's Distance (OWMD): 0.4986
# Optimized Word Mover's Similarity (OWMS): 0.6074
# --------------------------------------------------
#
# Processing Pair 23:
# Sentence A: আমি সঙ্গীত বাজাই।
# POS Tags A: [('আমি', 'PRP'), ('সঙ্গীত', None), ('বাজাই।', None)]
# Sentence B: সঙ্গীত আমার আবেগ প্রকাশ করে।
# POS Tags B: [('সঙ্গীত', None), ('আমার', 'PRP'), ('আবেগ', None), ('প্রকাশ', 'NN'), ('করে।', None)]
# Relevant Words A: ['আমি', 'সঙ্গীত', 'বাজাই।']
# Relevant Words B: ['প্রকাশ']
# Optimized Word Mover's Distance (OWMD): 0.6973
# Optimized Word Mover's Similarity (OWMS): 0.4979
# --------------------------------------------------
#
# Processing Pair 24:
# Sentence A: সে নতুন ফোন কিনেছে।
# POS Tags A: [('সে', 'PRP'), ('নতুন', 'JJ'), ('ফোন', None), ('কিনেছে।', None)]
# Sentence B: তার মোবাইলটি একেবারে ঝকঝকে।
# POS Tags B: [('তার', 'PRP'), ('মোবাইলটি', None), ('একেবারে', 'RB'), ('ঝকঝকে।', None)]
# Relevant Words A: ['নতুন']
# Relevant Words B: ['একেবারে']
# Optimized Word Mover's Distance (OWMD): 0.5229
# Optimized Word Mover's Similarity (OWMS): 0.5928
# --------------------------------------------------
#
# Processing Pair 25:
# Sentence A: আমরা সকালে সূর্যোদয় দেখেছিলাম।
# POS Tags A: [('আমরা', 'PRP'), ('সকালে', None), ('সূর্যোদয়', None), ('দেখেছিলাম।', None)]
# Sentence B: সকালে সূর্যের প্রথম আলো আমাদের অভিভূত করেছিল।
# POS Tags B: [('সকালে', None), ('সূর্যের', None), ('প্রথম', 'QO'), ('আলো', 'NN'), ('আমাদের', 'PRP'), ('অভিভূত', None), ('করেছিল।', None)]
# Relevant Words A: ['আমরা', 'সকালে', 'সূর্যোদয়', 'দেখেছিলাম।']
# Relevant Words B: ['আলো']
# Optimized Word Mover's Distance (OWMD): 0.6871
# Optimized Word Mover's Similarity (OWMS): 0.5030
# --------------------------------------------------
#
# Processing Pair 26:
# Sentence A: সে শহরে ভ্রমণ করে।
# POS Tags A: [('সে', 'PRP'), ('শহরে', None), ('ভ্রমণ', None), ('করে।', None)]
# Sentence B: শহরের সৌন্দর্য তার দৃষ্টি আকর্ষণ করে।
# POS Tags B: [('শহরের', None), ('সৌন্দর্য', None), ('তার', 'PRP'), ('দৃষ্টি', 'NN'), ('আকর্ষণ', None), ('করে।', None)]
# Relevant Words A: ['সে', 'শহরে', 'ভ্রমণ', 'করে।']
# Relevant Words B: ['দৃষ্টি']
# Optimized Word Mover's Distance (OWMD): 0.7078
# Optimized Word Mover's Similarity (OWMS): 0.4927
# --------------------------------------------------
#
# Processing Pair 27:
# Sentence A: আমি আর্ট গ্যালারিতে গিয়েছিলাম।
# POS Tags A: [('আমি', 'PRP'), ('আর্ট', None), ('গ্যালারিতে', None), ('গিয়েছিলাম।', None)]
# Sentence B: শিল্প প্রদর্শনী আমার মনের প্রশান্তি দেয়।
# POS Tags B: [('শিল্প', None), ('প্রদর্শনী', None), ('আমার', 'PRP'), ('মনের', 'NN'), ('প্রশান্তি', None), ('দেয়।', None)]
# Relevant Words A: ['আমি', 'আর্ট', 'গ্যালারিতে', 'গিয়েছিলাম।']
# Relevant Words B: ['মনের']
# Optimized Word Mover's Distance (OWMD): 0.6469
# Optimized Word Mover's Similarity (OWMS): 0.5236
# --------------------------------------------------
#
# Processing Pair 28:
# Sentence A: সে সাঁতার কাটা শিখেছে।
# POS Tags A: [('সে', 'PRP'), ('সাঁতার', None), ('কাটা', None), ('শিখেছে।', None)]
# Sentence B: তার সাঁতার কাটার দক্ষতা বৃদ্ধি পেয়েছে।
# POS Tags B: [('তার', 'PRP'), ('সাঁতার', None), ('কাটার', 'VM'), ('দক্ষতা', None), ('বৃদ্ধি', 'NN'), ('পেয়েছে।', None)]
# Relevant Words A: ['সে', 'সাঁতার', 'কাটা', 'শিখেছে।']
# Relevant Words B: ['কাটার', 'বৃদ্ধি']
# Optimized Word Mover's Distance (OWMD): 0.7227
# Optimized Word Mover's Similarity (OWMS): 0.4854
# --------------------------------------------------
#
# Processing Pair 29:
# Sentence A: আজকে ঠাণ্ডা বৃষ্টি হচ্ছে।
# POS Tags A: [('আজকে', 'NN'), ('ঠাণ্ডা', 'JJ'), ('বৃষ্টি', 'NN'), ('হচ্ছে।', None)]
# Sentence B: আবহাওয়া একদম শীতল।
# POS Tags B: [('আবহাওয়া', None), ('একদম', None), ('শীতল।', None)]
# Relevant Words A: ['আজকে', 'ঠাণ্ডা', 'বৃষ্টি']
# Relevant Words B: ['আবহাওয়া', 'একদম', 'শীতল।']
# Optimized Word Mover's Distance (OWMD): 0.9355
# Optimized Word Mover's Similarity (OWMS): 0.3924
# --------------------------------------------------
#
# Processing Pair 30:
# Sentence A: সে হাসতে ভালোবাসে।
# POS Tags A: [('সে', 'PRP'), ('হাসতে', None), ('ভালোবাসে।', None)]
# Sentence B: তার হাসি সবাইকে আনন্দ দেয়।
# POS Tags B: [('তার', 'PRP'), ('হাসি', 'NN'), ('সবাইকে', 'PRP'), ('আনন্দ', 'NN'), ('দেয়।', None)]
# Relevant Words A: ['সে', 'হাসতে', 'ভালোবাসে।']
# Relevant Words B: ['হাসি', 'আনন্দ']
# Optimized Word Mover's Distance (OWMD): 0.8761
# Optimized Word Mover's Similarity (OWMS): 0.4164
# --------------------------------------------------
#
# Processing Pair 31:
# Sentence A: আমি প্রতিদিন লেখা অনুশীলন করি।
# POS Tags A: [('আমি', 'PRP'), ('প্রতিদিন', None), ('লেখা', 'VM'), ('অনুশীলন', 'NN'), ('করি।', None)]
# Sentence B: লেখা আমার সৃজনশীলতার প্রকাশ।
# POS Tags B: [('লেখা', 'VM'), ('আমার', 'PRP'), ('সৃজনশীলতার', None), ('প্রকাশ।', None)]
# Relevant Words A: ['লেখা', 'অনুশীলন']
# Relevant Words B: ['লেখা']
# Optimized Word Mover's Distance (OWMD): 0.5680
# Optimized Word Mover's Similarity (OWMS): 0.5667
# --------------------------------------------------
#
# Processing Pair 32:
# Sentence A: সে রান্না করতে ভালোবাসে।
# POS Tags A: [('সে', 'PRP'), ('রান্না', 'NN'), ('করতে', 'VM'), ('ভালোবাসে।', None)]
# Sentence B: তার রান্নার স্বাদ অসাধারণ।
# POS Tags B: [('তার', 'PRP'), ('রান্নার', 'NN'), ('স্বাদ', 'NN'), ('অসাধারণ।', None)]
# Relevant Words A: ['রান্না', 'করতে']
# Relevant Words B: ['রান্নার', 'স্বাদ']
# Optimized Word Mover's Distance (OWMD): 0.5884
# Optimized Word Mover's Similarity (OWMS): 0.5552
# --------------------------------------------------
#
# Processing Pair 33:
# Sentence A: আমরা বইমেলায় গিয়েছিলাম।
# POS Tags A: [('আমরা', 'PRP'), ('বইমেলায়', None), ('গিয়েছিলাম।', None)]
# Sentence B: বইমেলায় নতুন বই আবিষ্কার করেছি।
# POS Tags B: [('বইমেলায়', None), ('নতুন', 'JJ'), ('বই', 'NN'), ('আবিষ্কার', None), ('করেছি।', None)]
# Relevant Words A: ['আমরা', 'বইমেলায়', 'গিয়েছিলাম।']
# Relevant Words B: ['নতুন', 'বই']
# Optimized Word Mover's Distance (OWMD): 0.7355
# Optimized Word Mover's Similarity (OWMS): 0.4793
# --------------------------------------------------
#
# Processing Pair 34:
# Sentence A: সে মাঠে ফুটবল খেলেছে।
# POS Tags A: [('সে', 'PRP'), ('মাঠে', None), ('ফুটবল', None), ('খেলেছে।', None)]
# Sentence B: তার ফুটবল খেলার চপলতা মুগ্ধকর।
# POS Tags B: [('তার', 'PRP'), ('ফুটবল', None), ('খেলার', None), ('চপলতা', None), ('মুগ্ধকর।', None)]
# Relevant Words A: ['সে', 'মাঠে', 'ফুটবল', 'খেলেছে।']
# Relevant Words B: ['তার', 'ফুটবল', 'খেলার', 'চপলতা', 'মুগ্ধকর।']
# Optimized Word Mover's Distance (OWMD): 0.6593
# Optimized Word Mover's Similarity (OWMS): 0.5172
# --------------------------------------------------
#
# Processing Pair 35:
# Sentence A: আমি নিজের মতো করে চিন্তা করি।
# POS Tags A: [('আমি', 'PRP'), ('নিজের', 'PRP'), ('মতো', 'PSP'), ('করে', 'VM'), ('চিন্তা', None), ('করি।', None)]
# Sentence B: আমার দৃষ্টিভঙ্গি ভিন্ন।
# POS Tags B: [('আমার', 'PRP'), ('দৃষ্টিভঙ্গি', None), ('ভিন্ন।', None)]
# Relevant Words A: ['করে']
# Relevant Words B: ['আমার', 'দৃষ্টিভঙ্গি', 'ভিন্ন।']
# Optimized Word Mover's Distance (OWMD): 0.6901
# Optimized Word Mover's Similarity (OWMS): 0.5015
# --------------------------------------------------
#
# Processing Pair 36:
# Sentence A: সে সঙ্গীতের ক্লাসে যায়।
# POS Tags A: [('সে', 'PRP'), ('সঙ্গীতের', None), ('ক্লাসে', None), ('যায়।', None)]
# Sentence B: তার সুরেলা কণ্ঠস্বর ক্লাসে প্রশংসিত।
# POS Tags B: [('তার', 'PRP'), ('সুরেলা', None), ('কণ্ঠস্বর', None), ('ক্লাসে', None), ('প্রশংসিত।', None)]
# Relevant Words A: ['সে', 'সঙ্গীতের', 'ক্লাসে', 'যায়।']
# Relevant Words B: ['তার', 'সুরেলা', 'কণ্ঠস্বর', 'ক্লাসে', 'প্রশংসিত।']
# Optimized Word Mover's Distance (OWMD): 0.4984
# Optimized Word Mover's Similarity (OWMS): 0.6075
# --------------------------------------------------
#
# Processing Pair 37:
# Sentence A: আজকের রাতটি শান্ত।
# POS Tags A: [('আজকের', 'NN'), ('রাতটি', None), ('শান্ত।', None)]
# Sentence B: রাত্রি একেবারে নিরিবিলি।
# POS Tags B: [('রাত্রি', 'NN'), ('একেবারে', 'RB'), ('নিরিবিলি।', None)]
# Relevant Words A: ['আজকের']
# Relevant Words B: ['রাত্রি', 'একেবারে']
# Optimized Word Mover's Distance (OWMD): 0.6245
# Optimized Word Mover's Similarity (OWMS): 0.5355
# --------------------------------------------------
#
# Processing Pair 38:
# Sentence A: সে পাখিদের কথা শুনে।
# POS Tags A: [('সে', 'PRP'), ('পাখিদের', None), ('কথা', 'NN'), ('শুনে।', None)]
# Sentence B: তার পরিবেশের প্রতি গভীর আকর্ষণ আছে।
# POS Tags B: [('তার', 'PRP'), ('পরিবেশের', None), ('প্রতি', 'QF'), ('গভীর', 'JJ'), ('আকর্ষণ', None), ('আছে।', None)]
# Relevant Words A: ['কথা']
# Relevant Words B: ['গভীর']
# Optimized Word Mover's Distance (OWMD): 1.4106
# Optimized Word Mover's Similarity (OWMS): 0.2440
# --------------------------------------------------
#
# Processing Pair 39:
# Sentence A: আমি ছবি আঁকতে ভালোবাসি।
# POS Tags A: [('আমি', 'PRP'), ('ছবি', 'NN'), ('আঁকতে', None), ('ভালোবাসি।', None)]
# Sentence B: আমার আঁকা ছবি মনোমুগ্ধকর।
# POS Tags B: [('আমার', 'PRP'), ('আঁকা', 'VM'), ('ছবি', 'NN'), ('মনোমুগ্ধকর।', None)]
# Relevant Words A: ['ছবি']
# Relevant Words B: ['আঁকা', 'ছবি']
# Optimized Word Mover's Distance (OWMD): 0.6867
# Optimized Word Mover's Similarity (OWMS): 0.5033
# --------------------------------------------------
#
# Processing Pair 40:
# Sentence A: সে প্রতিদিন ব্যায়াম করে।
# POS Tags A: [('সে', 'PRP'), ('প্রতিদিন', None), ('ব্যায়াম', None), ('করে।', None)]
# Sentence B: তার শরীরচর্চা নিয়মিত।
# POS Tags B: [('তার', 'PRP'), ('শরীরচর্চা', None), ('নিয়মিত।', None)]
# Relevant Words A: ['সে', 'প্রতিদিন', 'ব্যায়াম', 'করে।']
# Relevant Words B: ['তার', 'শরীরচর্চা', 'নিয়মিত।']
# Optimized Word Mover's Distance (OWMD): 0.7398
# Optimized Word Mover's Similarity (OWMS): 0.4772
# --------------------------------------------------
#
# Processing Pair 41:
# Sentence A: আমরা বাগানে ঘুমাই।
# POS Tags A: [('আমরা', 'PRP'), ('বাগানে', None), ('ঘুমাই।', None)]
# Sentence B: প্রকৃতির মাঝে বিশ্রাম পাই।
# POS Tags B: [('প্রকৃতির', None), ('মাঝে', 'RDP'), ('বিশ্রাম', 'NN'), ('পাই।', None)]
# Relevant Words A: ['আমরা', 'বাগানে', 'ঘুমাই।']
# Relevant Words B: ['বিশ্রাম']
# Optimized Word Mover's Distance (OWMD): 1.1162
# Optimized Word Mover's Similarity (OWMS): 0.3275
# --------------------------------------------------
#
# Processing Pair 42:
# Sentence A: সে নতুন গান রচনা করেছে।
# POS Tags A: [('সে', 'PRP'), ('নতুন', 'JJ'), ('গান', 'NN'), ('রচনা', 'NN'), ('করেছে।', None)]
# Sentence B: তার সুরেলা সঙ্গীত সবাইকে স্পর্শ করেছে।
# POS Tags B: [('তার', 'PRP'), ('সুরেলা', None), ('সঙ্গীত', None), ('সবাইকে', 'PRP'), ('স্পর্শ', 'NN'), ('করেছে।', None)]
# Relevant Words A: ['নতুন', 'গান', 'রচনা']
# Relevant Words B: ['স্পর্শ']
# Optimized Word Mover's Distance (OWMD): 1.0147
# Optimized Word Mover's Similarity (OWMS): 0.3625
# --------------------------------------------------
#
# Processing Pair 43:
# Sentence A: আমি কবিতা লিখি।
# POS Tags A: [('আমি', 'PRP'), ('কবিতা', None), ('লিখি।', None)]
# Sentence B: কবিতা আমার হৃদয়ের ভাষা।
# POS Tags B: [('কবিতা', None), ('আমার', 'PRP'), ('হৃদয়ের', None), ('ভাষা।', None)]
# Relevant Words A: ['আমি', 'কবিতা', 'লিখি।']
# Relevant Words B: ['কবিতা', 'আমার', 'হৃদয়ের', 'ভাষা।']
# Optimized Word Mover's Distance (OWMD): 0.6543
# Optimized Word Mover's Similarity (OWMS): 0.5198
# --------------------------------------------------
#
# Processing Pair 44:
# Sentence A: সে দোকানে নতুন জামাকাপড় কিনেছে।
# POS Tags A: [('সে', 'PRP'), ('দোকানে', 'NN'), ('নতুন', 'JJ'), ('জামাকাপড়', None), ('কিনেছে।', None)]
# Sentence B: তার পোশাক সংগ্রহে নতুনত্ব আছে।
# POS Tags B: [('তার', 'PRP'), ('পোশাক', 'NN'), ('সংগ্রহে', None), ('নতুনত্ব', None), ('আছে।', None)]
# Relevant Words A: ['দোকানে', 'নতুন']
# Relevant Words B: ['পোশাক']
# Optimized Word Mover's Distance (OWMD): 1.2700
# Optimized Word Mover's Similarity (OWMS): 0.2808
# --------------------------------------------------
#
# Processing Pair 45:
# Sentence A: আজ বৃষ্টি ঝরে পড়ছে।
# POS Tags A: [('আজ', 'NN'), ('বৃষ্টি', 'NN'), ('ঝরে', 'VM'), ('পড়ছে।', None)]
# Sentence B: আবহাওয়া একদম রোমান্টিক।
# POS Tags B: [('আবহাওয়া', None), ('একদম', None), ('রোমান্টিক।', None)]
# Relevant Words A: ['আজ', 'বৃষ্টি', 'ঝরে']
# Relevant Words B: ['আবহাওয়া', 'একদম', 'রোমান্টিক।']
# Optimized Word Mover's Distance (OWMD): 0.8980
# Optimized Word Mover's Similarity (OWMS): 0.4074
# --------------------------------------------------
#
# Processing Pair 46:
# Sentence A: সে কলেজে ভাল মেধাবী।
# POS Tags A: [('সে', 'PRP'), ('কলেজে', None), ('ভাল', 'JJ'), ('মেধাবী।', None)]
# Sentence B: তার পড়াশোনায় উৎকর্ষতা রয়েছে।
# POS Tags B: [('তার', 'PRP'), ('পড়াশোনায়', None), ('উৎকর্ষতা', None), ('রয়েছে।', None)]
# Relevant Words A: ['ভাল']
# Relevant Words B: ['তার', 'পড়াশোনায়', 'উৎকর্ষতা', 'রয়েছে।']
# Optimized Word Mover's Distance (OWMD): 0.7897
# Optimized Word Mover's Similarity (OWMS): 0.4540
# --------------------------------------------------
#
# Processing Pair 47:
# Sentence A: আমি বাগানে কাজ করি।
# POS Tags A: [('আমি', 'PRP'), ('বাগানে', None), ('কাজ', 'NN'), ('করি।', None)]
# Sentence B: প্রকৃতির মাঝে আমার শান্তি।
# POS Tags B: [('প্রকৃতির', None), ('মাঝে', 'RDP'), ('আমার', 'PRP'), ('শান্তি।', None)]
# Relevant Words A: ['কাজ']
# Relevant Words B: ['প্রকৃতির', 'মাঝে', 'আমার', 'শান্তি।']
# Optimized Word Mover's Distance (OWMD): 0.6457
# Optimized Word Mover's Similarity (OWMS): 0.5243
# --------------------------------------------------
#
# Processing Pair 48:
# Sentence A: সে বাজারে নতুন ফল কিনেছে।
# POS Tags A: [('সে', 'PRP'), ('বাজারে', None), ('নতুন', 'JJ'), ('ফল', 'NN'), ('কিনেছে।', None)]
# Sentence B: তার তাজা ফলের ভান্ডার সমৃদ্ধ।
# POS Tags B: [('তার', 'PRP'), ('তাজা', None), ('ফলের', 'NN'), ('ভান্ডার', None), ('সমৃদ্ধ।', None)]
# Relevant Words A: ['নতুন', 'ফল']
# Relevant Words B: ['ফলের']
# Optimized Word Mover's Distance (OWMD): 0.6594
# Optimized Word Mover's Similarity (OWMS): 0.5171
# --------------------------------------------------
#
# Processing Pair 49:
# Sentence A: আমরা বন্ধুদের সাথে সিনেমা দেখলাম।
# POS Tags A: [('আমরা', 'PRP'), ('বন্ধুদের', 'NN'), ('সাথে', 'PSP'), ('সিনেমা', None), ('দেখলাম।', None)]
# Sentence B: সিনেমা আমাদের মিলনের মুহূর্ত।
# POS Tags B: [('সিনেমা', None), ('আমাদের', 'PRP'), ('মিলনের', None), ('মুহূর্ত।', None)]
# Relevant Words A: ['বন্ধুদের']
# Relevant Words B: ['সিনেমা', 'আমাদের', 'মিলনের', 'মুহূর্ত।']
# Optimized Word Mover's Distance (OWMD): 0.5714
# Optimized Word Mover's Similarity (OWMS): 0.5647
# --------------------------------------------------
#
# Processing Pair 50:
# Sentence A: সে প্রতিদিন সকালে মেডিটেশন করে।
# POS Tags A: [('সে', 'PRP'), ('প্রতিদিন', None), ('সকালে', None), ('মেডিটেশন', None), ('করে।', None)]
# Sentence B: তার মনের শান্তি নিশ্চিত হয়।
# POS Tags B: [('তার', 'PRP'), ('মনের', 'NN'), ('শান্তি', 'NN'), ('নিশ্চিত', 'JJ'), ('হয়।', None)]
# Relevant Words A: ['সে', 'প্রতিদিন', 'সকালে', 'মেডিটেশন', 'করে।']
# Relevant Words B: ['মনের', 'শান্তি', 'নিশ্চিত']
# Optimized Word Mover's Distance (OWMD): 0.7151
# Optimized Word Mover's Similarity (OWMS): 0.4892
# --------------------------------------------------
#
# Processing Pair 51:
# Sentence A: আমি হস্তশিল্প করি।
# POS Tags A: [('আমি', 'PRP'), ('হস্তশিল্প', None), ('করি।', None)]
# Sentence B: হস্তশিল্প আমার সৃজনশীল প্রকাশ।
# POS Tags B: [('হস্তশিল্প', None), ('আমার', 'PRP'), ('সৃজনশীল', None), ('প্রকাশ।', None)]
# Relevant Words A: ['আমি', 'হস্তশিল্প', 'করি।']
# Relevant Words B: ['হস্তশিল্প', 'আমার', 'সৃজনশীল', 'প্রকাশ।']
# Optimized Word Mover's Distance (OWMD): 0.4978
# Optimized Word Mover's Similarity (OWMS): 0.6079
# --------------------------------------------------
#
# Processing Pair 52:
# Sentence A: সে তার আর্ট প্রোজেক্ট সম্পন্ন করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('আর্ট', None), ('প্রোজেক্ট', None), ('সম্পন্ন', 'JJ'), ('করেছে।', None)]
# Sentence B: তার চিত্রকর্ম প্রশংসিত হয়েছে।
# POS Tags B: [('তার', 'PRP'), ('চিত্রকর্ম', None), ('প্রশংসিত', None), ('হয়েছে।', None)]
# Relevant Words A: ['সম্পন্ন']
# Relevant Words B: ['তার', 'চিত্রকর্ম', 'প্রশংসিত', 'হয়েছে।']
# Optimized Word Mover's Distance (OWMD): 0.6438
# Optimized Word Mover's Similarity (OWMS): 0.5253
# --------------------------------------------------
#
# Processing Pair 53:
# Sentence A: আজকের দিনটি উজ্জ্বল।
# POS Tags A: [('আজকের', 'NN'), ('দিনটি', None), ('উজ্জ্বল।', None)]
# Sentence B: আলো দিনের ছোঁয়া মুগ্ধকর।
# POS Tags B: [('আলো', 'NN'), ('দিনের', 'NN'), ('ছোঁয়া', None), ('মুগ্ধকর।', None)]
# Relevant Words A: ['আজকের']
# Relevant Words B: ['আলো', 'দিনের']
# Optimized Word Mover's Distance (OWMD): 0.4952
# Optimized Word Mover's Similarity (OWMS): 0.6094
# --------------------------------------------------
#
# Processing Pair 54:
# Sentence A: সে প্রাকৃতিক সঙ্গীত উপভোগ করে।
# POS Tags A: [('সে', 'PRP'), ('প্রাকৃতিক', None), ('সঙ্গীত', None), ('উপভোগ', None), ('করে।', None)]
# Sentence B: প্রকৃতির শব্দ তার মনের প্রশান্তি দেয়।
# POS Tags B: [('প্রকৃতির', None), ('শব্দ', 'NN'), ('তার', 'PRP'), ('মনের', 'NN'), ('প্রশান্তি', None), ('দেয়।', None)]
# Relevant Words A: ['সে', 'প্রাকৃতিক', 'সঙ্গীত', 'উপভোগ', 'করে।']
# Relevant Words B: ['শব্দ', 'মনের']
# Optimized Word Mover's Distance (OWMD): 0.8322
# Optimized Word Mover's Similarity (OWMS): 0.4351
# --------------------------------------------------
#
# Processing Pair 55:
# Sentence A: আমি ভ্রমণ পছন্দ করি।
# POS Tags A: [('আমি', 'PRP'), ('ভ্রমণ', None), ('পছন্দ', 'NN'), ('করি।', None)]
# Sentence B: নতুন জায়গা অন্বেষণ আমার রুচির।
# POS Tags B: [('নতুন', 'JJ'), ('জায়গা', None), ('অন্বেষণ', None), ('আমার', 'PRP'), ('রুচির।', None)]
# Relevant Words A: ['পছন্দ']
# Relevant Words B: ['নতুন']
# Optimized Word Mover's Distance (OWMD): 0.8792
# Optimized Word Mover's Similarity (OWMS): 0.4151
# --------------------------------------------------
#
# Processing Pair 56:
# Sentence A: সে তার ডায়েরি লিখে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('ডায়েরি', None), ('লিখে।', None)]
# Sentence B: তার প্রতিদিনের অভিজ্ঞতা বইতে রূপান্তরিত।
# POS Tags B: [('তার', 'PRP'), ('প্রতিদিনের', None), ('অভিজ্ঞতা', None), ('বইতে', None), ('রূপান্তরিত।', None)]
# Relevant Words A: ['সে', 'তার', 'ডায়েরি', 'লিখে।']
# Relevant Words B: ['তার', 'প্রতিদিনের', 'অভিজ্ঞতা', 'বইতে', 'রূপান্তরিত।']
# Optimized Word Mover's Distance (OWMD): 0.6275
# Optimized Word Mover's Similarity (OWMS): 0.5339
# --------------------------------------------------
#
# Processing Pair 57:
# Sentence A: আজকের সকালের বাতাস সতেজ।
# POS Tags A: [('আজকের', 'NN'), ('সকালের', None), ('বাতাস', None), ('সতেজ।', None)]
# Sentence B: সকালে হাওয়া প্রাণবন্ত।
# POS Tags B: [('সকালে', None), ('হাওয়া', None), ('প্রাণবন্ত।', None)]
# Relevant Words A: ['আজকের']
# Relevant Words B: ['সকালে', 'হাওয়া', 'প্রাণবন্ত।']
# Optimized Word Mover's Distance (OWMD): 0.5232
# Optimized Word Mover's Similarity (OWMS): 0.5926
# --------------------------------------------------
#
# Processing Pair 58:
# Sentence A: সে তার নতুন ব্লগ শুরু করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('নতুন', 'JJ'), ('ব্লগ', None), ('শুরু', 'NN'), ('করেছে।', None)]
# Sentence B: তার লেখাগুলি অনন্য অভিজ্ঞতা প্রকাশ করে।
# POS Tags B: [('তার', 'PRP'), ('লেখাগুলি', None), ('অনন্য', None), ('অভিজ্ঞতা', None), ('প্রকাশ', 'NN'), ('করে।', None)]
# Relevant Words A: ['নতুন', 'শুরু']
# Relevant Words B: ['প্রকাশ']
# Optimized Word Mover's Distance (OWMD): 0.8996
# Optimized Word Mover's Similarity (OWMS): 0.4067
# --------------------------------------------------
#
# Processing Pair 59:
# Sentence A: আমি সাপ্তাহিক বাজারে যাই।
# POS Tags A: [('আমি', 'PRP'), ('সাপ্তাহিক', None), ('বাজারে', None), ('যাই।', None)]
# Sentence B: বাজারের রঙিনতা আমাকে মুগ্ধ করে।
# POS Tags B: [('বাজারের', 'NN'), ('রঙিনতা', None), ('আমাকে', 'PRP'), ('মুগ্ধ', None), ('করে।', None)]
# Relevant Words A: ['আমি', 'সাপ্তাহিক', 'বাজারে', 'যাই।']
# Relevant Words B: ['বাজারের']
# Optimized Word Mover's Distance (OWMD): 0.7272
# Optimized Word Mover's Similarity (OWMS): 0.4833
# --------------------------------------------------
#
# Processing Pair 60:
# Sentence A: সে তার প্রিয় গান গায়।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রিয়', None), ('গান', 'NN'), ('গায়।', None)]
# Sentence B: তার সুরেলা কণ্ঠস্বর সবাইকে আকৃষ্ট করে।
# POS Tags B: [('তার', 'PRP'), ('সুরেলা', None), ('কণ্ঠস্বর', None), ('সবাইকে', 'PRP'), ('আকৃষ্ট', None), ('করে।', None)]
# Relevant Words A: ['গান']
# Relevant Words B: ['তার', 'সুরেলা', 'কণ্ঠস্বর', 'সবাইকে', 'আকৃষ্ট', 'করে।']
# Optimized Word Mover's Distance (OWMD): 0.8217
# Optimized Word Mover's Similarity (OWMS): 0.4397
# --------------------------------------------------
#
# Processing Pair 61:
# Sentence A: আজকের মিটিং সফল হয়েছে।
# POS Tags A: [('আজকের', 'NN'), ('মিটিং', None), ('সফল', 'JJ'), ('হয়েছে।', None)]
# Sentence B: আলোচনায় সবাই সম্মত হয়েছে।
# POS Tags B: [('আলোচনায়', None), ('সবাই', 'PRP'), ('সম্মত', None), ('হয়েছে।', None)]
# Relevant Words A: ['আজকের', 'সফল']
# Relevant Words B: ['আলোচনায়', 'সবাই', 'সম্মত', 'হয়েছে।']
# Optimized Word Mover's Distance (OWMD): 0.7749
# Optimized Word Mover's Similarity (OWMS): 0.4607
# --------------------------------------------------
#
# Processing Pair 62:
# Sentence A: সে নতুন বন্ধু বানিয়েছে।
# POS Tags A: [('সে', 'PRP'), ('নতুন', 'JJ'), ('বন্ধু', 'NN'), ('বানিয়েছে।', None)]
# Sentence B: তার সামাজিকতা চমৎকার।
# POS Tags B: [('তার', 'PRP'), ('সামাজিকতা', None), ('চমৎকার।', None)]
# Relevant Words A: ['নতুন', 'বন্ধু']
# Relevant Words B: ['তার', 'সামাজিকতা', 'চমৎকার।']
# Optimized Word Mover's Distance (OWMD): 0.8346
# Optimized Word Mover's Similarity (OWMS): 0.4341
# --------------------------------------------------
#
# Processing Pair 63:
# Sentence A: আমি প্রাকৃতিক দৃশ্যের ছবি তুলি।
# POS Tags A: [('আমি', 'PRP'), ('প্রাকৃতিক', None), ('দৃশ্যের', None), ('ছবি', 'NN'), ('তুলি।', None)]
# Sentence B: ফটোগ্রাফি আমার শখ।
# POS Tags B: [('ফটোগ্রাফি', None), ('আমার', 'PRP'), ('শখ।', None)]
# Relevant Words A: ['ছবি']
# Relevant Words B: ['ফটোগ্রাফি', 'আমার', 'শখ।']
# Optimized Word Mover's Distance (OWMD): 1.1518
# Optimized Word Mover's Similarity (OWMS): 0.3161
# --------------------------------------------------
#
# Processing Pair 64:
# Sentence A: সে তার প্রোজেক্টে পরিশ্রম করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রোজেক্টে', None), ('পরিশ্রম', 'NN'), ('করেছে।', None)]
# Sentence B: তার কাজের ফলাফল সন্তোষজনক।
# POS Tags B: [('তার', 'PRP'), ('কাজের', 'NN'), ('ফলাফল', None), ('সন্তোষজনক।', None)]
# Relevant Words A: ['পরিশ্রম']
# Relevant Words B: ['কাজের']
# Optimized Word Mover's Distance (OWMD): 0.5764
# Optimized Word Mover's Similarity (OWMS): 0.5619
# --------------------------------------------------
#
# Processing Pair 65:
# Sentence A: আজকের খাওয়াদাওয়া সুস্বাদু।
# POS Tags A: [('আজকের', 'NN'), ('খাওয়াদাওয়া', None), ('সুস্বাদু।', None)]
# Sentence B: ভোজনের স্বাদ একেবারে মনোমুগ্ধকর।
# POS Tags B: [('ভোজনের', None), ('স্বাদ', 'NN'), ('একেবারে', 'RB'), ('মনোমুগ্ধকর।', None)]
# Relevant Words A: ['আজকের']
# Relevant Words B: ['স্বাদ', 'একেবারে']
# Optimized Word Mover's Distance (OWMD): 0.5659
# Optimized Word Mover's Similarity (OWMS): 0.5678
# --------------------------------------------------
#
# Processing Pair 66:
# Sentence A: সে তার কর্মক্ষেত্রে সফল হয়েছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('কর্মক্ষেত্রে', None), ('সফল', 'JJ'), ('হয়েছে।', None)]
# Sentence B: তার প্রফেশনাল জীবন উজ্জ্বল।
# POS Tags B: [('তার', 'PRP'), ('প্রফেশনাল', None), ('জীবন', 'NN'), ('উজ্জ্বল।', None)]
# Relevant Words A: ['সফল']
# Relevant Words B: ['জীবন']
# Optimized Word Mover's Distance (OWMD): 1.0735
# Optimized Word Mover's Similarity (OWMS): 0.3418
# --------------------------------------------------
#
# Processing Pair 67:
# Sentence A: আমি প্রতিদিন সাঁতার কাটি।
# POS Tags A: [('আমি', 'PRP'), ('প্রতিদিন', None), ('সাঁতার', None), ('কাটি।', None)]
# Sentence B: সাঁতার আমার শরীরকে সুস্থ রাখে।
# POS Tags B: [('সাঁতার', None), ('আমার', 'PRP'), ('শরীরকে', None), ('সুস্থ', None), ('রাখে।', None)]
# Relevant Words A: ['আমি', 'প্রতিদিন', 'সাঁতার', 'কাটি।']
# Relevant Words B: ['সাঁতার', 'আমার', 'শরীরকে', 'সুস্থ', 'রাখে।']
# Optimized Word Mover's Distance (OWMD): 0.6355
# Optimized Word Mover's Similarity (OWMS): 0.5296
# --------------------------------------------------
#
# Processing Pair 68:
# Sentence A: সে তার বাড়ির ছাদে বসে গল্প করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('বাড়ির', 'NN'), ('ছাদে', None), ('বসে', 'VM'), ('গল্প', None), ('করে।', None)]
# Sentence B: তার রাত্রির আলাপ সবাইকে মুগ্ধ করে।
# POS Tags B: [('তার', 'PRP'), ('রাত্রির', 'NN'), ('আলাপ', None), ('সবাইকে', 'PRP'), ('মুগ্ধ', None), ('করে।', None)]
# Relevant Words A: ['বাড়ির', 'বসে']
# Relevant Words B: ['রাত্রির']
# Optimized Word Mover's Distance (OWMD): 0.7871
# Optimized Word Mover's Similarity (OWMS): 0.4552
# --------------------------------------------------
#
# Processing Pair 69:
# Sentence A: আজকের পাঠ্যসূচি অত্যন্ত তথ্যবহুল।
# POS Tags A: [('আজকের', 'NN'), ('পাঠ্যসূচি', None), ('অত্যন্ত', 'INTF'), ('তথ্যবহুল।', None)]
# Sentence B: শিক্ষা আজকের আলোচনার কেন্দ্রবিন্দু।
# POS Tags B: [('শিক্ষা', 'NN'), ('আজকের', 'NN'), ('আলোচনার', None), ('কেন্দ্রবিন্দু।', None)]
# Relevant Words A: ['আজকের']
# Relevant Words B: ['শিক্ষা', 'আজকের']
# Optimized Word Mover's Distance (OWMD): 0.4090
# Optimized Word Mover's Similarity (OWMS): 0.6643
# --------------------------------------------------
#
# Processing Pair 70:
# Sentence A: সে তার প্রতিদিনের অভ্যাস রেকর্ড করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রতিদিনের', None), ('অভ্যাস', None), ('রেকর্ড', None), ('করে।', None)]
# Sentence B: তার ডায়েরিতে প্রতিটি দিন সংরক্ষিত।
# POS Tags B: [('তার', 'PRP'), ('ডায়েরিতে', None), ('প্রতিটি', 'QF'), ('দিন', 'NN'), ('সংরক্ষিত।', None)]
# Relevant Words A: ['সে', 'তার', 'প্রতিদিনের', 'অভ্যাস', 'রেকর্ড', 'করে।']
# Relevant Words B: ['দিন']
# Optimized Word Mover's Distance (OWMD): 0.8116
# Optimized Word Mover's Similarity (OWMS): 0.4442
# --------------------------------------------------
#
# Processing Pair 71:
# Sentence A: আমি আমার প্রিয় সঙ্গীত শুনি।
# POS Tags A: [('আমি', 'PRP'), ('আমার', 'PRP'), ('প্রিয়', None), ('সঙ্গীত', None), ('শুনি।', None)]
# Sentence B: সঙ্গীত আমার জীবনের সুর।
# POS Tags B: [('সঙ্গীত', None), ('আমার', 'PRP'), ('জীবনের', 'NN'), ('সুর।', None)]
# Relevant Words A: ['আমি', 'আমার', 'প্রিয়', 'সঙ্গীত', 'শুনি।']
# Relevant Words B: ['জীবনের']
# Optimized Word Mover's Distance (OWMD): 0.5940
# Optimized Word Mover's Similarity (OWMS): 0.5521
# --------------------------------------------------
#
# Processing Pair 72:
# Sentence A: সে তার মোবাইল ফোন আপডেট করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('মোবাইল', None), ('ফোন', None), ('আপডেট', None), ('করেছে।', None)]
# Sentence B: তার টেকনোলজি ভালোভাবে পরিচালিত।
# POS Tags B: [('তার', 'PRP'), ('টেকনোলজি', None), ('ভালোভাবে', 'RB'), ('পরিচালিত।', None)]
# Relevant Words A: ['সে', 'তার', 'মোবাইল', 'ফোন', 'আপডেট', 'করেছে।']
# Relevant Words B: ['ভালোভাবে']
# Optimized Word Mover's Distance (OWMD): 0.8817
# Optimized Word Mover's Similarity (OWMS): 0.4141
# --------------------------------------------------
#
# Processing Pair 73:
# Sentence A: আজকের সন্ধ্যা একেবারে মনোমুগ্ধকর।
# POS Tags A: [('আজকের', 'NN'), ('সন্ধ্যা', None), ('একেবারে', 'RB'), ('মনোমুগ্ধকর।', None)]
# Sentence B: সন্ধ্যার আলো আমাকে মুগ্ধ করে।
# POS Tags B: [('সন্ধ্যার', None), ('আলো', 'NN'), ('আমাকে', 'PRP'), ('মুগ্ধ', None), ('করে।', None)]
# Relevant Words A: ['আজকের', 'একেবারে']
# Relevant Words B: ['আলো']
# Optimized Word Mover's Distance (OWMD): 0.6283
# Optimized Word Mover's Similarity (OWMS): 0.5335
# --------------------------------------------------
#
# Processing Pair 74:
# Sentence A: সে তার প্রোগ্রামিং কোড লিখেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রোগ্রামিং', None), ('কোড', None), ('লিখেছে।', None)]
# Sentence B: তার সফটওয়্যার দক্ষতা অসাধারণ।
# POS Tags B: [('তার', 'PRP'), ('সফটওয়্যার', None), ('দক্ষতা', None), ('অসাধারণ।', None)]
# Relevant Words A: ['সে', 'তার', 'প্রোগ্রামিং', 'কোড', 'লিখেছে।']
# Relevant Words B: ['তার', 'সফটওয়্যার', 'দক্ষতা', 'অসাধারণ।']
# Optimized Word Mover's Distance (OWMD): 0.6994
# Optimized Word Mover's Similarity (OWMS): 0.4969
# --------------------------------------------------
#
# Processing Pair 75:
# Sentence A: আমি নতুন রেসিপি চেষ্টা করি।
# POS Tags A: [('আমি', 'PRP'), ('নতুন', 'JJ'), ('রেসিপি', None), ('চেষ্টা', 'NN'), ('করি।', None)]
# Sentence B: রান্নাঘরে নতুনত্ব আমার সৃজনশীলতা।
# POS Tags B: [('রান্নাঘরে', None), ('নতুনত্ব', None), ('আমার', 'PRP'), ('সৃজনশীলতা।', None)]
# Relevant Words A: ['নতুন', 'চেষ্টা']
# Relevant Words B: ['রান্নাঘরে', 'নতুনত্ব', 'আমার', 'সৃজনশীলতা।']
# Optimized Word Mover's Distance (OWMD): 0.8297
# Optimized Word Mover's Similarity (OWMS): 0.4362
# --------------------------------------------------
#
# Processing Pair 76:
# Sentence A: সে তার গাড়ি পরিষ্কার করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('গাড়ি', None), ('পরিষ্কার', 'NN'), ('করেছে।', None)]
# Sentence B: তার যানবাহন ঝকঝকে করে তুলেছে।
# POS Tags B: [('তার', 'PRP'), ('যানবাহন', None), ('ঝকঝকে', None), ('করে', 'VM'), ('তুলেছে।', None)]
# Relevant Words A: ['পরিষ্কার']
# Relevant Words B: ['করে']
# Optimized Word Mover's Distance (OWMD): 0.5638
# Optimized Word Mover's Similarity (OWMS): 0.5690
# --------------------------------------------------
#
# Processing Pair 77:
# Sentence A: আজকের আবহাওয়া চমৎকার।
# POS Tags A: [('আজকের', 'NN'), ('আবহাওয়া', None), ('চমৎকার।', None)]
# Sentence B: আকাশে রৌদ্রের উজ্জ্বলতা স্পষ্ট।
# POS Tags B: [('আকাশে', 'NN'), ('রৌদ্রের', None), ('উজ্জ্বলতা', None), ('স্পষ্ট।', None)]
# Relevant Words A: ['আজকের']
# Relevant Words B: ['আকাশে']
# Optimized Word Mover's Distance (OWMD): 0.8655
# Optimized Word Mover's Similarity (OWMS): 0.4209
# --------------------------------------------------
#
# Processing Pair 78:
# Sentence A: সে তার প্রতিযোগিতায় জয়ী হয়েছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রতিযোগিতায়', None), ('জয়ী', None), ('হয়েছে।', None)]
# Sentence B: তার কঠোর পরিশ্রম ফলপ্রসূ হয়েছে।
# POS Tags B: [('তার', 'PRP'), ('কঠোর', None), ('পরিশ্রম', 'NN'), ('ফলপ্রসূ', None), ('হয়েছে।', None)]
# Relevant Words A: ['সে', 'তার', 'প্রতিযোগিতায়', 'জয়ী', 'হয়েছে।']
# Relevant Words B: ['পরিশ্রম']
# Optimized Word Mover's Distance (OWMD): 0.7090
# Optimized Word Mover's Similarity (OWMS): 0.4921
# --------------------------------------------------
#
# Processing Pair 79:
# Sentence A: আমি বইয়ের দোকানে ভ্রমণ করি।
# POS Tags A: [('আমি', 'PRP'), ('বইয়ের', None), ('দোকানে', 'NN'), ('ভ্রমণ', None), ('করি।', None)]
# Sentence B: নতুন বই আমার আনন্দের উৎস।
# POS Tags B: [('নতুন', 'JJ'), ('বই', 'NN'), ('আমার', 'PRP'), ('আনন্দের', 'NN'), ('উৎস।', None)]
# Relevant Words A: ['দোকানে']
# Relevant Words B: ['নতুন', 'বই', 'আনন্দের']
# Optimized Word Mover's Distance (OWMD): 0.8789
# Optimized Word Mover's Similarity (OWMS): 0.4153
# --------------------------------------------------
#
# Processing Pair 80:
# Sentence A: সে তার পরীক্ষায় উচ্চতম নম্বর অর্জন করেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('পরীক্ষায়', None), ('উচ্চতম', None), ('নম্বর', None), ('অর্জন', None), ('করেছে।', None)]
# Sentence B: তার অধ্যবসায় সফলতার চাবিকাঠি।
# POS Tags B: [('তার', 'PRP'), ('অধ্যবসায়', None), ('সফলতার', None), ('চাবিকাঠি।', None)]
# Relevant Words A: ['সে', 'তার', 'পরীক্ষায়', 'উচ্চতম', 'নম্বর', 'অর্জন', 'করেছে।']
# Relevant Words B: ['তার', 'অধ্যবসায়', 'সফলতার', 'চাবিকাঠি।']
# Optimized Word Mover's Distance (OWMD): 0.6220
# Optimized Word Mover's Similarity (OWMS): 0.5369
# --------------------------------------------------
#
# Processing Pair 81:
# Sentence A: আজকের রাত্রি নিরিবিলি।
# POS Tags A: [('আজকের', 'NN'), ('রাত্রি', 'NN'), ('নিরিবিলি।', None)]
# Sentence B: চাঁদের আলো শান্তির বার্তা দেয়।
# POS Tags B: [('চাঁদের', None), ('আলো', 'NN'), ('শান্তির', None), ('বার্তা', 'NN'), ('দেয়।', None)]
# Relevant Words A: ['আজকের', 'রাত্রি']
# Relevant Words B: ['আলো', 'বার্তা']
# Optimized Word Mover's Distance (OWMD): 0.7015
# Optimized Word Mover's Similarity (OWMS): 0.4958
# --------------------------------------------------
#
# Processing Pair 82:
# Sentence A: সে তার প্রজেক্টের উপস্থাপনা দিয়েছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রজেক্টের', None), ('উপস্থাপনা', None), ('দিয়েছে।', None)]
# Sentence B: তার বক্তব্য সবাইকে অনুপ্রাণিত করেছে।
# POS Tags B: [('তার', 'PRP'), ('বক্তব্য', 'NN'), ('সবাইকে', 'PRP'), ('অনুপ্রাণিত', None), ('করেছে।', None)]
# Relevant Words A: ['সে', 'তার', 'প্রজেক্টের', 'উপস্থাপনা', 'দিয়েছে।']
# Relevant Words B: ['বক্তব্য']
# Optimized Word Mover's Distance (OWMD): 1.0339
# Optimized Word Mover's Similarity (OWMS): 0.3556
# --------------------------------------------------
#
# Processing Pair 83:
# Sentence A: আমি পার্কে দৌড়াদৌড়ি করি।
# POS Tags A: [('আমি', 'PRP'), ('পার্কে', None), ('দৌড়াদৌড়ি', None), ('করি।', None)]
# Sentence B: ব্যায়াম আমার স্বাস্থ্য রক্ষায় সহায়ক।
# POS Tags B: [('ব্যায়াম', None), ('আমার', 'PRP'), ('স্বাস্থ্য', None), ('রক্ষায়', None), ('সহায়ক।', None)]
# Relevant Words A: ['আমি', 'পার্কে', 'দৌড়াদৌড়ি', 'করি।']
# Relevant Words B: ['ব্যায়াম', 'আমার', 'স্বাস্থ্য', 'রক্ষায়', 'সহায়ক।']
# Optimized Word Mover's Distance (OWMD): 0.7613
# Optimized Word Mover's Similarity (OWMS): 0.4671
# --------------------------------------------------
#
# Processing Pair 84:
# Sentence A: সে তার যাত্রার গল্প শেয়ার করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('যাত্রার', None), ('গল্প', None), ('শেয়ার', None), ('করে।', None)]
# Sentence B: তার অভিজ্ঞতা সকলের জন্য প্রেরণাদায়ক।
# POS Tags B: [('তার', 'PRP'), ('অভিজ্ঞতা', None), ('সকলের', 'PRP'), ('জন্য', 'PSP'), ('প্রেরণাদায়ক।', None)]
# Relevant Words A: ['সে', 'তার', 'যাত্রার', 'গল্প', 'শেয়ার', 'করে।']
# Relevant Words B: ['তার', 'অভিজ্ঞতা', 'সকলের', 'জন্য', 'প্রেরণাদায়ক।']
# Optimized Word Mover's Distance (OWMD): 0.5872
# Optimized Word Mover's Similarity (OWMS): 0.5559
# --------------------------------------------------
#
# Processing Pair 85:
# Sentence A: আজকের সকালে পাখির গান শুনি।
# POS Tags A: [('আজকের', 'NN'), ('সকালে', None), ('পাখির', None), ('গান', 'NN'), ('শুনি।', None)]
# Sentence B: প্রকৃতির সুর আমার মনকে ছুঁয়ে যায়।
# POS Tags B: [('প্রকৃতির', None), ('সুর', 'NN'), ('আমার', 'PRP'), ('মনকে', None), ('ছুঁয়ে', None), ('যায়।', None)]
# Relevant Words A: ['আজকের', 'গান']
# Relevant Words B: ['সুর']
# Optimized Word Mover's Distance (OWMD): 0.9513
# Optimized Word Mover's Similarity (OWMS): 0.3862
# --------------------------------------------------
#
# Processing Pair 86:
# Sentence A: সে তার সৃজনশীল কাজ প্রদর্শন করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('সৃজনশীল', None), ('কাজ', 'NN'), ('প্রদর্শন', None), ('করে।', None)]
# Sentence B: তার শিল্পকর্ম সকলের নজর কেড়ে নেয়।
# POS Tags B: [('তার', 'PRP'), ('শিল্পকর্ম', None), ('সকলের', 'PRP'), ('নজর', None), ('কেড়ে', None), ('নেয়।', None)]
# Relevant Words A: ['কাজ']
# Relevant Words B: ['তার', 'শিল্পকর্ম', 'সকলের', 'নজর', 'কেড়ে', 'নেয়।']
# Optimized Word Mover's Distance (OWMD): 0.8588
# Optimized Word Mover's Similarity (OWMS): 0.4237
# --------------------------------------------------
#
# Processing Pair 87:
# Sentence A: আমি ট্রেনের মাধ্যমে ভ্রমণ করি।
# POS Tags A: [('আমি', 'PRP'), ('ট্রেনের', None), ('মাধ্যমে', 'PSP'), ('ভ্রমণ', None), ('করি।', None)]
# Sentence B: যাত্রাপথের অভিজ্ঞতা অনন্য।
# POS Tags B: [('যাত্রাপথের', None), ('অভিজ্ঞতা', None), ('অনন্য।', None)]
# Relevant Words A: ['আমি', 'ট্রেনের', 'মাধ্যমে', 'ভ্রমণ', 'করি।']
# Relevant Words B: ['যাত্রাপথের', 'অভিজ্ঞতা', 'অনন্য।']
# Optimized Word Mover's Distance (OWMD): 0.7358
# Optimized Word Mover's Similarity (OWMS): 0.4791
# --------------------------------------------------
#
# Processing Pair 88:
# Sentence A: সে তার অফিসে সময়মত পৌঁছায়।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('অফিসে', None), ('সময়মত', None), ('পৌঁছায়।', None)]
# Sentence B: তার পেশাগত দায়িত্ব পালনে দক্ষ।
# POS Tags B: [('তার', 'PRP'), ('পেশাগত', None), ('দায়িত্ব', None), ('পালনে', None), ('দক্ষ।', None)]
# Relevant Words A: ['সে', 'তার', 'অফিসে', 'সময়মত', 'পৌঁছায়।']
# Relevant Words B: ['তার', 'পেশাগত', 'দায়িত্ব', 'পালনে', 'দক্ষ।']
# Optimized Word Mover's Distance (OWMD): 0.8030
# Optimized Word Mover's Similarity (OWMS): 0.4480
# --------------------------------------------------
#
# Processing Pair 89:
# Sentence A: আজকের দুপুরের খাবার স্বাস্থ্যকর।
# POS Tags A: [('আজকের', 'NN'), ('দুপুরের', None), ('খাবার', None), ('স্বাস্থ্যকর।', None)]
# Sentence B: পুষ্টিকর আহার আমার শক্তির উৎস।
# POS Tags B: [('পুষ্টিকর', None), ('আহার', None), ('আমার', 'PRP'), ('শক্তির', None), ('উৎস।', None)]
# Relevant Words A: ['আজকের']
# Relevant Words B: ['পুষ্টিকর', 'আহার', 'আমার', 'শক্তির', 'উৎস।']
# Optimized Word Mover's Distance (OWMD): 0.6869
# Optimized Word Mover's Similarity (OWMS): 0.5032
# --------------------------------------------------
#
# Processing Pair 90:
# Sentence A: সে তার স্কুলে নতুন পরিকল্পনা উপস্থাপন করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('স্কুলে', None), ('নতুন', 'JJ'), ('পরিকল্পনা', None), ('উপস্থাপন', None), ('করে।', None)]
# Sentence B: তার আইডিয়া সকলকে অনুপ্রাণিত করে।
# POS Tags B: [('তার', 'PRP'), ('আইডিয়া', None), ('সকলকে', None), ('অনুপ্রাণিত', None), ('করে।', None)]
# Relevant Words A: ['নতুন']
# Relevant Words B: ['তার', 'আইডিয়া', 'সকলকে', 'অনুপ্রাণিত', 'করে।']
# Optimized Word Mover's Distance (OWMD): 0.5581
# Optimized Word Mover's Similarity (OWMS): 0.5723
# --------------------------------------------------
#
# Processing Pair 91:
# Sentence A: আমি সাপ্তাহিক বাজারে তাজা ফল কিনি।
# POS Tags A: [('আমি', 'PRP'), ('সাপ্তাহিক', None), ('বাজারে', None), ('তাজা', None), ('ফল', 'NN'), ('কিনি।', None)]
# Sentence B: ফল আমার দিনের তাজা উপাদান।
# POS Tags B: [('ফল', 'NN'), ('আমার', 'PRP'), ('দিনের', 'NN'), ('তাজা', None), ('উপাদান।', None)]
# Relevant Words A: ['ফল']
# Relevant Words B: ['ফল', 'দিনের']
# Optimized Word Mover's Distance (OWMD): 0.4185
# Optimized Word Mover's Similarity (OWMS): 0.6580
# --------------------------------------------------
#
# Processing Pair 92:
# Sentence A: সে তার বাড়ির সামনে পেইন্টিং করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('বাড়ির', 'NN'), ('সামনে', 'NST'), ('পেইন্টিং', None), ('করে।', None)]
# Sentence B: তার রংয়ের সমাহার মনোমুগ্ধকর।
# POS Tags B: [('তার', 'PRP'), ('রংয়ের', None), ('সমাহার', None), ('মনোমুগ্ধকর।', None)]
# Relevant Words A: ['বাড়ির']
# Relevant Words B: ['তার', 'রংয়ের', 'সমাহার', 'মনোমুগ্ধকর।']
# Optimized Word Mover's Distance (OWMD): 0.6352
# Optimized Word Mover's Similarity (OWMS): 0.5298
# --------------------------------------------------
#
# Processing Pair 93:
# Sentence A: আজকের রাতের খাওয়াদাওয়া মনোরম।
# POS Tags A: [('আজকের', 'NN'), ('রাতের', 'NN'), ('খাওয়াদাওয়া', None), ('মনোরম।', None)]
# Sentence B: ভোজনের সাথেই মিলনের মুহূর্ত সৃষ্টি হয়।
# POS Tags B: [('ভোজনের', None), ('সাথেই', None), ('মিলনের', None), ('মুহূর্ত', None), ('সৃষ্টি', 'NN'), ('হয়।', None)]
# Relevant Words A: ['আজকের', 'রাতের']
# Relevant Words B: ['সৃষ্টি']
# Optimized Word Mover's Distance (OWMD): 0.5292
# Optimized Word Mover's Similarity (OWMS): 0.5891
# --------------------------------------------------
#
# Processing Pair 94:
# Sentence A: সে তার প্রিয় ব্লগে নতুন পোস্ট লিখেছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রিয়', None), ('ব্লগে', None), ('নতুন', 'JJ'), ('পোস্ট', None), ('লিখেছে।', None)]
# Sentence B: তার লেখাগুলি পাঠকদের আনন্দ দেয়।
# POS Tags B: [('তার', 'PRP'), ('লেখাগুলি', None), ('পাঠকদের', 'NN'), ('আনন্দ', 'NN'), ('দেয়।', None)]
# Relevant Words A: ['নতুন']
# Relevant Words B: ['পাঠকদের', 'আনন্দ']
# Optimized Word Mover's Distance (OWMD): 0.5513
# Optimized Word Mover's Similarity (OWMS): 0.5762
# --------------------------------------------------
#
# Processing Pair 95:
# Sentence A: আমি প্রতিদিন কিছু না কিছু শিখি।
# POS Tags A: [('আমি', 'PRP'), ('প্রতিদিন', None), ('কিছু', 'QF'), ('না', 'NEG'), ('কিছু', 'QF'), ('শিখি।', None)]
# Sentence B: শিক্ষা আমার জীবনের অংশ।
# POS Tags B: [('শিক্ষা', 'NN'), ('আমার', 'PRP'), ('জীবনের', 'NN'), ('অংশ।', None)]
# Relevant Words A: ['আমি', 'প্রতিদিন', 'কিছু', 'না', 'কিছু', 'শিখি।']
# Relevant Words B: ['শিক্ষা', 'জীবনের']
# Optimized Word Mover's Distance (OWMD): 0.8015
# Optimized Word Mover's Similarity (OWMS): 0.4487
# --------------------------------------------------
#
# Processing Pair 96:
# Sentence A: সে তার বন্ধুদের সাথে খেলা করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('বন্ধুদের', 'NN'), ('সাথে', 'PSP'), ('খেলা', None), ('করে।', None)]
# Sentence B: তার হাসিখুশি মিলনের সময়।
# POS Tags B: [('তার', 'PRP'), ('হাসিখুশি', None), ('মিলনের', None), ('সময়।', None)]
# Relevant Words A: ['বন্ধুদের']
# Relevant Words B: ['তার', 'হাসিখুশি', 'মিলনের', 'সময়।']
# Optimized Word Mover's Distance (OWMD): 0.7406
# Optimized Word Mover's Similarity (OWMS): 0.4768
# --------------------------------------------------
#
# Processing Pair 97:
# Sentence A: আজকের সকালের আর্দ্রতা স্বচ্ছ।
# POS Tags A: [('আজকের', 'NN'), ('সকালের', None), ('আর্দ্রতা', None), ('স্বচ্ছ।', None)]
# Sentence B: সকালে মাটির গন্ধ প্রশান্তিদায়ক।
# POS Tags B: [('সকালে', None), ('মাটির', 'NN'), ('গন্ধ', 'NN'), ('প্রশান্তিদায়ক।', None)]
# Relevant Words A: ['আজকের']
# Relevant Words B: ['মাটির', 'গন্ধ']
# Optimized Word Mover's Distance (OWMD): 0.9850
# Optimized Word Mover's Similarity (OWMS): 0.3734
# --------------------------------------------------
#
# Processing Pair 98:
# Sentence A: সে তার সৃজনশীল ধারণা প্রকাশ করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('সৃজনশীল', None), ('ধারণা', 'NN'), ('প্রকাশ', 'NN'), ('করে।', None)]
# Sentence B: তার আইডিয়া সত্যিই অনন্য।
# POS Tags B: [('তার', 'PRP'), ('আইডিয়া', None), ('সত্যিই', 'RB'), ('অনন্য।', None)]
# Relevant Words A: ['ধারণা', 'প্রকাশ']
# Relevant Words B: ['সত্যিই']
# Optimized Word Mover's Distance (OWMD): 1.1113
# Optimized Word Mover's Similarity (OWMS): 0.3291
# --------------------------------------------------
#
# Processing Pair 99:
# Sentence A: আমি তারাতারি রান্না করি।
# POS Tags A: [('আমি', 'PRP'), ('তারাতারি', None), ('রান্না', 'NN'), ('করি।', None)]
# Sentence B: রান্নাঘরে তাড়াতাড়ি স্বাদের খোঁজ।
# POS Tags B: [('রান্নাঘরে', None), ('তাড়াতাড়ি', 'RB'), ('স্বাদের', None), ('খোঁজ।', None)]
# Relevant Words A: ['রান্না']
# Relevant Words B: ['তাড়াতাড়ি']
# Optimized Word Mover's Distance (OWMD): 0.6270
# Optimized Word Mover's Similarity (OWMS): 0.5342
# --------------------------------------------------
#
# Processing Pair 100:
# Sentence A: সে তার যন্ত্রপাতি ঠিক করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('যন্ত্রপাতি', None), ('ঠিক', 'RB'), ('করে।', None)]
# Sentence B: তার মেকানিক্যাল কাজ দক্ষতার পরিচয় দেয়।
# POS Tags B: [('তার', 'PRP'), ('মেকানিক্যাল', None), ('কাজ', 'NN'), ('দক্ষতার', None), ('পরিচয়', None), ('দেয়।', None)]
# Relevant Words A: ['ঠিক']
# Relevant Words B: ['কাজ']
# Optimized Word Mover's Distance (OWMD): 1.1934
# Optimized Word Mover's Similarity (OWMS): 0.3032
# --------------------------------------------------
#
# Processing Pair 101:
# Sentence A: আজকের দিনটি উদযাপনের মতো।
# POS Tags A: [('আজকের', 'NN'), ('দিনটি', None), ('উদযাপনের', None), ('মতো।', None)]
# Sentence B: উৎসবমুখর পরিবেশ সবাইকে আনন্দ দেয়।
# POS Tags B: [('উৎসবমুখর', None), ('পরিবেশ', None), ('সবাইকে', 'PRP'), ('আনন্দ', 'NN'), ('দেয়।', None)]
# Relevant Words A: ['আজকের']
# Relevant Words B: ['আনন্দ']
# Optimized Word Mover's Distance (OWMD): 0.4978
# Optimized Word Mover's Similarity (OWMS): 0.6079
# --------------------------------------------------
#
# Processing Pair 102:
# Sentence A: সে তার স্বপ্নের চাকরি পেয়েছে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('স্বপ্নের', None), ('চাকরি', 'NN'), ('পেয়েছে।', None)]
# Sentence B: তার পরিশ্রম সফলতার ফল।
# POS Tags B: [('তার', 'PRP'), ('পরিশ্রম', 'NN'), ('সফলতার', None), ('ফল।', None)]
# Relevant Words A: ['চাকরি']
# Relevant Words B: ['পরিশ্রম']
# Optimized Word Mover's Distance (OWMD): 1.0154
# Optimized Word Mover's Similarity (OWMS): 0.3623
# --------------------------------------------------
#
# Processing Pair 103:
# Sentence A: আমি প্রাকৃতিক দৃশ্য উপভোগ করি।
# POS Tags A: [('আমি', 'PRP'), ('প্রাকৃতিক', None), ('দৃশ্য', None), ('উপভোগ', None), ('করি।', None)]
# Sentence B: প্রকৃতির সৌন্দর্য আমাকে মুগ্ধ করে।
# POS Tags B: [('প্রকৃতির', None), ('সৌন্দর্য', None), ('আমাকে', 'PRP'), ('মুগ্ধ', None), ('করে।', None)]
# Relevant Words A: ['আমি', 'প্রাকৃতিক', 'দৃশ্য', 'উপভোগ', 'করি।']
# Relevant Words B: ['প্রকৃতির', 'সৌন্দর্য', 'আমাকে', 'মুগ্ধ', 'করে।']
# Optimized Word Mover's Distance (OWMD): 0.6943
# Optimized Word Mover's Similarity (OWMS): 0.4994
# --------------------------------------------------
#
# Processing Pair 104:
# Sentence A: সে তার কর্মজীবনে উদ্যমী।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('কর্মজীবনে', None), ('উদ্যমী।', None)]
# Sentence B: তার কাজের প্রতি নিবেদিত মনোভাব প্রশংসনীয়।
# POS Tags B: [('তার', 'PRP'), ('কাজের', 'NN'), ('প্রতি', 'QF'), ('নিবেদিত', None), ('মনোভাব', None), ('প্রশংসনীয়।', None)]
# Relevant Words A: ['সে', 'তার', 'কর্মজীবনে', 'উদ্যমী।']
# Relevant Words B: ['কাজের']
# Optimized Word Mover's Distance (OWMD): 0.7463
# Optimized Word Mover's Similarity (OWMS): 0.4741
# --------------------------------------------------
#
# Processing Pair 105:
# Sentence A: আজকের আলো সকালে একেবারে দীপ্ত।
# POS Tags A: [('আজকের', 'NN'), ('আলো', 'NN'), ('সকালে', None), ('একেবারে', 'RB'), ('দীপ্ত।', None)]
# Sentence B: সকালের সূর্যোদয় মনোহর।
# POS Tags B: [('সকালের', None), ('সূর্যোদয়', None), ('মনোহর।', None)]
# Relevant Words A: ['আজকের', 'আলো', 'একেবারে']
# Relevant Words B: ['সকালের', 'সূর্যোদয়', 'মনোহর।']
# Optimized Word Mover's Distance (OWMD): 0.7307
# Optimized Word Mover's Similarity (OWMS): 0.4816
# --------------------------------------------------
#
# Processing Pair 106:
# Sentence A: সে তার প্রোজেক্টে সৃজনশীলতা দেখায়।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রোজেক্টে', None), ('সৃজনশীলতা', None), ('দেখায়।', None)]
# Sentence B: তার কাজের নতুনত্ব সবাইকে আকৃষ্ট করে।
# POS Tags B: [('তার', 'PRP'), ('কাজের', 'NN'), ('নতুনত্ব', None), ('সবাইকে', 'PRP'), ('আকৃষ্ট', None), ('করে।', None)]
# Relevant Words A: ['সে', 'তার', 'প্রোজেক্টে', 'সৃজনশীলতা', 'দেখায়।']
# Relevant Words B: ['কাজের']
# Optimized Word Mover's Distance (OWMD): 0.5067
# Optimized Word Mover's Similarity (OWMS): 0.6025
# --------------------------------------------------
#
# Processing Pair 107:
# Sentence A: আমি প্রতিদিন নতুন কিছু জানি।
# POS Tags A: [('আমি', 'PRP'), ('প্রতিদিন', None), ('নতুন', 'JJ'), ('কিছু', 'QF'), ('জানি।', None)]
# Sentence B: জ্ঞান আমার জীবনের আলো।
# POS Tags B: [('জ্ঞান', 'XC'), ('আমার', 'PRP'), ('জীবনের', 'NN'), ('আলো।', None)]
# Relevant Words A: ['নতুন']
# Relevant Words B: ['জীবনের']
# Optimized Word Mover's Distance (OWMD): 0.4518
# Optimized Word Mover's Similarity (OWMS): 0.6365
# --------------------------------------------------
#
# Processing Pair 108:
# Sentence A: সে তার সৃজনশীলতা নিয়ে কাজ করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('সৃজনশীলতা', None), ('নিয়ে', None), ('কাজ', 'NN'), ('করে।', None)]
# Sentence B: তার নতুন ধারণা প্রত্যাশিত।
# POS Tags B: [('তার', 'PRP'), ('নতুন', 'JJ'), ('ধারণা', 'NN'), ('প্রত্যাশিত।', None)]
# Relevant Words A: ['কাজ']
# Relevant Words B: ['নতুন', 'ধারণা']
# Optimized Word Mover's Distance (OWMD): 0.7166
# Optimized Word Mover's Similarity (OWMS): 0.4884
# --------------------------------------------------
#
# Processing Pair 109:
# Sentence A: আজকের আবহাওয়া আনন্দদায়ক।
# POS Tags A: [('আজকের', 'NN'), ('আবহাওয়া', None), ('আনন্দদায়ক।', None)]
# Sentence B: প্রকৃতির ছোঁয়া আমাকে প্রশান্ত করে।
# POS Tags B: [('প্রকৃতির', None), ('ছোঁয়া', None), ('আমাকে', 'PRP'), ('প্রশান্ত', None), ('করে।', None)]
# Relevant Words A: ['আজকের']
# Relevant Words B: ['প্রকৃতির', 'ছোঁয়া', 'আমাকে', 'প্রশান্ত', 'করে।']
# Optimized Word Mover's Distance (OWMD): 0.5061
# Optimized Word Mover's Similarity (OWMS): 0.6028
# --------------------------------------------------
#
# Processing Pair 110:
# Sentence A: সে তার দৈনন্দিন কাজ নিয়মিত সম্পন্ন করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('দৈনন্দিন', None), ('কাজ', 'NN'), ('নিয়মিত', None), ('সম্পন্ন', 'JJ'), ('করে।', None)]
# Sentence B: তার শৃঙ্খলাবদ্ধতা মুগ্ধকর।
# POS Tags B: [('তার', 'PRP'), ('শৃঙ্খলাবদ্ধতা', None), ('মুগ্ধকর।', None)]
# Relevant Words A: ['কাজ', 'সম্পন্ন']
# Relevant Words B: ['তার', 'শৃঙ্খলাবদ্ধতা', 'মুগ্ধকর।']
# Optimized Word Mover's Distance (OWMD): 0.7383
# Optimized Word Mover's Similarity (OWMS): 0.4779
# --------------------------------------------------
#
# Processing Pair 111:
# Sentence A: আমি নতুন বই পড়ার অভিজ্ঞতা সংগ্রহ করি।
# POS Tags A: [('আমি', 'PRP'), ('নতুন', 'JJ'), ('বই', 'NN'), ('পড়ার', None), ('অভিজ্ঞতা', None), ('সংগ্রহ', 'NN'), ('করি।', None)]
# Sentence B: পাঠ্যবই আমার মনের খোরাক।
# POS Tags B: [('পাঠ্যবই', None), ('আমার', 'PRP'), ('মনের', 'NN'), ('খোরাক।', None)]
# Relevant Words A: ['নতুন', 'বই', 'সংগ্রহ']
# Relevant Words B: ['মনের']
# Optimized Word Mover's Distance (OWMD): 0.7052
# Optimized Word Mover's Similarity (OWMS): 0.4940
# --------------------------------------------------
#
# Processing Pair 112:
# Sentence A: সে তার অফিসের কাজ সাবলীলভাবে সম্পন্ন করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('অফিসের', None), ('কাজ', 'NN'), ('সাবলীলভাবে', None), ('সম্পন্ন', 'JJ'), ('করে।', None)]
# Sentence B: তার পেশাগত দক্ষতা সবাইকে অনুপ্রাণিত করে।
# POS Tags B: [('তার', 'PRP'), ('পেশাগত', None), ('দক্ষতা', None), ('সবাইকে', 'PRP'), ('অনুপ্রাণিত', None), ('করে।', None)]
# Relevant Words A: ['কাজ', 'সম্পন্ন']
# Relevant Words B: ['তার', 'পেশাগত', 'দক্ষতা', 'সবাইকে', 'অনুপ্রাণিত', 'করে।']
# Optimized Word Mover's Distance (OWMD): 0.6623
# Optimized Word Mover's Similarity (OWMS): 0.5157
# --------------------------------------------------
#
# Processing Pair 113:
# Sentence A: আজকের দিনের আলো উজ্জ্বল।
# POS Tags A: [('আজকের', 'NN'), ('দিনের', 'NN'), ('আলো', 'NN'), ('উজ্জ্বল।', None)]
# Sentence B: সকালে রৌদ্রের আলোকসজ্জা মনোমুগ্ধকর।
# POS Tags B: [('সকালে', None), ('রৌদ্রের', None), ('আলোকসজ্জা', None), ('মনোমুগ্ধকর।', None)]
# Relevant Words A: ['আজকের', 'দিনের', 'আলো']
# Relevant Words B: ['সকালে', 'রৌদ্রের', 'আলোকসজ্জা', 'মনোমুগ্ধকর।']
# Optimized Word Mover's Distance (OWMD): 0.5615
# Optimized Word Mover's Similarity (OWMS): 0.5704
# --------------------------------------------------
#
# Processing Pair 114:
# Sentence A: সে তার সৃজনশীল লেখালেখি করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('সৃজনশীল', None), ('লেখালেখি', None), ('করে।', None)]
# Sentence B: তার লেখা সকলকে ভাবতে বাধ্য করে।
# POS Tags B: [('তার', 'PRP'), ('লেখা', 'VM'), ('সকলকে', None), ('ভাবতে', 'VM'), ('বাধ্য', 'JJ'), ('করে।', None)]
# Relevant Words A: ['সে', 'তার', 'সৃজনশীল', 'লেখালেখি', 'করে।']
# Relevant Words B: ['লেখা', 'ভাবতে', 'বাধ্য']
# Optimized Word Mover's Distance (OWMD): 0.7394
# Optimized Word Mover's Similarity (OWMS): 0.4774
# --------------------------------------------------
#
# Processing Pair 115:
# Sentence A: আমি সৃজনশীল কাজের প্রতি উৎসাহী।
# POS Tags A: [('আমি', 'PRP'), ('সৃজনশীল', None), ('কাজের', 'NN'), ('প্রতি', 'QF'), ('উৎসাহী।', None)]
# Sentence B: আমার সৃজনশীলতা আমার পরিচয়।
# POS Tags B: [('আমার', 'PRP'), ('সৃজনশীলতা', None), ('আমার', 'PRP'), ('পরিচয়।', None)]
# Relevant Words A: ['কাজের']
# Relevant Words B: ['আমার', 'সৃজনশীলতা', 'আমার', 'পরিচয়।']
# Optimized Word Mover's Distance (OWMD): 0.4931
# Optimized Word Mover's Similarity (OWMS): 0.6107
# --------------------------------------------------
#
# Processing Pair 116:
# Sentence A: সে তার প্রিয় সঙ্গীতে মগ্ন।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('প্রিয়', None), ('সঙ্গীতে', None), ('মগ্ন।', None)]
# Sentence B: তার সুরেলা কণ্ঠস্বর সবাইকে স্পর্শ করে।
# POS Tags B: [('তার', 'PRP'), ('সুরেলা', None), ('কণ্ঠস্বর', None), ('সবাইকে', 'PRP'), ('স্পর্শ', 'NN'), ('করে।', None)]
# Relevant Words A: ['সে', 'তার', 'প্রিয়', 'সঙ্গীতে', 'মগ্ন।']
# Relevant Words B: ['স্পর্শ']
# Optimized Word Mover's Distance (OWMD): 0.9688
# Optimized Word Mover's Similarity (OWMS): 0.3795
# --------------------------------------------------
#
# Processing Pair 117:
# Sentence A: আজকের দিনটি উদ্দীপ্ত।
# POS Tags A: [('আজকের', 'NN'), ('দিনটি', None), ('উদ্দীপ্ত।', None)]
# Sentence B: আলো দিনের ছোঁয়ায় মন ভালো হয়ে যায়।
# POS Tags B: [('আলো', 'NN'), ('দিনের', 'NN'), ('ছোঁয়ায়', None), ('মন', 'NN'), ('ভালো', 'JJ'), ('হয়ে', None), ('যায়।', None)]
# Relevant Words A: ['আজকের']
# Relevant Words B: ['আলো', 'দিনের', 'মন', 'ভালো']
# Optimized Word Mover's Distance (OWMD): 0.5669
# Optimized Word Mover's Similarity (OWMS): 0.5673
# --------------------------------------------------
#
# Processing Pair 118:
# Sentence A: সে তার নতুন পরিকল্পনা নিয়ে আলোচনা করে।
# POS Tags A: [('সে', 'PRP'), ('তার', 'PRP'), ('নতুন', 'JJ'), ('পরিকল্পনা', None), ('নিয়ে', None), ('আলোচনা', 'NN'), ('করে।', None)]
# Sentence B: তার আইডিয়া দলের সকলকে অনুপ্রাণিত করে।
# POS Tags B: [('তার', 'PRP'), ('আইডিয়া', None), ('দলের', None), ('সকলকে', None), ('অনুপ্রাণিত', None), ('করে।', None)]
# Relevant Words A: ['নতুন', 'আলোচনা']
# Relevant Words B: ['তার', 'আইডিয়া', 'দলের', 'সকলকে', 'অনুপ্রাণিত', 'করে।']
# Optimized Word Mover's Distance (OWMD): 0.6476
# Optimized Word Mover's Similarity (OWMS): 0.5233
# --------------------------------------------------
#
# Processing Pair 119:
# Sentence A: আমি প্রতিদিন প্রাকৃতিক পরিবেশে ভ্রমণ করি।
# POS Tags A: [('আমি', 'PRP'), ('প্রতিদিন', None), ('প্রাকৃতিক', None), ('পরিবেশে', None), ('ভ্রমণ', None), ('করি।', None)]
# Sentence B: প্রকৃতির সৌন্দর্য আমাকে রোমাঞ্চিত করে।
# POS Tags B: [('প্রকৃতির', None), ('সৌন্দর্য', None), ('আমাকে', 'PRP'), ('রোমাঞ্চিত', None), ('করে।', None)]
# Relevant Words A: ['আমি', 'প্রতিদিন', 'প্রাকৃতিক', 'পরিবেশে', 'ভ্রমণ', 'করি।']
# Relevant Words B: ['প্রকৃতির', 'সৌন্দর্য', 'আমাকে', 'রোমাঞ্চিত', 'করে।']
# Optimized Word Mover's Distance (OWMD): 0.6694
# Optimized Word Mover's Similarity (OWMS): 0.5120
# --------------------------------------------------
#
# Processing Pair 120:
# Sentence A: সে শহরে দ্রুত চলাফেরা করে।
# POS Tags A: [('সে', 'PRP'), ('শহরে', None), ('দ্রুত', None), ('চলাফেরা', 'NN'), ('করে।', None)]
# Sentence B: শহরের চাঞ্চল্য তার মনকে উদ্দীপিত করে।
# POS Tags B: [('শহরের', None), ('চাঞ্চল্য', None), ('তার', 'PRP'), ('মনকে', None), ('উদ্দীপিত', None), ('করে।', None)]
# Relevant Words A: ['চলাফেরা']
# Relevant Words B: ['শহরের', 'চাঞ্চল্য', 'তার', 'মনকে', 'উদ্দীপিত', 'করে।']
# Optimized Word Mover's Distance (OWMD): 0.9717
# Optimized Word Mover's Similarity (OWMS): 0.3784
# --------------------------------------------------
# OWMD computation completed!

# %%
import matplotlib.pyplot as plt

# Data for the first 20 WMD scores (from paste.txt)
wmd_values = [
    0.6919, 0.4666, 0.5781, 0.4049, 0.7144,
    0.4757, 0.6380, 0.5921, 0.5353, 0.4970,
    0.6216, 0.9141, 0.6205, 0.9442, 0.7834,
    0.8938, 0.7652, 0.6331, 0.5512, 0.7667
]

# Data for the first 20 OWMD scores (from paste-2.txt)
owmd_values = [
    1.1561, 0.5176, 0.4223, 0.4905, 0.7807,
    0.8900, 0.5739, 0.9193, 0.0000, 0.6975,
    0.7614, 1.1483, 0.6426, 1.1026, 0.3877,
    0.5962, 0.8286, 0.6698, 0.4930, 0.8265
]

# Sentence pair indices
pairs = range(1, 21)

# Plotting the data
plt.figure(figsize=(12, 6))
plt.plot(pairs, wmd_values, label="WMD", marker='o', linestyle='-', color='blue')
plt.plot(pairs, owmd_values, label="OWMD", marker='x', linestyle='--', color='orange')

# Adding labels and title
plt.xlabel("Sentence Pair Index", fontsize=12)
plt.ylabel("Distance Value", fontsize=12)
plt.title("Comparison of WMD and OWMD for First 20 Sentence Pairs", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.show()
